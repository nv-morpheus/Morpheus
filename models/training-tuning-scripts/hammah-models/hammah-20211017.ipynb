# %% [markdown]
# # Humans and Machines AutoEncoder Training Notebook

# %% [markdown]
# ### Table of Contents
# * Introduction
# * Dataset
# * Training
# * References

# %% [markdown]
# #### Introduction
#
# AWS accounts and usernames used for service accounts(machines) doing automated activities show different behaviours than accounts used by humans. Therefore, when such accounts are compromised, their CloudTrail logs change behaviour. AWS CloudTrail monitors activity across the AWS infrastructure. More information on AWS CloudTrail can be found [here](https://aws.amazon.com/cloudtrail/).
#
# This notebook shows how to train a neural network to learn the patterns in CloudTrail logs of AWS Accounts. We use an autoencoder and try to reconstruct the CloudTrail logs.
# An autoencoder is a neural network that can be used to learn a compressed representation of data. An autoencoder has encoder and decoder parts. The encoder compresses the data into a smaller dimension, and the decoder attempts to reconstruct the input. More information on the dfencoder library can be found [here](https://github.com/AlliedToasters/dfencoder).
#
# In inference, unusual logs should have a higher reconstruction error.

# %% [markdown]
# #### Dataset
# The dataset we use is the AWS CloudTrail logs in a tabular format consisting of the features we use.

# %%
import pandas as pd
import os
import numpy as np
import glob
import torch
from dfencoder import AutoEncoder
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import dill

# %% [markdown]
# Reading the benign training data and test data that contain anomalies

# %%
TRAINING_DATA_PATH = "../datasets/training-data/hammah-user123-training-data.csv"
VAL_DATA_PATH = "../datasets/validation-data/hammah-user123-validation-data.csv"
OUTPUT_MODEL_NAME = "hammah-user123-20211017.pkl"

# %%
# uncomment to train on other "role-g" instead of "user123"

# TRAINING_DATA_PATH = "../datasets/training-data/hammah-role-g-training-data.csv"
# VAL_DATA_PATH = "../datasets/validation-data/hammah-role-g-validation-data.csv"
# OUTPUT_MODEL_NAME = "hammah-role-g-20211017.pkl"

# %%
X_train=pd.read_csv(TRAINING_DATA_PATH)
X_val=pd.read_csv(VAL_DATA_PATH)

# %% [markdown]
# Selecting the features

# %%
features=['eventSource', 'eventName', 'sourceIPAddress', 'userAgent','userIdentitytype', 'requestParametersroleArn', 'requestParametersroleSessionName','requestParametersdurationSeconds', 'responseElementsassumedRoleUserassumedRoleId','responseElementsassumedRoleUserarn', 'apiVersion', 'userIdentityprincipalId','userIdentityarn', 'userIdentityaccountId', 'userIdentityaccessKeyId','userIdentitysessionContextsessionIssuerprincipalId', 'userIdentitysessionContextsessionIssueruserName','tlsDetailsclientProvidedHostHeader', 'requestParametersownersSetitems','requestParametersmaxResults', 'requestParametersinstancesSetitems','errorCode', 'errorMessage', 'requestParametersmaxItems','responseElementsrequestId', 'responseElementsinstancesSetitems','requestParametersgroupSetitems', 'requestParametersinstanceType','requestParametersmonitoringenabled', 'requestParametersdisableApiTermination','requestParametersebsOptimized', 'responseElementsreservationId', 'requestParametersgroupName'] #NO userIdentitysessionContextsessionIssuerarn,userIdentityuserName

# %%
for i in list(X_train):
    if i not in features:
        X_train=X_train.drop(i,axis=1)
for i in list(X_val):
    if i not in features:
        X_val=X_val.drop(i,axis=1)

# %% [markdown]
# Data types of the fields

# %%
X_train.dtypes
# Out:
# userIdentityaccountId                 object
# eventSource                           object
# eventName                             object
# sourceIPAddress                       object
# userAgent                             object
# userIdentitytype                      object
# apiVersion                            object
# userIdentityprincipalId               object
# userIdentityarn                       object
# userIdentityaccessKeyId               object
# tlsDetailsclientProvidedHostHeader    object
# errorCode                             object
# errorMessage                          object
# dtype: object

# %% [markdown]
# Making sure there's no completely empty columns in the training and validation sets

# %%
X_train = X_train.dropna(axis=1, how='all')
X_val = X_val.dropna(axis=1, how='all')

# %%
for i in list(X_val):
    if i not in list(X_train):
        X_val=X_val.drop([i],axis=1)

# %%
for i in list(X_train):
    if i not in list(X_val):
        X_train=X_train.drop([i],axis=1)

# %% [markdown]
# Configuring an autoencoder.
# More details about the model and the parameters can be found [here](https://github.com/AlliedToasters/dfencoder)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)
torch.backends.cudnn.deterministic = True
model = AutoEncoder(
    encoder_layers = [512, 500], #layers of the encoding part
    decoder_layers = [512], #layers of the decoding part
    activation='relu', #activation function
    swap_p=0.2, #noise parameter
    lr = 0.01, # learning rate
    lr_decay=.99, # learning decay
    batch_size=512,
    logger='ipynb', 
    verbose=False,
    optimizer='sgd', #SGD optimizer is selected(Stochastic gradient descent)
    scaler='gauss_rank', #feature scaling method
    min_cats=1 #cut off for minority categories
)

# %% [markdown]
# Train the model

# %%
model.fit(X_train, epochs=25, val=X_val)

# %% [markdown]
# Saving the trained model

# %%
torch.save(model.state_dict(),OUTPUT_MODEL_NAME)

# %%
with open(OUTPUT_MODEL_NAME[:-4]+'dill'+'.pkl', 'wb') as f:
    serialized_model = dill.dumps(model)
    f.write(serialized_model)

# %% [markdown]
# Testing the model

# %%
scores = model.get_anomaly_score(X_val)
X_val['anomaly_score'] = scores

# %%
#scores = model.get_anomaly_score(X_val)
X_val['anomaly_score'] = scores
X_val.sort_values('anomaly_score', ascending=False).head(10)
# Out:
#     userIdentityaccountId      eventSource            eventName  \
# 315     Account-123456789  lopez-byrd.info     DeleteEverything
# 314     Account-123456789        salas.com     DetachRolePolicy
# 318     Account-123456789        salas.com     DetachRolePolicy
# 317     Account-123456789  lopez-byrd.info      DescribeSubnets
# 321     Account-123456789  lopez-byrd.info      DescribeSubnets
# 316     Account-123456789  lopez-byrd.info      DescribeSubnets
# 544     Account-123456789     anderson.net  ListReadinessChecks
# 741     Account-123456789     anderson.net  ListReadinessChecks
# 476     Account-123456789     anderson.net  ListReadinessChecks
# 816     Account-123456789     anderson.net  ListReadinessChecks
#
#      sourceIPAddress                                          userAgent  \
# 315  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 314     23.19.39.232  Opera/8.23.(X11; Linux i686; da-DK) Presto/2.9...
# 318   156.198.140.30  Opera/8.23.(X11; Linux i686; da-DK) Presto/2.9...
# 317  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 321  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 316  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 544   91.115.171.224  Mozilla/5.0 (iPad; CPU iPad OS 7_1_2 like Mac ...
# 741     72.5.160.159  Mozilla/5.0 (compatible; MSIE 8.0; Windows 98;...
# 476   91.115.171.224  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# 816     72.5.160.159  Mozilla/5.0 (iPad; CPU iPad OS 4_2_1 like Mac ...
#
#     userIdentitytype  apiVersion               userIdentityprincipalId  \
# 315             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 314             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 318             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 317             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 321             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 316             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 544             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 741             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 476             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 816             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
#
#                                   userIdentityarn userIdentityaccessKeyId  \
# 315  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 314  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 318  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 317  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 321  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 316  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 544  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
# 741  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
# 476  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
# 816  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
#
#     tlsDetailsclientProvidedHostHeader             errorCode  \
# 315                                NaN  UnsupportedOperation
# 314                         hooper.com               success
# 318                         hooper.com               success
# 317                                NaN         MissingAction
# 321                                NaN         MissingAction
# 316                                NaN         MissingAction
# 544                         lester.net               success
# 741                         lester.net               success
# 476                         lester.net               success
# 816                         lester.net               success
#
#                                           errorMessage  anomaly_score
# 315  The specified subnet belongs to a different ac...       1.656023
# 314                                                NaN       1.647644
# 318                                                NaN       1.627712
# 317  The input fails to satisfy the constraints spe...       1.588513
# 321  The input fails to satisfy the constraints spe...       1.588513
# 316  The input fails to satisfy the constraints spe...       1.588513
# 544                                                NaN       1.194987
# 741                                                NaN       1.185173
# 476                                                NaN       1.173235
# 816                                                NaN       1.147573

# %%
X_val["zscore"] = (X_val["anomaly_score"] - X_val["anomaly_score"].mean())/X_val["anomaly_score"].std()

# %%
X_val.sort_values('zscore', ascending=False).head(10)
# Out:
#     userIdentityaccountId      eventSource            eventName  \
# 315     Account-123456789  lopez-byrd.info     DeleteEverything
# 314     Account-123456789        salas.com     DetachRolePolicy
# 318     Account-123456789        salas.com     DetachRolePolicy
# 317     Account-123456789  lopez-byrd.info      DescribeSubnets
# 321     Account-123456789  lopez-byrd.info      DescribeSubnets
# 316     Account-123456789  lopez-byrd.info      DescribeSubnets
# 544     Account-123456789     anderson.net  ListReadinessChecks
# 741     Account-123456789     anderson.net  ListReadinessChecks
# 476     Account-123456789     anderson.net  ListReadinessChecks
# 816     Account-123456789     anderson.net  ListReadinessChecks
#
#      sourceIPAddress                                          userAgent  \
# 315  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 314     23.19.39.232  Opera/8.23.(X11; Linux i686; da-DK) Presto/2.9...
# 318   156.198.140.30  Opera/8.23.(X11; Linux i686; da-DK) Presto/2.9...
# 317  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 321  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 316  200.228.121.182  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
# 544   91.115.171.224  Mozilla/5.0 (iPad; CPU iPad OS 7_1_2 like Mac ...
# 741     72.5.160.159  Mozilla/5.0 (compatible; MSIE 8.0; Windows 98;...
# 476   91.115.171.224  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# 816     72.5.160.159  Mozilla/5.0 (iPad; CPU iPad OS 4_2_1 like Mac ...
#
#     userIdentitytype  apiVersion               userIdentityprincipalId  \
# 315             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 314             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 318             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 317             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 321             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 316             Root         NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 544             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 741             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 476             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 816             Root  1970-07-15  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
#
#                                   userIdentityarn userIdentityaccessKeyId  \
# 315  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 314  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 318  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 317  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 321  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 316  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 544  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
# 741  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
# 476  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
# 816  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AMV0GEBKYXVMOZWRG7PN
#
#     tlsDetailsclientProvidedHostHeader             errorCode  \
# 315                                NaN  UnsupportedOperation
# 314                         hooper.com               success
# 318                         hooper.com               success
# 317                                NaN         MissingAction
# 321                                NaN         MissingAction
# 316                                NaN         MissingAction
# 544                         lester.net               success
# 741                         lester.net               success
# 476                         lester.net               success
# 816                         lester.net               success
#
#                                           errorMessage  anomaly_score  \
# 315  The specified subnet belongs to a different ac...       1.656023
# 314                                                NaN       1.647644
# 318                                                NaN       1.627712
# 317  The input fails to satisfy the constraints spe...       1.588513
# 321  The input fails to satisfy the constraints spe...       1.588513
# 316  The input fails to satisfy the constraints spe...       1.588513
# 544                                                NaN       1.194987
# 741                                                NaN       1.185173
# 476                                                NaN       1.173235
# 816                                                NaN       1.147573
#
#        zscore
# 315  5.165512
# 314  5.130512
# 318  5.047260
# 317  4.883530
# 321  4.883530
# 316  4.883530
# 544  3.239801
# 741  3.198811
# 476  3.148948
# 816  3.041761

# %% [markdown]
# Anomalous events if there are any, based on 4 standard deviations :

# %%
X_val[X_val['zscore']>4]
# Out:
#     userIdentityaccountId      eventSource         eventName  sourceIPAddress  \
# 314     Account-123456789        salas.com  DetachRolePolicy     23.19.39.232
# 315     Account-123456789  lopez-byrd.info  DeleteEverything  200.228.121.182
# 316     Account-123456789  lopez-byrd.info   DescribeSubnets  200.228.121.182
# 317     Account-123456789  lopez-byrd.info   DescribeSubnets  200.228.121.182
# 318     Account-123456789        salas.com  DetachRolePolicy   156.198.140.30
# 321     Account-123456789  lopez-byrd.info   DescribeSubnets  200.228.121.182
#
#                                              userAgent userIdentitytype  \
# 314  Opera/8.23.(X11; Linux i686; da-DK) Presto/2.9...             Root
# 315  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...             Root
# 316  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...             Root
# 317  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...             Root
# 318  Opera/8.23.(X11; Linux i686; da-DK) Presto/2.9...             Root
# 321  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...             Root
#
#     apiVersion               userIdentityprincipalId  \
# 314        NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 315        NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 316        NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 317        NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 318        NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
# 321        NaN  c605fd31-b71e-4385-a9c9-1cfc259fcbe1
#
#                                   userIdentityarn userIdentityaccessKeyId  \
# 314  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 315  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 316  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 317  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 318  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
# 321  arn:aws:8ab33856-b311-4fa8-bab1-2a7fad0ec33d    AZM8CDAQJ8EN63D9DV3H
#
#     tlsDetailsclientProvidedHostHeader             errorCode  \
# 314                         hooper.com               success
# 315                                NaN  UnsupportedOperation
# 316                                NaN         MissingAction
# 317                                NaN         MissingAction
# 318                         hooper.com               success
# 321                                NaN         MissingAction
#
#                                           errorMessage  anomaly_score  \
# 314                                                NaN       1.647644
# 315  The specified subnet belongs to a different ac...       1.656023
# 316  The input fails to satisfy the constraints spe...       1.588513
# 317  The input fails to satisfy the constraints spe...       1.588513
# 318                                                NaN       1.627712
# 321  The input fails to satisfy the constraints spe...       1.588513
#
#        zscore
# 314  5.130512
# 315  5.165512
# 316  4.883530
# 317  4.883530
# 318  5.047260
# 321  4.883530

# %% [markdown]
# ### Conclusion
# Individual models can be trained for different users or roles. Other log types that can be represented in tabular format can also be used to learn the patterns and detect anomalous ones. Because the training is unsupervised, the users do not need to label their dataset. In production, the reconstruction loss should be calculated over a period of time where there are no substantial attacks on the network. Once a mean value for the reconstruction loss is determined, the CloudTrail logs that are two or more standard deviations away from the mean can be marked as anomalies.
# ### References
# https://github.com/AlliedToasters/dfencoder
#
# https://aws.amazon.com/cloudtrail/
