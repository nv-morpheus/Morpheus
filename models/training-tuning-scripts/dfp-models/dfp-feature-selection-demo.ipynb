# %% [markdown]
# # Digital Fingerprinting (DFP) — Feature Selection

# %% [markdown]
# This notebook includes an introduction to DFP, the suggested steps for DFP feature selection, and the code segments demonstrating how each step can be done in practice.<br>
# Note. This notebook uses Azure AD logs as an example but the same process can be applied to any data sources.<br>
# <font color='#C00000'>Disclaimer.</font> The data was generated using the python [faker](https://faker.readthedocs.io/en/master/#) package. If there is any resemblance to real individuals, it is purely coincidental.

# %% [markdown]
# ## Table of Contents
# 1. [The Application of DFP](#1.2)
# 2. [DFP Features In Use - Azure AD Logs](#1.3)
# 3. [DFP Features In Use - DUO Authentication Logs](#1.4)
# 4. [Feature Engineering and Feature Types](#1.5)
# 5. [Steps for Selecting Raw Features](#1.6)<br>
#     - 5.0. [Load Data](#1.6.1)<br>
#     - 5.1. [Data Overview](#1.6.2)<br>
#     - 5.2. [Overall Statistics](#1.6.3)<br>
#         - 5.2.1 [Signs of a bad feature](#1.6.3.1)<br>
# 		- 5.2.2 [Good feature candidates](#1.6.3.5)<br>
# 	- 5.3. [Per-entity Statistics](#1.6.4)<br>
# 		- 5.3.1 [Good feature candidates](#1.6.4.1) <br>
# 	- 5.4. [Feature Correlation](#1.6.5)<br>
# 		- 5.4.1 [Pearson Correlation Coefficients - Numerical Feature Correlation](#1.6.5.1)<br>
# 		- 5.4.2 [Cramer's V - Categorical Feature Correlation](#1.6.5.2)<br>
# 	- 5.5. [Review with Security Experts](1.6.6)<br>
# 6. [Ideas on Derived Features](#1.7)
# 7. [Conclusion](#1.8)

# %% [markdown]
# ## 1. The Application of DFP <a class="anchor" id="1.2"></a>
# - DFP is a general pipeline that can ingest various data sources to do behavioral anomaly detection
# - POC was done on <font color='#76B900'>Azure AD logs</font> and <font color='#76B900'>DUO authentication logs</font>, but the application of DFP can easily be expanded to other data sources
# - The key to applying DFP to a new data source is through the process of <font color='#76B900'>feature selection</font>
#     - DFP supports all types of features (numerical/categorical/binary)
#     - Any data source can be fed into DFP after some preprocessing to get a feature vector per log/data point
# - Note that DFP builds targeted model for each entity (user/service/machine… etc.), so it would work best if the chosen data source has a field that uniquely identify the entity we’re trying to model

# %% [markdown]
# ## 2. DFP Features In Use - Azure AD Logs <a class="anchor" id="1.3"></a>
# **<font color='#76B900'>1. </font>appDisplayName**: e.g., Windows sign in, MS Teams, Office 365<br>
# **<font color='#76B900'>2. </font>clientAppUsed**: e.g., IMAP4, Browser<br>
# **<font color='#76B900'>3. </font>deviceDetail.displayName**: e.g., username-LT<br>
# **<font color='#76B900'>4. </font>deviceDetail.browser**: e.g., EDGE 98.0.xyz, Chrome 98.0.xyz<br>
# **<font color='#76B900'>5. </font>deviceDetail.operatingSystem**: e.g., Linux, IOS 15, Windows 10<br>
# **<font color='#76B900'>6. </font>statusfailureReason**: e.g., external security challenge not satisfied, error validating credentials<br>
# **<font color='#76B900'>7. </font>riskEventTypesv2**: AzureADThreatIntel, unfamiliarFeatures<br>
# **<font color='#76B900'>8. </font>location.countryOrRegion**: country or region name<br>
# **<font color='#76B900'>9. </font>location.city**: city name<br>
#
# <ins>Derived features</ins>:<br>
# **<font color='#76B900'>10. </font>Log count**: tracks the number of logs generated by a user within that day (increments with every log)<br>
# **<font color='#76B900'>11. </font>Location increment**: increments every time we observe a new city (location.city) in a user’s logs within that day<br>
# **<font color='#76B900'>12. </font>App increment**: increments every time we observe a new app (appDisplayName) in a user’s logs within that day<br>

# %% [markdown]
# ## 3. DFP Features In Use - DUO Authentication Logs <a class="anchor" id="1.4"></a>
# **<font color='#76B900'>1. </font>auth_device.name**: phone number<br>
# **<font color='#76B900'>2. </font>access_device.browser**: e.g., Edge, Chrome, Chrome Mobile<br>
# **<font color='#76B900'>3. </font>access_device.os**: e.g., Android, Windows<br>
# **<font color='#76B900'>4. </font>result**: SUCCESS or FAILURE <br>
# **<font color='#76B900'>5. </font>reason**: reason for the results, e.g., User Cancelled, User Approved, User Mistake, No Response<br>
# **<font color='#76B900'>6. </font>access_device.location.city**: city name<br>
#
# <ins>Derived features</ins>:<br>
# **<font color='#76B900'>7. </font>Log count**: tracks the number of logs generated by a user within that day (increments with every log)<br>
# **<font color='#76B900'>8. </font>Location increment**: increments every time we observe a new city (location.city) in a user’s logs within that day<br>

# %% [markdown]
# ## 4. Feature Engineering and Feature Types <a class="anchor" id="1.5"></a>
# - Feature engineering is key to every successful machine learning application
#     - The more <font color='#76B900'>relevant</font> the features are to the problem being solved the better
#     - <font color='#76B900'>Excluding redundant fields</font> in the raw data helps the model concentrate on key information
# - The different feature types:<br>
#     **<font color='#76B900'>1. </font>Raw feature**: raw value from a data field (e.g., operation name)<br>
#     **<font color='#76B900'>2. </font>Derived feature**: processed value from one or more data fields and/or data records<br>
#     - **Single-record extracted feature**: value computed from one or more fields of a single data record<br>
#         E.g.: parse from IPv4 address the /16 CIDR block to get a “subnet” feature<br>
#         E.g.: concatenate first and last name fields into a “name” feature<br>
#     - **Aggregated feature**: value computed across multiple data records over time<br>
#         E.g.: a “log count” feature that counts the number of logs generated by a user within a given day<br>
#         (this is <font color='#76B900'>time-dependent</font> as the count increments with each log throughout the day)<br>
#         <font color='#C00000'>Note. Aggregated features can require significant resource to compute. Use with caution to avoid unnecessary performance penalties.</font>

# %% [markdown]
# ## 5. Steps for Selecting Raw Features <a class="anchor" id="1.6"></a>
# - Each data source provides a unique set of information about cyber activities
#     - There can be a high number of fields while many of them are <font color='#76B900'>unpopulated</font> or <font color='#76B900'>irrelevant</font> to our problem
#     - Data analysis can help us quickly identify good and bad candidates for raw features
# - The following steps are a general guideline on feature selection for custom DFP applications:<br>
#     **<font color='#76B900'>1. </font>Date overview**: scan through all the features to understand what are available<br>
#     **<font color='#76B900'>2. </font>Overall statistics**: collect global statistics for each feature to rule out bad fits<br>
#     **<font color='#76B900'>3. </font>Per-entity statistics**: collect entity-level statistics for each feature to further evaluate their “usefulness”<br>
#     **<font color='#76B900'>4. </font>Feature correlation**: evaluate the correlation between feature candidates to remove redundancy<br>
#     **<font color='#76B900'>5. </font>Review with security experts**: run the feature candidates by security experts to make sure they are meaningful and relevant to the problem being solved<br>

# %% [markdown]
# <img src="steps.png" width="1000"/>

# %%
import json
import pandas as pd
import numpy as np
import scipy.stats as ss

# %% [markdown]
# ### 5.0 Load Data <a class="anchor" id="1.6.1"></a>
# The following steps show how to load a __nested json__ file and flatten it into a pandas dataframe.<br>
# If your data doesn't have nested fields or is in other formats, you can load it by `pd.read_json` or other `pd.read_*` methods.<br>
#
# __Note.__ Make sure you're loading the __entire__ dataset OR a sample as representative as it can be of the entire dataset.<br>
# This is to avoid underestimating the cardinality of each feature by using a small, non-representative sample of the entire dataset.

# %%
json_obj = json.load(open('../../datasets/training-data/azure/azure-ad-logs-sample-training-data.json', 'r'))

# %%
print(f'# rows: {len(json_obj)}\nExample:\n{json.dumps(json_obj[0], indent=2, sort_keys=True)}')
# Out:
# # rows: 3239
# Example:
# {
#   "Level": 4,
#   "callerIpAddress": "44.22.19.201",
#   "category": "NonInteractiveUserSignInLogs",
#   "correlationId": "84ca338d-f4ff-4f34-9f2a-5a6e23f78c0b",
#   "durationMs": 0,
#   "identity": "Thomas Price",
#   "location": "XN",
#   "operationName": "Sign-in activity",
#   "operationVersion": "1.0",
#   "properties": {
#     "appDisplayName": "Adobe Identity Management",
#     "appId": "9a7e67c7-6f05-42a3-b226-97c7ec3e9696",
#     "appServicePrincipalId": null,
#     "appliedConditionalAccessPolicies": [],
#     "authenticationContextClassReferences": [],
#     "authenticationDetails": [],
#     "authenticationProcessingDetails": [],
#     "authenticationProtocol": "none",
#     "authenticationRequirement": "singleFactorAuthentication",
#     "authenticationRequirementPolicies": [],
#     "autonomousSystemNumber": 230297,
#     "clientAppUsed": "Mobile Apps and Desktop clients",
#     "clientCredentialType": "none",
#     "conditionalAccessStatus": "failure",
#     "correlationId": "bf37c95d-08e3-4342-b83f-4827b020e5b4",
#     "createdDateTime": "2022-08-01T00:03:56.371532Z",
#     "crossTenantAccessType": "none",
#     "deviceDetail": {
#       "browser": "Edge 118.12158",
#       "deviceId": "0927e60c-8dfa-4ecf-be85-ad63bccf40a1",
#       "displayName": "THOMASPRICE-LT",
#       "operatingSystem": "Windows 10",
#       "trustType": "Hybrid Azure AD joined"
#     },
#     "flaggedForReview": false,
#     "homeTenantId": "d3e5a967-5657-4a42-afcc-6106b6c3c299",
#     "id": "df70b726-7756-4baa-9a7d-5ac965198e00",
#     "incomingTokenType": "primaryRefreshToken",
#     "ipAddress": "44.22.19.201",
#     "isInteractive": false,
#     "isTenantRestricted": false,
#     "location": {
#       "city": "Littlemouth",
#       "countryOrRegion": "XN",
#       "geoCoordinates": {
#         "latitude": 25.4437255,
#         "longitude": -109.530885
#       },
#       "state": "Alexanderfurt"
#     },
#     "networkLocationDetails": [],
#     "originalRequestId": "dce375bd-b82e-494f-98e4-1ad345dda0bf",
#     "privateLinkDetails": {},
#     "processingTimeInMilliseconds": 164,
#     "resourceDisplayName": "Adobe Identity Management Service",
#     "resourceId": "30663ca7-f8a9-43ab-8ca1-7906bdbc1485",
#     "resourceServicePrincipalId": "a6c259e5-7f16-48b2-a9f3-75becd6daa9b",
#     "resourceTenantId": "d3e5a967-5657-4a42-afcc-6106b6c3c299",
#     "riskDetail": "none",
#     "riskEventTypes": [],
#     "riskEventTypes_v2": [],
#     "riskLevelAggregated": "none",
#     "riskLevelDuringSignIn": "none",
#     "riskState": "none",
#     "rngcStatus": 0,
#     "servicePrincipalId": "",
#     "ssoExtensionVersion": "",
#     "status": {
#       "errorCode": 50158,
#       "failureReason": "External security challenge was not satisfied."
#     },
#     "tokenIssuerName": "",
#     "tokenIssuerType": "AzureAD",
#     "uniqueTokenIdentifier": "sRma0NKgsBO3hkJGXjMCmsRgf5phSAdeuQ2CpFyvZiqp9BWu",
#     "userAgent": "Mozilla/5.0 (X11; Linux i686) AppleWebKit/535.2 (KHTML, like Gecko) Chrome/22.0.843.0 Safari/535.2 Edge/118.12158",
#     "userDisplayName": "Thomas Price",
#     "userId": "32109ee2-ee4f-4d11-9c38-2556aec0f2b5",
#     "userPrincipalName": "tprice@domain.com",
#     "userType": "Member"
#   },
#   "resourceId": "/tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/providers/Microsoft.aadiam",
#   "resultDescription": "External security challenge was not satisfied.",
#   "resultSignature": "None",
#   "resultType": "50158",
#   "tenantId": "d3e5a967-5657-4a42-afcc-6106b6c3c299",
#   "time": "2022-08-01T00:03:56.207532Z"
# }

# %%
data = pd.json_normalize(json_obj)

# %% [markdown]
# ### 5.1. Data Overview <a class="anchor" id="1.6.2"></a>
# Scan through the columns and understand what are available.<br>
# - A quick glance over the data helps us identify whether the data source is a good fit for DFP and what options we have on potential features
# - In the POC, DFP works well with the following set of information:
#     - **<span style='background:#76B900;color:white'>WHO</span>** Unique identifier of the entity: e.g., user ID, email address, machine name
#     - **<span style='background:#76B900;color:white'>WHAT</span>** Device involved: e.g., device ID, browser, OS version
#     - **<span style='background:#76B900;color:white'>WHERE</span>** Location of the event: e.g., country, state, city, latitude, longitude
#     - **<span style='background:#76B900;color:white'>WHY</span>** Application used: e.g., app name, resource ID, service principal name
#     - **<span style='background:#76B900;color:white'>WHEN</span>** Time stamp: for temporal analysis
#     - Any features that can provide the above information are good candidates to consider!

# %%
pd.set_option('display.max_columns', None)  # ask pandas to show all the columns

# %%
data
# Out:
#                              time  \
# 0     2022-08-01T00:03:56.207532Z
# 1     2022-08-01T00:19:37.909827Z
# 2     2022-08-01T00:25:38.530749Z
# 3     2022-08-01T00:37:00.149031Z
# 4     2022-08-01T00:44:19.056251Z
# ...                           ...
# 3234  2022-08-29T22:23:15.895201Z
# 3235  2022-08-29T22:37:38.943454Z
# 3236  2022-08-29T22:56:13.322849Z
# 3237  2022-08-29T22:56:55.676126Z
# 3238  2022-08-29T23:35:24.446589Z
#
#                                              resourceId     operationName  \
# 0     /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 1     /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 2     /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 3     /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 4     /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# ...                                                 ...               ...
# 3234  /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 3235  /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 3236  /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 3237  /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
# 3238  /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...  Sign-in activity
#
#      operationVersion                      category  \
# 0                 1.0  NonInteractiveUserSignInLogs
# 1                 1.0                    SignInLogs
# 2                 1.0  NonInteractiveUserSignInLogs
# 3                 1.0  NonInteractiveUserSignInLogs
# 4                 1.0  NonInteractiveUserSignInLogs
# ...               ...                           ...
# 3234              1.0  NonInteractiveUserSignInLogs
# 3235              1.0  NonInteractiveUserSignInLogs
# 3236              1.0  NonInteractiveUserSignInLogs
# 3237              1.0  NonInteractiveUserSignInLogs
# 3238              1.0  NonInteractiveUserSignInLogs
#
#                                   tenantId resultType resultSignature  \
# 0     d3e5a967-5657-4a42-afcc-6106b6c3c299      50158            None
# 1     d3e5a967-5657-4a42-afcc-6106b6c3c299          0            None
# 2     d3e5a967-5657-4a42-afcc-6106b6c3c299          0            None
# 3     d3e5a967-5657-4a42-afcc-6106b6c3c299      50158            None
# 4     d3e5a967-5657-4a42-afcc-6106b6c3c299          0            None
# ...                                    ...        ...             ...
# 3234  d3e5a967-5657-4a42-afcc-6106b6c3c299      50158            None
# 3235  d3e5a967-5657-4a42-afcc-6106b6c3c299          0            None
# 3236  d3e5a967-5657-4a42-afcc-6106b6c3c299          0            None
# 3237  d3e5a967-5657-4a42-afcc-6106b6c3c299          0            None
# 3238  d3e5a967-5657-4a42-afcc-6106b6c3c299          0            None
#
#                                    resultDescription  durationMs  \
# 0     External security challenge was not satisfied.           0
# 1                                                NaN           0
# 2                                                NaN           0
# 3     External security challenge was not satisfied.           0
# 4                                                NaN           0
# ...                                              ...         ...
# 3234  External security challenge was not satisfied.           0
# 3235                                             NaN           0
# 3236                                             NaN           0
# 3237                                             NaN           0
# 3238                                             NaN           0
#
#       callerIpAddress                         correlationId          identity  \
# 0        44.22.19.201  84ca338d-f4ff-4f34-9f2a-5a6e23f78c0b      Thomas Price
# 1      99.116.100.205  7641103c-1db3-4e14-9ebc-6a9555ba02b2        Aaron Cole
# 2      86.154.193.190  ef72b144-8295-493d-8231-c12e755a74d8    Kristen Howell
# 3        42.62.103.34  9901c16e-f768-4891-9b92-f1ab68223893     Joseph Taylor
# 4        42.62.103.34  c25d344f-ea74-4470-94bb-ea652c630dd3     Joseph Taylor
# ...               ...                                   ...               ...
# 3234  147.132.189.119  d83e9693-78d9-4035-bb81-4f7766ea452d  Cassie Fernandez
# 3235     42.62.103.34  c8ff49e3-999e-4e3d-8193-c59fdcaf5805     Joseph Taylor
# 3236     205.33.24.92  10b4d505-2bb4-4556-8406-39dbc1d1e8c8        Aaron Cole
# 3237    13.113.40.157  c8abd3f4-3162-4637-9cfb-7187fd3fa340     Attack Target
# 3238   199.12.127.103  e0feca63-df1c-48f3-8c65-77a7ecc0f417      Jacob Meyers
#
#       Level location                         properties.id  \
# 0         4       XN  df70b726-7756-4baa-9a7d-5ac965198e00
# 1         4       XD  c98bb980-53fe-43a8-afd2-72b917706b00
# 2         4       XR  4ef53074-987d-44ae-a8dd-b6e418929900
# 3         4       XF  7f19788f-2e61-49ad-9601-4fe6e5b87200
# 4         4       XF  20f677f0-ddf9-46df-bf50-9e296caa9100
# ...     ...      ...                                   ...
# 3234      4       XR  3252cc26-bd51-4e86-91d8-5aec768e6900
# 3235      4       XF  86ec8f81-b065-45d1-84e2-abcf1c788600
# 3236      4       XD  ada0cd79-9550-4249-a9fe-bc578c978c00
# 3237      4       XR  05126ca7-c65f-4544-8acb-9d5046044200
# 3238      4       XG  72a91770-778f-4a68-a911-ad08a1b56100
#
#        properties.createdDateTime properties.userDisplayName  \
# 0     2022-08-01T00:03:56.371532Z               Thomas Price
# 1     2022-08-01T00:19:38.009827Z                 Aaron Cole
# 2     2022-08-01T00:25:38.621749Z             Kristen Howell
# 3     2022-08-01T00:37:00.269031Z              Joseph Taylor
# 4     2022-08-01T00:44:19.137251Z              Joseph Taylor
# ...                           ...                        ...
# 3234  2022-08-29T22:23:16.018201Z           Cassie Fernandez
# 3235  2022-08-29T22:37:39.026454Z              Joseph Taylor
# 3236  2022-08-29T22:56:13.389849Z                 Aaron Cole
# 3237  2022-08-29T22:56:55.778126Z              Attack Target
# 3238  2022-08-29T23:35:24.558589Z               Jacob Meyers
#
#      properties.userPrincipalName                     properties.userId  \
# 0               tprice@domain.com  32109ee2-ee4f-4d11-9c38-2556aec0f2b5
# 1                acole@domain.com  5d557969-1645-4ba4-be83-b6fd943659f7
# 2              khowell@domain.com  20e1e3f9-665f-45bd-9984-5e74b526d3b5
# 3              jtaylor@domain.com  af9847eb-c773-41ae-bf94-42747c5e986c
# 4              jtaylor@domain.com  af9847eb-c773-41ae-bf94-42747c5e986c
# ...                           ...                                   ...
# 3234        cfernandez@domain.com  67ef8be6-3f44-4db7-8172-fd6211428c1e
# 3235           jtaylor@domain.com  af9847eb-c773-41ae-bf94-42747c5e986c
# 3236             acole@domain.com  5d557969-1645-4ba4-be83-b6fd943659f7
# 3237      attacktarget@domain.com  d735e84b-dcca-404d-9f7d-700f360f41a6
# 3238           jmeyers@domain.com  c63a67b0-1651-4a8a-9560-cc703cdad5ad
#
#                           properties.appId  properties.appDisplayName  \
# 0     9a7e67c7-6f05-42a3-b226-97c7ec3e9696  Adobe Identity Management
# 1     e47a1d38-5f61-45cd-b1b9-bc92f525c598                    Altoura
# 2     9c5b7fe3-0ad2-4ea6-94e5-9e0001f367e3             Articulate 360
# 3     9c5b7fe3-0ad2-4ea6-94e5-9e0001f367e3             Articulate 360
# 4     9a7e67c7-6f05-42a3-b226-97c7ec3e9696  Adobe Identity Management
# ...                                    ...                        ...
# 3234  79510a8f-6421-4348-a2ea-bcc2b02485c1           Cisco AnyConnect
# 3235  2eae4ad1-8cae-48fe-b718-76bd66e2fc7f                    Bipsync
# 3236  cb9ad245-0b24-4c75-ba23-398500baf7a8                  FileCloud
# 3237  9a7e67c7-6f05-42a3-b226-97c7ec3e9696  Adobe Identity Management
# 3238  9c5b7fe3-0ad2-4ea6-94e5-9e0001f367e3             Articulate 360
#
#      properties.ipAddress  properties.status.errorCode  \
# 0            44.22.19.201                        50158
# 1          99.116.100.205                            0
# 2          86.154.193.190                            0
# 3            42.62.103.34                        50158
# 4            42.62.103.34                            0
# ...                   ...                          ...
# 3234      147.132.189.119                        50158
# 3235         42.62.103.34                            0
# 3236         205.33.24.92                            0
# 3237        13.113.40.157                            0
# 3238       199.12.127.103                            0
#
#                      properties.status.failureReason  \
# 0     External security challenge was not satisfied.
# 1                                                NaN
# 2                                                NaN
# 3     External security challenge was not satisfied.
# 4                                                NaN
# ...                                              ...
# 3234  External security challenge was not satisfied.
# 3235                                             NaN
# 3236                                             NaN
# 3237                                             NaN
# 3238                                             NaN
#
#              properties.clientAppUsed  \
# 0     Mobile Apps and Desktop clients
# 1                             Browser
# 2     Mobile Apps and Desktop clients
# 3     Mobile Apps and Desktop clients
# 4     Mobile Apps and Desktop clients
# ...                               ...
# 3234  Mobile Apps and Desktop clients
# 3235  Mobile Apps and Desktop clients
# 3236                          Browser
# 3237  Mobile Apps and Desktop clients
# 3238  Mobile Apps and Desktop clients
#
#                                    properties.userAgent  \
# 0     Mozilla/5.0 (X11; Linux i686) AppleWebKit/535....
# 1     Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit...
# 2     Mozilla/5.0 (X11; Linux i686) AppleWebKit/533....
# 3     Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac ...
# 4     Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac ...
# ...                                                 ...
# 3234  Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac ...
# 3235  Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac ...
# 3236                                                NaN
# 3237  Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac ...
# 3238  Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac ...
#
#           properties.deviceDetail.deviceId  \
# 0     0927e60c-8dfa-4ecf-be85-ad63bccf40a1
# 1
# 2     6ea76864-5f18-47dd-adb9-2b1dfcbfc425
# 3     76b96bd3-e5d7-49ee-b195-bf363facdb3d
# 4     76b96bd3-e5d7-49ee-b195-bf363facdb3d
# ...                                    ...
# 3234  bf67c857-685a-4457-89c4-db2afa581bd2
# 3235  76b96bd3-e5d7-49ee-b195-bf363facdb3d
# 3236
# 3237  a44625dc-6f81-449a-9799-8005f7209b42
# 3238  68cb982e-f215-496c-89bb-cc07716ff474
#
#      properties.deviceDetail.displayName  \
# 0                         THOMASPRICE-LT
# 1                                    NaN
# 2                       KRISTENHOWELL-LT
# 3                        JOSEPHTAYLOR-LT
# 4                        JOSEPHTAYLOR-LT
# ...                                  ...
# 3234                  CASSIEFERNANDEZ-LT
# 3235                     JOSEPHTAYLOR-LT
# 3236                                 NaN
# 3237                     ATTACKTARGET-LT
# 3238                      JACOBMEYERS-LT
#
#      properties.deviceDetail.operatingSystem properties.deviceDetail.browser  \
# 0                                 Windows 10                  Edge 118.12158
# 1                                 Windows 10                  Edge 105.19198
# 2                                 Windows 10                   Edge 40.11325
# 3                                 Windows 10                   Edge 99.14477
# 4                                 Windows 10                   Edge 99.14477
# ...                                      ...                             ...
# 3234                              Windows 10                   Edge 99.14477
# 3235                              Windows 10                   Edge 99.14477
# 3236                                 Windows            Rich Client 4.35.1.0
# 3237                              Windows 10                   Edge 99.14477
# 3238                              Windows 10                   Edge 99.14477
#
#      properties.deviceDetail.trustType properties.location.city  \
# 0               Hybrid Azure AD joined              Littlemouth
# 1                                  NaN              Carrollstad
# 2                      Azure AD joined          Port Denisetown
# 3                      Azure AD joined              Jessicafurt
# 4                      Azure AD joined              Jessicafurt
# ...                                ...                      ...
# 3234            Hybrid Azure AD joined          Port Denisetown
# 3235                   Azure AD joined              Jessicafurt
# 3236                               NaN             Kristinmouth
# 3237               Azure AD registered                Smithfort
# 3238               Azure AD registered              Port Nathan
#
#      properties.location.state properties.location.countryOrRegion  \
# 0                Alexanderfurt                                  XN
# 1                   Norrisbury                                  XD
# 2                     Smithton                                  XR
# 3                    Smithbury                                  XF
# 4                    Smithbury                                  XF
# ...                        ...                                 ...
# 3234                  Smithton                                  XR
# 3235                 Smithbury                                  XF
# 3236                Norrisbury                                  XD
# 3237                 Smithfort                                  XR
# 3238               Newmanville                                  XG
#
#       properties.location.geoCoordinates.latitude  \
# 0                                       25.443725
# 1                                      -38.854047
# 2                                        3.551896
# 3                                       17.508239
# 4                                       17.508239
# ...                                           ...
# 3234                                     3.551896
# 3235                                    17.508239
# 3236                                    26.278784
# 3237                                     3.756410
# 3238                                    23.244641
#
#       properties.location.geoCoordinates.longitude  \
# 0                                      -109.530885
# 1                                       -17.674718
# 2                                       131.871582
# 3                                      -115.304215
# 4                                      -115.304215
# ...                                            ...
# 3234                                    131.871582
# 3235                                   -115.304215
# 3236                                    -92.042573
# 3237                                   -121.574606
# 3238                                   -113.392021
#
#                   properties.correlationId properties.conditionalAccessStatus  \
# 0     bf37c95d-08e3-4342-b83f-4827b020e5b4                            failure
# 1     690fb113-a50a-46bc-b5ca-90b2c6988d8a                            success
# 2     106735ee-529f-4d3e-a513-557fac957792                            success
# 3     58556cc8-a955-4756-a85b-1f1bfd847881                            failure
# 4     a8685bf7-ee79-4bdc-b8f0-68ccaad1026c                            success
# ...                                    ...                                ...
# 3234  2323aef7-8894-45e5-aaf6-99bc8bc2b249                            failure
# 3235  3c754d1e-33de-421b-8f6f-ea693b4d8fbb                            success
# 3236  dd2c7972-f095-4c78-bb86-5cb43d99a562                            success
# 3237  a33f73ab-6941-46d7-87a9-995cc9750d41                            success
# 3238  a1d29d38-1bf6-449f-9eaa-e7f9ecb24e53                            success
#
#      properties.appliedConditionalAccessPolicies  \
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4                                             []
# ...                                          ...
# 3234                                          []
# 3235                                          []
# 3236                                          []
# 3237                                          []
# 3238                                          []
#
#      properties.authenticationContextClassReferences  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# ...                                              ...
# 3234                                              []
# 3235                                              []
# 3236                                              []
# 3237                                              []
# 3238                                              []
#
#               properties.originalRequestId  properties.isInteractive  \
# 0     dce375bd-b82e-494f-98e4-1ad345dda0bf                     False
# 1     84920ffc-d938-4eb7-97ac-3f2769d09bba                      True
# 2     f2b94018-fbfd-4349-9243-96169a0e79bf                     False
# 3     afe3b133-af74-4023-9ecc-473d415fe2a0                     False
# 4     8f8b7fc8-c76f-4d21-b481-90dcee28c1de                     False
# ...                                    ...                       ...
# 3234  6a7e00ad-14c2-4c26-a00d-bc33a75e88d0                     False
# 3235  3b82a0a7-f88a-4156-9f87-831da11ed0ab                     False
# 3236  c89fe99a-088b-4a21-8eb2-0bb46b111d9d                     False
# 3237  786fcb98-1251-45f8-a208-f0df74c50fd3                     False
# 3238  fc18b110-daad-4d49-8b77-340e4f802bd7                     False
#
#      properties.tokenIssuerName properties.tokenIssuerType  \
# 0                                                  AzureAD
# 1                                                  AzureAD
# 2                                                  AzureAD
# 3                                                  AzureAD
# 4                                                  AzureAD
# ...                         ...                        ...
# 3234                                               AzureAD
# 3235                                               AzureAD
# 3236                                               AzureAD
# 3237                                               AzureAD
# 3238                                               AzureAD
#
#      properties.authenticationProcessingDetails  \
# 0                                            []
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
# ...                                         ...
# 3234                                         []
# 3235                                         []
# 3236                                         []
# 3237                                         []
# 3238                                         []
#
#      properties.networkLocationDetails properties.clientCredentialType  \
# 0                                   []                            none
# 1                                   []                            none
# 2                                   []                            none
# 3                                   []                            none
# 4                                   []                            none
# ...                                ...                             ...
# 3234                                []                            none
# 3235                                []                            none
# 3236                                []                            none
# 3237                                []                            none
# 3238                                []                            none
#
#       properties.processingTimeInMilliseconds properties.riskDetail  \
# 0                                         164                  none
# 1                                         100                  none
# 2                                          91                  none
# 3                                         120                  none
# 4                                          81                  none
# ...                                       ...                   ...
# 3234                                      123                  none
# 3235                                       83                  none
# 3236                                       67                  none
# 3237                                      102                  none
# 3238                                      112                  none
#
#      properties.riskLevelAggregated properties.riskLevelDuringSignIn  \
# 0                              none                             none
# 1                              none                             none
# 2                              none                             none
# 3                              none                             none
# 4                              none                             none
# ...                             ...                              ...
# 3234                           none                             none
# 3235                           none                             none
# 3236                           none                             none
# 3237                           none                             none
# 3238                           none                             none
#
#      properties.riskState properties.riskEventTypes  \
# 0                    none                        []
# 1                    none                        []
# 2                    none                        []
# 3                    none                        []
# 4                    none                        []
# ...                   ...                       ...
# 3234                 none                        []
# 3235                 none                        []
# 3236                 none                        []
# 3237                 none                        []
# 3238                 none                        []
#
#      properties.riskEventTypes_v2     properties.resourceDisplayName  \
# 0                              []  Adobe Identity Management Service
# 1                              []                     Altoura Online
# 2                              []              Articulate 360 Online
# 3                              []              Articulate 360 Online
# 4                              []  Adobe Identity Management Service
# ...                           ...                                ...
# 3234                           []            Cisco AnyConnect Online
# 3235                           []                    Bipsync Service
# 3236                           []                  FileCloud Service
# 3237                           []  Adobe Identity Management Service
# 3238                           []              Articulate 360 Online
#
#                      properties.resourceId  \
# 0     30663ca7-f8a9-43ab-8ca1-7906bdbc1485
# 1     f0630e90-b752-4960-bfb9-a0794fc34930
# 2     5e244d4f-26b9-4ef2-a497-f0c533628ee1
# 3     5e244d4f-26b9-4ef2-a497-f0c533628ee1
# 4     2c3383ff-432a-49ee-bb8b-8699a7d0416f
# ...                                    ...
# 3234  5d5b8d28-6a28-472e-b837-a4094e466965
# 3235  40a5d724-be1a-443b-8964-2d2e99910144
# 3236  120f310e-002d-4cf0-803a-8e3f1188c691
# 3237  30663ca7-f8a9-43ab-8ca1-7906bdbc1485
# 3238  436260d5-3791-4aea-a4da-aa698ec35f2f
#
#                properties.resourceTenantId  \
# 0     d3e5a967-5657-4a42-afcc-6106b6c3c299
# 1     d3e5a967-5657-4a42-afcc-6106b6c3c299
# 2     d3e5a967-5657-4a42-afcc-6106b6c3c299
# 3     d3e5a967-5657-4a42-afcc-6106b6c3c299
# 4     d3e5a967-5657-4a42-afcc-6106b6c3c299
# ...                                    ...
# 3234  d3e5a967-5657-4a42-afcc-6106b6c3c299
# 3235  d3e5a967-5657-4a42-afcc-6106b6c3c299
# 3236  d3e5a967-5657-4a42-afcc-6106b6c3c299
# 3237  d3e5a967-5657-4a42-afcc-6106b6c3c299
# 3238  d3e5a967-5657-4a42-afcc-6106b6c3c299
#
#                    properties.homeTenantId properties.authenticationDetails  \
# 0     d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 1     d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 2     d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 3     d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 4     d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# ...                                    ...                              ...
# 3234  d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 3235  d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 3236  d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 3237  d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
# 3238  d3e5a967-5657-4a42-afcc-6106b6c3c299                               []
#
#      properties.authenticationRequirementPolicies  \
# 0                                              []
# 1                                              []
# 2                                              []
# 3                                              []
# 4                                              []
# ...                                           ...
# 3234                                           []
# 3235                                           []
# 3236                                           []
# 3237                                           []
# 3238                                           []
#
#      properties.authenticationRequirement properties.servicePrincipalId  \
# 0              singleFactorAuthentication
# 1              singleFactorAuthentication
# 2              singleFactorAuthentication
# 3              singleFactorAuthentication
# 4              singleFactorAuthentication
# ...                                   ...                           ...
# 3234           singleFactorAuthentication
# 3235           singleFactorAuthentication
# 3236           singleFactorAuthentication
# 3237           singleFactorAuthentication
# 3238           singleFactorAuthentication
#
#      properties.userType  properties.flaggedForReview  \
# 0                 Member                        False
# 1                 Member                        False
# 2                 Member                        False
# 3                 Member                        False
# 4                 Member                        False
# ...                  ...                          ...
# 3234              Member                        False
# 3235              Member                        False
# 3236              Member                        False
# 3237              Member                        False
# 3238              Member                        False
#
#       properties.isTenantRestricted  properties.autonomousSystemNumber  \
# 0                             False                             230297
# 1                             False                             214655
# 2                             False                             256668
# 3                             False                             393508
# 4                             False                             393508
# ...                             ...                                ...
# 3234                          False                             256668
# 3235                          False                             393508
# 3236                          False                             214655
# 3237                          False                              34974
# 3238                          False                             282405
#
#      properties.crossTenantAccessType properties.ssoExtensionVersion  \
# 0                                none
# 1                                none
# 2                                none
# 3                                none
# 4                                none
# ...                               ...                            ...
# 3234                             none
# 3235                             none
# 3236                             none
# 3237                             none
# 3238                             none
#
#                       properties.uniqueTokenIdentifier  \
# 0     sRma0NKgsBO3hkJGXjMCmsRgf5phSAdeuQ2CpFyvZiqp9BWu
# 1     JmqXv1yjmpLCVKYQkwoaQn0ibst82O1aYzAfql41BAoBA52Q
# 2     fDViSwd7VgvV1pXGIvJrscgRMoytG09bt259jU5BiY1GqRIZ
# 3     1I6QLAKmwNYcV5FEKrwaPn10Nbxo4FP8BqYL5evsfG9mOo5g
# 4     vjgAV7fm3LZCwDrHJQ7TPcc94vukyhQfpTAEP8i8ra8Jg8CN
# ...                                                ...
# 3234  8KGkjOpLZPLP8EDPmW7kNvd4rLZtyqlbqEBuHnmozdiPYMoS
# 3235  T5pXSDW5yEpayDDfpZpXHoBVHoFYuXxtJS3kKnuK2InhsOZn
# 3236  41bWMZvKD7wzmAhXxWOsYsRlmP2b1UA4kksFPP4ts2zHjEwu
# 3237  Vt6Ua2rvFtjHPoAoeuzIxNGe5ikYE472MrABYhK8yvYZmLex
# 3238  YRFUGIOxMAnF0Nl2jG8ULcWNioyQIhAei3EvDKj053OGpK7f
#
#      properties.incomingTokenType properties.authenticationProtocol  \
# 0             primaryRefreshToken                              none
# 1                            none                              none
# 2             primaryRefreshToken                              none
# 3             primaryRefreshToken                              none
# 4             primaryRefreshToken                              none
# ...                           ...                               ...
# 3234          primaryRefreshToken                              none
# 3235          primaryRefreshToken                              none
# 3236          primaryRefreshToken                              none
# 3237          primaryRefreshToken                              none
# 3238          primaryRefreshToken                              none
#
#      properties.appServicePrincipalId properties.resourceServicePrincipalId  \
# 0                                None  a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 1                                None  1f37c851-4be4-455b-928a-fbde7845a68a
# 2                                None  36673087-318c-4304-8804-602d45a6f290
# 3                                None  36673087-318c-4304-8804-602d45a6f290
# 4                                None  35efb8e5-3b35-4a86-b7ce-660b69bfa773
# ...                               ...                                   ...
# 3234                             None  15655e1f-5005-4c53-b3c0-c4a1d1ca5e9e
# 3235                             None  8678b6d2-0d07-4480-b90d-d1a18a815502
# 3236                             None  64fdf9a3-2711-4206-8c5a-100403727b93
# 3237                             None  a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 3238                             None  94b9f3ba-5f4b-4edc-99dc-a420b76960f9
#
#       properties.rngcStatus              properties.status.additionalDetails  \
# 0                       0.0                                              NaN
# 1                       0.0                                              NaN
# 2                       0.0  MFA requirement satisfied by claim in the token
# 3                       0.0                                              NaN
# 4                       0.0  MFA requirement satisfied by claim in the token
# ...                     ...                                              ...
# 3234                    0.0                                              NaN
# 3235                    0.0  MFA requirement satisfied by claim in the token
# 3236                    0.0                                              NaN
# 3237                    0.0                                              NaN
# 3238                    0.0                                              NaN
#
#      properties.deviceDetail.isCompliant properties.deviceDetail.isManaged  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                   True                              True
# 3                                   True                              True
# 4                                   True                              True
# ...                                  ...                               ...
# 3234                                 NaN                               NaN
# 3235                                True                              True
# 3236                                 NaN                               NaN
# 3237                                 NaN                               NaN
# 3238                                 NaN                               NaN
#
#      properties.ipAddressFromResourceProvider properties.alternateSignInName  \
# 0                                         NaN                            NaN
# 1                                         NaN                            NaN
# 2                                         NaN                            NaN
# 3                                         NaN                            NaN
# 4                                         NaN                            NaN
# ...                                       ...                            ...
# 3234                                      NaN                            NaN
# 3235                                      NaN                            NaN
# 3236                                      NaN                            NaN
# 3237                                      NaN                            NaN
# 3238                                      NaN                            NaN
#
#      properties.signInIdentifier
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3234                         NaN
# 3235                         NaN
# 3236                         NaN
# 3237                         NaN
# 3238                         NaN
#
# [3239 rows x 81 columns]

# %% [markdown]
# Note that it's important to make sure there is a field that **uniquely identifies** each entity you wish to monitor with DFP.<br>
# E.g. `properties.userPrincipalName` for Azure AD.

# %% [markdown]
# ### 5.2. Overall Statistics <a class="anchor" id="1.6.3"></a>
# Collect global statistics for each feature to rule out bad fits.
#
# - Interesting stats to collect over the entire dataset for each feature:
#     - Unique value count (cardinality)
#     - Percentage of missing values or “null”
#     - Distribution of the unique values

# %%
def json_dumps_keep_null(obj):
    """A wrapper around jsonn.dumps to keep `null` from converted to a string `'null'`."""
    if type(obj) != list and pd.isnull(obj):
        return obj
    return json.dumps(obj)

def collect_overall_stats(data, n_example=3):
    """Take the data and return a dataframe that summarizes the data into stats and example values for each column."""
    overall_stats = []
    total_row_count = len(data)
    for col in data.columns:
        try:
            uniq_values = data[col].unique()
        except:
            # unique() will throw an error if the values in the column are not hashable
            # dump into strings if so
            uniq_values = data[col].apply(json_dumps_keep_null).unique()

        null_ratio = round(data[col].isnull().sum() / total_row_count, 4) # round the numbers to be more readable
        
        # Collect `n_example` examples for each column to include in the result dataframe (non-null values only)
        examples = []
        for val in uniq_values:
            if pd.isnull(val):
                continue
                
            examples.append(val)
            
            if len(examples) >= n_example:
                break
                
        # Pad sentinel values for columns with less than `n_example` unique values
        while len(examples) < n_example:
            examples.append('(empty)')

        overall_stats.append(
            [col, type(data[col][0]).__name__, len(uniq_values), len(uniq_values)/total_row_count, null_ratio, *examples]
        )
        
    result = pd.DataFrame(
        overall_stats, 
        columns=[
            'field', 
            'type', 
            'cardinality', 
            'uniq_ratio', 
            'null_ratio', 
            *[f'example{i+1}' for i in range(n_example)],
        ]
    )
    return result

# %%
pd.set_option('display.max_rows', 200) # ask pandas to display more rows

# %%
overall_stats = collect_overall_stats(data).sort_values(['null_ratio', 'cardinality'], ascending=[True, False]).reset_index(drop=True)

# %%
overall_stats
# Out:
#                                               field      type  cardinality  \
# 0                                              time       str         3239
# 1                        properties.createdDateTime       str         3239
# 2                          properties.correlationId       str         3239
# 3                      properties.originalRequestId       str         3239
# 4                  properties.uniqueTokenIdentifier       str         3239
# 5                                     properties.id       str         3233
# 6                                     correlationId       str         3146
# 7           properties.processingTimeInMilliseconds     int64          307
# 8                                  properties.appId       str           78
# 9                         properties.appDisplayName       str           77
# 10                                  callerIpAddress       str           42
# 11                             properties.ipAddress       str           42
# 12     properties.location.geoCoordinates.longitude   float64           41
# 13      properties.location.geoCoordinates.latitude   float64           40
# 14                 properties.deviceDetail.deviceId       str           36
# 15                         properties.location.city       str           34
# 16                properties.autonomousSystemNumber     int64           27
# 17                                         identity       str           20
# 18                       properties.userDisplayName       str           20
# 19                     properties.userPrincipalName       str           20
# 20                                properties.userId       str           20
# 21                                       resultType       str           16
# 22                      properties.status.errorCode     int64           16
# 23                        properties.location.state       str           16
# 24                                         location       str           11
# 25              properties.location.countryOrRegion       str           11
# 26          properties.deviceDetail.operatingSystem       str            7
# 27               properties.conditionalAccessStatus       str            3
# 28                                         category       str            2
# 29                         properties.isInteractive     bool_            2
# 30     properties.authenticationRequirementPolicies      list            2
# 31             properties.authenticationRequirement       str            2
# 32                     properties.incomingTokenType       str            2
# 33                                       resourceId       str            1
# 34                                    operationName       str            1
# 35                                 operationVersion       str            1
# 36                                         tenantId       str            1
# 37                                  resultSignature       str            1
# 38                                       durationMs     int64            1
# 39                                            Level     int64            1
# 40      properties.appliedConditionalAccessPolicies      list            1
# 41  properties.authenticationContextClassReferences      list            1
# 42                       properties.tokenIssuerName       str            1
# 43                       properties.tokenIssuerType       str            1
# 44       properties.authenticationProcessingDetails      list            1
# 45                properties.networkLocationDetails      list            1
# 46                            properties.riskDetail       str            1
# 47                   properties.riskLevelAggregated       str            1
# 48                 properties.riskLevelDuringSignIn       str            1
# 49                             properties.riskState       str            1
# 50                        properties.riskEventTypes      list            1
# 51                     properties.riskEventTypes_v2      list            1
# 52                      properties.resourceTenantId       str            1
# 53                          properties.homeTenantId       str            1
# 54                 properties.authenticationDetails      list            1
# 55                    properties.servicePrincipalId       str            1
# 56                      properties.flaggedForReview     bool_            1
# 57                    properties.isTenantRestricted     bool_            1
# 58                 properties.crossTenantAccessType       str            1
# 59                   properties.ssoExtensionVersion       str            1
# 60                properties.authenticationProtocol       str            1
# 61                            properties.resourceId       str           83
# 62                         properties.clientAppUsed       str            3
# 63                              properties.userType       str            2
# 64                   properties.resourceDisplayName       str           87
# 65            properties.resourceServicePrincipalId       str           60
# 66                  properties.deviceDetail.browser       str           41
# 67                  properties.clientCredentialType       str            2
# 68                            properties.rngcStatus   float64            2
# 69                             properties.userAgent       str           22
# 70              properties.deviceDetail.displayName       str           19
# 71                properties.deviceDetail.trustType       str            4
# 72                                resultDescription       str           13
# 73                  properties.status.failureReason       str           13
# 74                properties.deviceDetail.isManaged     float            2
# 75              properties.deviceDetail.isCompliant     float            2
# 76              properties.status.additionalDetails     float            5
# 77         properties.ipAddressFromResourceProvider     float           15
# 78                   properties.alternateSignInName     float            5
# 79                      properties.signInIdentifier     float            5
# 80                 properties.appServicePrincipalId  NoneType            1
#
#     uniq_ratio  null_ratio                                           example1  \
# 0     1.000000      0.0000                        2022-08-01T00:03:56.207532Z
# 1     1.000000      0.0000                        2022-08-01T00:03:56.371532Z
# 2     1.000000      0.0000               bf37c95d-08e3-4342-b83f-4827b020e5b4
# 3     1.000000      0.0000               dce375bd-b82e-494f-98e4-1ad345dda0bf
# 4     1.000000      0.0000   sRma0NKgsBO3hkJGXjMCmsRgf5phSAdeuQ2CpFyvZiqp9BWu
# 5     0.998148      0.0000               df70b726-7756-4baa-9a7d-5ac965198e00
# 6     0.971287      0.0000               84ca338d-f4ff-4f34-9f2a-5a6e23f78c0b
# 7     0.094782      0.0000                                                164
# 8     0.024082      0.0000               9a7e67c7-6f05-42a3-b226-97c7ec3e9696
# 9     0.023773      0.0000                          Adobe Identity Management
# 10    0.012967      0.0000                                       44.22.19.201
# 11    0.012967      0.0000                                       44.22.19.201
# 12    0.012658      0.0000                                        -109.530885
# 13    0.012349      0.0000                                          25.443725
# 14    0.011115      0.0000               0927e60c-8dfa-4ecf-be85-ad63bccf40a1
# 15    0.010497      0.0000                                        Littlemouth
# 16    0.008336      0.0000                                             230297
# 17    0.006175      0.0000                                       Thomas Price
# 18    0.006175      0.0000                                       Thomas Price
# 19    0.006175      0.0000                                  tprice@domain.com
# 20    0.006175      0.0000               32109ee2-ee4f-4d11-9c38-2556aec0f2b5
# 21    0.004940      0.0000                                              50158
# 22    0.004940      0.0000                                              50158
# 23    0.004940      0.0000                                      Alexanderfurt
# 24    0.003396      0.0000                                                 XN
# 25    0.003396      0.0000                                                 XN
# 26    0.002161      0.0000                                         Windows 10
# 27    0.000926      0.0000                                            failure
# 28    0.000617      0.0000                       NonInteractiveUserSignInLogs
# 29    0.000617      0.0000                                              False
# 30    0.000617      0.0000                                                 []
# 31    0.000617      0.0000                         singleFactorAuthentication
# 32    0.000617      0.0000                                primaryRefreshToken
# 33    0.000309      0.0000  /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...
# 34    0.000309      0.0000                                   Sign-in activity
# 35    0.000309      0.0000                                                1.0
# 36    0.000309      0.0000               d3e5a967-5657-4a42-afcc-6106b6c3c299
# 37    0.000309      0.0000                                               None
# 38    0.000309      0.0000                                                  0
# 39    0.000309      0.0000                                                  4
# 40    0.000309      0.0000                                                 []
# 41    0.000309      0.0000                                                 []
# 42    0.000309      0.0000
# 43    0.000309      0.0000                                            AzureAD
# 44    0.000309      0.0000                                                 []
# 45    0.000309      0.0000                                                 []
# 46    0.000309      0.0000                                               none
# 47    0.000309      0.0000                                               none
# 48    0.000309      0.0000                                               none
# 49    0.000309      0.0000                                               none
# 50    0.000309      0.0000                                                 []
# 51    0.000309      0.0000                                                 []
# 52    0.000309      0.0000               d3e5a967-5657-4a42-afcc-6106b6c3c299
# 53    0.000309      0.0000               d3e5a967-5657-4a42-afcc-6106b6c3c299
# 54    0.000309      0.0000                                                 []
# 55    0.000309      0.0000
# 56    0.000309      0.0000                                              False
# 57    0.000309      0.0000                                              False
# 58    0.000309      0.0000                                               none
# 59    0.000309      0.0000
# 60    0.000309      0.0000                                               none
# 61    0.025625      0.0022               30663ca7-f8a9-43ab-8ca1-7906bdbc1485
# 62    0.000926      0.0028                    Mobile Apps and Desktop clients
# 63    0.000617      0.0028                                             Member
# 64    0.026860      0.0043                  Adobe Identity Management Service
# 65    0.018524      0.1849               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 66    0.012658      0.1911                                     Edge 118.12158
# 67    0.000617      0.2170                                               none
# 68    0.000617      0.2170                                                0.0
# 69    0.006792      0.3359  Mozilla/5.0 (X11; Linux i686) AppleWebKit/535....
# 70    0.005866      0.3381                                     THOMASPRICE-LT
# 71    0.001235      0.3381                             Hybrid Azure AD joined
# 72    0.004014      0.7891     External security challenge was not satisfied.
# 73    0.004014      0.7891     External security challenge was not satisfied.
# 74    0.000617      0.8194                                               True
# 75    0.000617      0.8197                                               True
# 76    0.001544      0.8713    MFA requirement satisfied by claim in the token
# 77    0.004631      0.9373                                     155.96.237.219
# 78    0.001544      0.9904                                 cperry1@domain.com
# 79    0.001544      0.9904                                 cperry1@domain.com
# 80    0.000309      1.0000                                            (empty)
#
#                                              example2  \
# 0                         2022-08-01T00:19:37.909827Z
# 1                         2022-08-01T00:19:38.009827Z
# 2                690fb113-a50a-46bc-b5ca-90b2c6988d8a
# 3                84920ffc-d938-4eb7-97ac-3f2769d09bba
# 4    JmqXv1yjmpLCVKYQkwoaQn0ibst82O1aYzAfql41BAoBA52Q
# 5                c98bb980-53fe-43a8-afd2-72b917706b00
# 6                7641103c-1db3-4e14-9ebc-6a9555ba02b2
# 7                                                 100
# 8                e47a1d38-5f61-45cd-b1b9-bc92f525c598
# 9                                             Altoura
# 10                                     99.116.100.205
# 11                                     99.116.100.205
# 12                                         -17.674718
# 13                                         -38.854047
# 14
# 15                                        Carrollstad
# 16                                             214655
# 17                                         Aaron Cole
# 18                                         Aaron Cole
# 19                                   acole@domain.com
# 20               5d557969-1645-4ba4-be83-b6fd943659f7
# 21                                                  0
# 22                                                  0
# 23                                         Norrisbury
# 24                                                 XD
# 25                                                 XD
# 26                                            Windows
# 27                                            success
# 28                                         SignInLogs
# 29                                               True
# 30  [{"requirementProvider": "request", "detail": ...
# 31                          multiFactorAuthentication
# 32                                               none
# 33                                            (empty)
# 34                                            (empty)
# 35                                            (empty)
# 36                                            (empty)
# 37                                            (empty)
# 38                                            (empty)
# 39                                            (empty)
# 40                                            (empty)
# 41                                            (empty)
# 42                                            (empty)
# 43                                            (empty)
# 44                                            (empty)
# 45                                            (empty)
# 46                                            (empty)
# 47                                            (empty)
# 48                                            (empty)
# 49                                            (empty)
# 50                                            (empty)
# 51                                            (empty)
# 52                                            (empty)
# 53                                            (empty)
# 54                                            (empty)
# 55                                            (empty)
# 56                                            (empty)
# 57                                            (empty)
# 58                                            (empty)
# 59                                            (empty)
# 60                                            (empty)
# 61               f0630e90-b752-4960-bfb9-a0794fc34930
# 62                                            Browser
# 63                                            (empty)
# 64                                     Altoura Online
# 65               1f37c851-4be4-455b-928a-fbde7845a68a
# 66                                     Edge 105.19198
# 67                                            (empty)
# 68                                            (empty)
# 69  Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit...
# 70                                   KRISTENHOWELL-LT
# 71                                    Azure AD joined
# 72                                              Other
# 73                                              Other
# 74                                            (empty)
# 75                                            (empty)
# 76                           MFA required in Azure AD
# 77                                      13.113.40.157
# 78                                  acole1@domain.com
# 79                                  acole1@domain.com
# 80                                            (empty)
#
#                                              example3
# 0                         2022-08-01T00:25:38.530749Z
# 1                         2022-08-01T00:25:38.621749Z
# 2                106735ee-529f-4d3e-a513-557fac957792
# 3                f2b94018-fbfd-4349-9243-96169a0e79bf
# 4    fDViSwd7VgvV1pXGIvJrscgRMoytG09bt259jU5BiY1GqRIZ
# 5                4ef53074-987d-44ae-a8dd-b6e418929900
# 6                ef72b144-8295-493d-8231-c12e755a74d8
# 7                                                  91
# 8                9c5b7fe3-0ad2-4ea6-94e5-9e0001f367e3
# 9                                      Articulate 360
# 10                                     86.154.193.190
# 11                                     86.154.193.190
# 12                                         131.871582
# 13                                           3.551896
# 14               6ea76864-5f18-47dd-adb9-2b1dfcbfc425
# 15                                    Port Denisetown
# 16                                             256668
# 17                                     Kristen Howell
# 18                                     Kristen Howell
# 19                                 khowell@domain.com
# 20               20e1e3f9-665f-45bd-9984-5e74b526d3b5
# 21                                             700084
# 22                                             700084
# 23                                           Smithton
# 24                                                 XR
# 25                                                 XR
# 26                                          Windows10
# 27                                         notApplied
# 28                                            (empty)
# 29                                            (empty)
# 30                                            (empty)
# 31                                            (empty)
# 32                                            (empty)
# 33                                            (empty)
# 34                                            (empty)
# 35                                            (empty)
# 36                                            (empty)
# 37                                            (empty)
# 38                                            (empty)
# 39                                            (empty)
# 40                                            (empty)
# 41                                            (empty)
# 42                                            (empty)
# 43                                            (empty)
# 44                                            (empty)
# 45                                            (empty)
# 46                                            (empty)
# 47                                            (empty)
# 48                                            (empty)
# 49                                            (empty)
# 50                                            (empty)
# 51                                            (empty)
# 52                                            (empty)
# 53                                            (empty)
# 54                                            (empty)
# 55                                            (empty)
# 56                                            (empty)
# 57                                            (empty)
# 58                                            (empty)
# 59                                            (empty)
# 60                                            (empty)
# 61               5e244d4f-26b9-4ef2-a497-f0c533628ee1
# 62                                            (empty)
# 63                                            (empty)
# 64                              Articulate 360 Online
# 65               36673087-318c-4304-8804-602d45a6f290
# 66                                      Edge 40.11325
# 67                                            (empty)
# 68                                            (empty)
# 69  Mozilla/5.0 (X11; Linux i686) AppleWebKit/533....
# 70                                    JOSEPHTAYLOR-LT
# 71                                Azure AD registered
# 72  Fresh auth token is needed. Have the user re-s...
# 73  Fresh auth token is needed. Have the user re-s...
# 74                                            (empty)
# 75                                            (empty)
# 76                          MFA completed in Azure AD
# 77                                       11.5.130.220
# 78                              ksheppard1@domain.com
# 79                              ksheppard1@domain.com
# 80                                            (empty)

# %% [markdown]
# Definition of `null`: NaN in numeric arrays, None or NaN in object arrays, NaT in datetimelike<br>
# Note. Unique count includes null values

# %% [markdown]
# #### 5.2.1 Signs of a bad feature<a class="anchor" id="1.6.3.1"></a>
# #### High Cardinality
# Each row has a unique value (cardinality/(# of all data points) ≅ 1)<br>
# E.g.: Log ID (correlationId) that uniquely identifies each log entry

# %%
overall_stats.loc[overall_stats.uniq_ratio > 0.95]
# Out:
#                               field type  cardinality  uniq_ratio  null_ratio  \
# 0                              time  str         3239    1.000000         0.0
# 1        properties.createdDateTime  str         3239    1.000000         0.0
# 2          properties.correlationId  str         3239    1.000000         0.0
# 3      properties.originalRequestId  str         3239    1.000000         0.0
# 4  properties.uniqueTokenIdentifier  str         3239    1.000000         0.0
# 5                     properties.id  str         3233    0.998148         0.0
# 6                     correlationId  str         3146    0.971287         0.0
#
#                                            example1  \
# 0                       2022-08-01T00:03:56.207532Z
# 1                       2022-08-01T00:03:56.371532Z
# 2              bf37c95d-08e3-4342-b83f-4827b020e5b4
# 3              dce375bd-b82e-494f-98e4-1ad345dda0bf
# 4  sRma0NKgsBO3hkJGXjMCmsRgf5phSAdeuQ2CpFyvZiqp9BWu
# 5              df70b726-7756-4baa-9a7d-5ac965198e00
# 6              84ca338d-f4ff-4f34-9f2a-5a6e23f78c0b
#
#                                            example2  \
# 0                       2022-08-01T00:19:37.909827Z
# 1                       2022-08-01T00:19:38.009827Z
# 2              690fb113-a50a-46bc-b5ca-90b2c6988d8a
# 3              84920ffc-d938-4eb7-97ac-3f2769d09bba
# 4  JmqXv1yjmpLCVKYQkwoaQn0ibst82O1aYzAfql41BAoBA52Q
# 5              c98bb980-53fe-43a8-afd2-72b917706b00
# 6              7641103c-1db3-4e14-9ebc-6a9555ba02b2
#
#                                            example3
# 0                       2022-08-01T00:25:38.530749Z
# 1                       2022-08-01T00:25:38.621749Z
# 2              106735ee-529f-4d3e-a513-557fac957792
# 3              f2b94018-fbfd-4349-9243-96169a0e79bf
# 4  fDViSwd7VgvV1pXGIvJrscgRMoytG09bt259jU5BiY1GqRIZ
# 5              4ef53074-987d-44ae-a8dd-b6e418929900
# 6              ef72b144-8295-493d-8231-c12e755a74d8

# %% [markdown]
# Fields with constantly changing values are not good candidates as a feature as there isn't much predictability.

# %% [markdown]
# #### Low Cardinality
# All rows share the same value ( cardinality ≅ 1 )<br>
# E.g.: tenantId if all logs are coming from the same tenant<br>

# %%
# excluding bool columns, as they'll by default have a low cardinality. Their usefulness needs to be determined by the security context they carry.
overall_stats.loc[(overall_stats.cardinality <= 3) & (overall_stats.type != 'bool')]
# Out:
#                                               field      type  cardinality  \
# 27               properties.conditionalAccessStatus       str            3
# 28                                         category       str            2
# 29                         properties.isInteractive     bool_            2
# 30     properties.authenticationRequirementPolicies      list            2
# 31             properties.authenticationRequirement       str            2
# 32                     properties.incomingTokenType       str            2
# 33                                       resourceId       str            1
# 34                                    operationName       str            1
# 35                                 operationVersion       str            1
# 36                                         tenantId       str            1
# 37                                  resultSignature       str            1
# 38                                       durationMs     int64            1
# 39                                            Level     int64            1
# 40      properties.appliedConditionalAccessPolicies      list            1
# 41  properties.authenticationContextClassReferences      list            1
# 42                       properties.tokenIssuerName       str            1
# 43                       properties.tokenIssuerType       str            1
# 44       properties.authenticationProcessingDetails      list            1
# 45                properties.networkLocationDetails      list            1
# 46                            properties.riskDetail       str            1
# 47                   properties.riskLevelAggregated       str            1
# 48                 properties.riskLevelDuringSignIn       str            1
# 49                             properties.riskState       str            1
# 50                        properties.riskEventTypes      list            1
# 51                     properties.riskEventTypes_v2      list            1
# 52                      properties.resourceTenantId       str            1
# 53                          properties.homeTenantId       str            1
# 54                 properties.authenticationDetails      list            1
# 55                    properties.servicePrincipalId       str            1
# 56                      properties.flaggedForReview     bool_            1
# 57                    properties.isTenantRestricted     bool_            1
# 58                 properties.crossTenantAccessType       str            1
# 59                   properties.ssoExtensionVersion       str            1
# 60                properties.authenticationProtocol       str            1
# 62                         properties.clientAppUsed       str            3
# 63                              properties.userType       str            2
# 67                  properties.clientCredentialType       str            2
# 68                            properties.rngcStatus   float64            2
# 74                properties.deviceDetail.isManaged     float            2
# 75              properties.deviceDetail.isCompliant     float            2
# 80                 properties.appServicePrincipalId  NoneType            1
#
#     uniq_ratio  null_ratio                                           example1  \
# 27    0.000926      0.0000                                            failure
# 28    0.000617      0.0000                       NonInteractiveUserSignInLogs
# 29    0.000617      0.0000                                              False
# 30    0.000617      0.0000                                                 []
# 31    0.000617      0.0000                         singleFactorAuthentication
# 32    0.000617      0.0000                                primaryRefreshToken
# 33    0.000309      0.0000  /tenants/d3e5a967-5657-4a42-afcc-6106b6c3c299/...
# 34    0.000309      0.0000                                   Sign-in activity
# 35    0.000309      0.0000                                                1.0
# 36    0.000309      0.0000               d3e5a967-5657-4a42-afcc-6106b6c3c299
# 37    0.000309      0.0000                                               None
# 38    0.000309      0.0000                                                  0
# 39    0.000309      0.0000                                                  4
# 40    0.000309      0.0000                                                 []
# 41    0.000309      0.0000                                                 []
# 42    0.000309      0.0000
# 43    0.000309      0.0000                                            AzureAD
# 44    0.000309      0.0000                                                 []
# 45    0.000309      0.0000                                                 []
# 46    0.000309      0.0000                                               none
# 47    0.000309      0.0000                                               none
# 48    0.000309      0.0000                                               none
# 49    0.000309      0.0000                                               none
# 50    0.000309      0.0000                                                 []
# 51    0.000309      0.0000                                                 []
# 52    0.000309      0.0000               d3e5a967-5657-4a42-afcc-6106b6c3c299
# 53    0.000309      0.0000               d3e5a967-5657-4a42-afcc-6106b6c3c299
# 54    0.000309      0.0000                                                 []
# 55    0.000309      0.0000
# 56    0.000309      0.0000                                              False
# 57    0.000309      0.0000                                              False
# 58    0.000309      0.0000                                               none
# 59    0.000309      0.0000
# 60    0.000309      0.0000                                               none
# 62    0.000926      0.0028                    Mobile Apps and Desktop clients
# 63    0.000617      0.0028                                             Member
# 67    0.000617      0.2170                                               none
# 68    0.000617      0.2170                                                0.0
# 74    0.000617      0.8194                                               True
# 75    0.000617      0.8197                                               True
# 80    0.000309      1.0000                                            (empty)
#
#                                              example2    example3
# 27                                            success  notApplied
# 28                                         SignInLogs     (empty)
# 29                                               True     (empty)
# 30  [{"requirementProvider": "request", "detail": ...     (empty)
# 31                          multiFactorAuthentication     (empty)
# 32                                               none     (empty)
# 33                                            (empty)     (empty)
# 34                                            (empty)     (empty)
# 35                                            (empty)     (empty)
# 36                                            (empty)     (empty)
# 37                                            (empty)     (empty)
# 38                                            (empty)     (empty)
# 39                                            (empty)     (empty)
# 40                                            (empty)     (empty)
# 41                                            (empty)     (empty)
# 42                                            (empty)     (empty)
# 43                                            (empty)     (empty)
# 44                                            (empty)     (empty)
# 45                                            (empty)     (empty)
# 46                                            (empty)     (empty)
# 47                                            (empty)     (empty)
# 48                                            (empty)     (empty)
# 49                                            (empty)     (empty)
# 50                                            (empty)     (empty)
# 51                                            (empty)     (empty)
# 52                                            (empty)     (empty)
# 53                                            (empty)     (empty)
# 54                                            (empty)     (empty)
# 55                                            (empty)     (empty)
# 56                                            (empty)     (empty)
# 57                                            (empty)     (empty)
# 58                                            (empty)     (empty)
# 59                                            (empty)     (empty)
# 60                                            (empty)     (empty)
# 62                                            Browser     (empty)
# 63                                            (empty)     (empty)
# 67                                            (empty)     (empty)
# 68                                            (empty)     (empty)
# 74                                            (empty)     (empty)
# 75                                            (empty)     (empty)
# 80                                            (empty)     (empty)

# %% [markdown]
# Note that `cardinality` here includes `null` values too, so fields with one possible value + `null` will have 2 as the cardinality.

# %% [markdown]
# #### Mostly Null
# Most values are Null ( (# of  null values)/(# of all data points) ≅ 1)<br>
# Might be a redundant/non-populated field that does not provide much information<br>
# ! Beware that sometimes "None" can be in the string format and bypass the `pd.isnull` check

# %%
overall_stats.loc[overall_stats.null_ratio > 0.9]
# Out:
#                                        field      type  cardinality  \
# 77  properties.ipAddressFromResourceProvider     float           15
# 78            properties.alternateSignInName     float            5
# 79               properties.signInIdentifier     float            5
# 80          properties.appServicePrincipalId  NoneType            1
#
#     uniq_ratio  null_ratio            example1           example2  \
# 77    0.004631      0.9373      155.96.237.219      13.113.40.157
# 78    0.001544      0.9904  cperry1@domain.com  acole1@domain.com
# 79    0.001544      0.9904  cperry1@domain.com  acole1@domain.com
# 80    0.000309      1.0000             (empty)            (empty)
#
#                  example3
# 77           11.5.130.220
# 78  ksheppard1@domain.com
# 79  ksheppard1@domain.com
# 80                (empty)

# %% [markdown]
# #### 5.2.2 Good feature candidates<a class="anchor" id="1.6.3.5"></a>
# The thresholds used here are just for demonstration. They can be tuned to suit your data and your requirements better.

# %%
good_feat_candidate_criteria = (
    (overall_stats.uniq_ratio < 0.95)
    & ~((overall_stats.cardinality <= 3) & (overall_stats.type != 'bool'))
    & (overall_stats.null_ratio < 0.9)
)
feature_candidates = overall_stats.loc[good_feat_candidate_criteria]

# %%
print(f'Number of all columns: {len(overall_stats)}\nPotential feature candidate count: {len(feature_candidates)}')
# Out:
# Number of all columns: 81
# Potential feature candidate count: 30

# %%
feature_candidates
# Out:
#                                            field     type  cardinality  \
# 7        properties.processingTimeInMilliseconds    int64          307
# 8                               properties.appId      str           78
# 9                      properties.appDisplayName      str           77
# 10                               callerIpAddress      str           42
# 11                          properties.ipAddress      str           42
# 12  properties.location.geoCoordinates.longitude  float64           41
# 13   properties.location.geoCoordinates.latitude  float64           40
# 14              properties.deviceDetail.deviceId      str           36
# 15                      properties.location.city      str           34
# 16             properties.autonomousSystemNumber    int64           27
# 17                                      identity      str           20
# 18                    properties.userDisplayName      str           20
# 19                  properties.userPrincipalName      str           20
# 20                             properties.userId      str           20
# 21                                    resultType      str           16
# 22                   properties.status.errorCode    int64           16
# 23                     properties.location.state      str           16
# 24                                      location      str           11
# 25           properties.location.countryOrRegion      str           11
# 26       properties.deviceDetail.operatingSystem      str            7
# 61                         properties.resourceId      str           83
# 64                properties.resourceDisplayName      str           87
# 65         properties.resourceServicePrincipalId      str           60
# 66               properties.deviceDetail.browser      str           41
# 69                          properties.userAgent      str           22
# 70           properties.deviceDetail.displayName      str           19
# 71             properties.deviceDetail.trustType      str            4
# 72                             resultDescription      str           13
# 73               properties.status.failureReason      str           13
# 76           properties.status.additionalDetails    float            5
#
#     uniq_ratio  null_ratio                                           example1  \
# 7     0.094782      0.0000                                                164
# 8     0.024082      0.0000               9a7e67c7-6f05-42a3-b226-97c7ec3e9696
# 9     0.023773      0.0000                          Adobe Identity Management
# 10    0.012967      0.0000                                       44.22.19.201
# 11    0.012967      0.0000                                       44.22.19.201
# 12    0.012658      0.0000                                        -109.530885
# 13    0.012349      0.0000                                          25.443725
# 14    0.011115      0.0000               0927e60c-8dfa-4ecf-be85-ad63bccf40a1
# 15    0.010497      0.0000                                        Littlemouth
# 16    0.008336      0.0000                                             230297
# 17    0.006175      0.0000                                       Thomas Price
# 18    0.006175      0.0000                                       Thomas Price
# 19    0.006175      0.0000                                  tprice@domain.com
# 20    0.006175      0.0000               32109ee2-ee4f-4d11-9c38-2556aec0f2b5
# 21    0.004940      0.0000                                              50158
# 22    0.004940      0.0000                                              50158
# 23    0.004940      0.0000                                      Alexanderfurt
# 24    0.003396      0.0000                                                 XN
# 25    0.003396      0.0000                                                 XN
# 26    0.002161      0.0000                                         Windows 10
# 61    0.025625      0.0022               30663ca7-f8a9-43ab-8ca1-7906bdbc1485
# 64    0.026860      0.0043                  Adobe Identity Management Service
# 65    0.018524      0.1849               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 66    0.012658      0.1911                                     Edge 118.12158
# 69    0.006792      0.3359  Mozilla/5.0 (X11; Linux i686) AppleWebKit/535....
# 70    0.005866      0.3381                                     THOMASPRICE-LT
# 71    0.001235      0.3381                             Hybrid Azure AD joined
# 72    0.004014      0.7891     External security challenge was not satisfied.
# 73    0.004014      0.7891     External security challenge was not satisfied.
# 76    0.001544      0.8713    MFA requirement satisfied by claim in the token
#
#                                              example2  \
# 7                                                 100
# 8                e47a1d38-5f61-45cd-b1b9-bc92f525c598
# 9                                             Altoura
# 10                                     99.116.100.205
# 11                                     99.116.100.205
# 12                                         -17.674718
# 13                                         -38.854047
# 14
# 15                                        Carrollstad
# 16                                             214655
# 17                                         Aaron Cole
# 18                                         Aaron Cole
# 19                                   acole@domain.com
# 20               5d557969-1645-4ba4-be83-b6fd943659f7
# 21                                                  0
# 22                                                  0
# 23                                         Norrisbury
# 24                                                 XD
# 25                                                 XD
# 26                                            Windows
# 61               f0630e90-b752-4960-bfb9-a0794fc34930
# 64                                     Altoura Online
# 65               1f37c851-4be4-455b-928a-fbde7845a68a
# 66                                     Edge 105.19198
# 69  Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit...
# 70                                   KRISTENHOWELL-LT
# 71                                    Azure AD joined
# 72                                              Other
# 73                                              Other
# 76                           MFA required in Azure AD
#
#                                              example3
# 7                                                  91
# 8                9c5b7fe3-0ad2-4ea6-94e5-9e0001f367e3
# 9                                      Articulate 360
# 10                                     86.154.193.190
# 11                                     86.154.193.190
# 12                                         131.871582
# 13                                           3.551896
# 14               6ea76864-5f18-47dd-adb9-2b1dfcbfc425
# 15                                    Port Denisetown
# 16                                             256668
# 17                                     Kristen Howell
# 18                                     Kristen Howell
# 19                                 khowell@domain.com
# 20               20e1e3f9-665f-45bd-9984-5e74b526d3b5
# 21                                             700084
# 22                                             700084
# 23                                           Smithton
# 24                                                 XR
# 25                                                 XR
# 26                                          Windows10
# 61               5e244d4f-26b9-4ef2-a497-f0c533628ee1
# 64                              Articulate 360 Online
# 65               36673087-318c-4304-8804-602d45a6f290
# 66                                      Edge 40.11325
# 69  Mozilla/5.0 (X11; Linux i686) AppleWebKit/533....
# 70                                    JOSEPHTAYLOR-LT
# 71                                Azure AD registered
# 72  Fresh auth token is needed. Have the user re-s...
# 73  Fresh auth token is needed. Have the user re-s...
# 76                          MFA completed in Azure AD

# %% [markdown]
# Now we can double-check if these are good candidates under the per-entity scope.

# %% [markdown]
# ### 5.3. Per-entity Statistics<a class="anchor" id="1.6.4"></a>
# Collect entity-level statistics for each feature to further evaluate their “usefulness”.

# %%
def get_data_with_selected_features(data, features):
    """Return a new dataframe with only the selected features and json dumps the unhashable fields for `nunique` to work."""
    data_candidate_cols = pd.DataFrame()
    for col in features:
        # json dumps the array fields
        try:
            data[col].nunique()
            data_candidate_cols[col] = data[col]
        except:
            data_candidate_cols[col] = data[col].apply(json_dumps_keep_null)
    return data_candidate_cols

def get_entity_feature_cardinality(data, entity_id_field, trainable_user_activity_limit=100):
    """Return a dataframe of the per-entity cardinality (unique count) of each feature, including only the entities with enough activity to be "trainable" by DFP. 
    (DFP doesn't train a model for entities with little activity. Instead, it uses a shared model for the light-traffic entities.)
    """
    kwargs = {col: (col, 'nunique') for col in data.columns if col != entity_id_field}
    kwargs['count'] = (data.columns[0], 'count')
    per_entity_nunique_all = data.groupby(entity_id_field).agg(**kwargs).reset_index()
    
    per_entity_nunique = per_entity_nunique_all.loc[per_entity_nunique_all['count'] > trainable_user_activity_limit]
    return per_entity_nunique

def get_entity_feature_null_ratio(data, entity_id_field, trainable_user_activity_limit=100):
    """Return a dataframe of the per-entity null ratio of each feature, including only the entities with enough activity to be "trainable" by DFP. 
    (DFP doesn't train a model for entities with little activity. Instead, it uses a shared model for the light-traffic entities.)
    """
    data_with_null_eval = data.join(data.isnull(), rsuffix='_isnull')
    kwargs = {f'{col}': (f'{col}_isnull', 'sum') for col in data.columns if col != entity_id_field}
    kwargs['count'] = (data.columns[0], 'count')
    per_entity_null_count_all = data_with_null_eval.groupby(entity_id_field).agg(**kwargs).reset_index()
    per_entity_null_count = per_entity_null_count_all.loc[per_entity_null_count_all['count'] > trainable_user_activity_limit]
    
    # calculate null ratio
    per_entity_null_ratio = pd.DataFrame()
    per_entity_null_ratio[entity_id_field] = per_entity_null_count[entity_id_field]
    for col in per_entity_null_count.columns:
        if col == entity_id_field or col == 'count':
            continue
        per_entity_null_ratio[col] = per_entity_null_count[col] / per_entity_null_count['count']
    
    return per_entity_null_ratio

def get_feature_per_entity_stats(entity_feature_cardinality, entity_feature_null_ratio, entity_id_field):
    """ Given the cardinality and the null ratio of each feature, return a summary dataframe of the per-entity stats for each feature.
    """
    stat_types = ['max', 'med', 'mean', 'min']
    stat_funcs = [max, np.median, np.mean, min]
    
    per_user_feature_dist = []
    for col in entity_feature_cardinality.columns:
        if col == entity_id_field or col == 'count':
            continue

        vals = entity_feature_cardinality[col]
        uniq_ratios = vals / entity_feature_cardinality['count']
        null_ratios = entity_feature_null_ratio[col]
        
        
        per_user_feature_dist.append([
            col,
            # cardinality
            *[func(vals) for func in stat_funcs],
            # unique ratio
            *[func(uniq_ratios) for func in stat_funcs],
            # null ratio
            *[func(null_ratios) for func in stat_funcs],
        ])

    return pd.DataFrame(
        data=per_user_feature_dist, 
        columns=[
            'field', 
            *[f'cardinality_{stat}' for stat in stat_types], 
            *[f'uniq_ratio_{stat}' for stat in stat_types],
            *[f'null_ratio_{stat}' for stat in stat_types],
        ]
    ).sort_values('cardinality_med', ascending=False).reset_index(drop=True)

# %%
data_candidate_cols = get_data_with_selected_features(data, feature_candidates.field)
user_feature_cardinality = get_entity_feature_cardinality(data_candidate_cols, entity_id_field='properties.userPrincipalName')
user_feature_null_ratio = get_entity_feature_null_ratio(data_candidate_cols, entity_id_field='properties.userPrincipalName')
per_entity_stats = get_feature_per_entity_stats(user_feature_cardinality, user_feature_null_ratio, entity_id_field='properties.userPrincipalName')

# %%
per_entity_stats
# Out:
#                                            field  cardinality_max  \
# 0        properties.processingTimeInMilliseconds              144
# 1                          properties.resourceId               51
# 2          properties.resourceServicePrincipalId               39
# 3                 properties.resourceDisplayName               47
# 4                               properties.appId               44
# 5                      properties.appDisplayName               43
# 6                properties.deviceDetail.browser               18
# 7        properties.deviceDetail.operatingSystem                5
# 8                                callerIpAddress               11
# 9                           properties.ipAddress               11
# 10  properties.location.geoCoordinates.longitude               11
# 11   properties.location.geoCoordinates.latitude               10
# 12                          properties.userAgent                6
# 13                   properties.status.errorCode                8
# 14                                    resultType                8
# 15             properties.autonomousSystemNumber                7
# 16                      properties.location.city               10
# 17              properties.deviceDetail.deviceId               13
# 18                     properties.location.state                5
# 19                                      location                4
# 20           properties.location.countryOrRegion                4
# 21                             properties.userId                1
# 22                    properties.userDisplayName                1
# 23                                      identity                1
# 24           properties.deviceDetail.displayName                1
# 25             properties.deviceDetail.trustType                2
# 26                             resultDescription                7
# 27               properties.status.failureReason                7
# 28           properties.status.additionalDetails                4
#
#     cardinality_med  cardinality_mean  cardinality_min  uniq_ratio_max  \
# 0              72.0         90.000000               61        0.631148
# 1              30.0         29.266667               11        0.285714
# 2              23.0         22.333333               10        0.230769
# 3              20.0         21.066667                5        0.205128
# 4              19.0         19.666667                5        0.196721
# 5              19.0         19.600000                5        0.196721
# 6               7.0          8.200000                2        0.093220
# 7               4.0          3.666667                2        0.038462
# 8               3.0          3.266667                1        0.032787
# 9               3.0          3.266667                1        0.032787
# 10              3.0          3.333333                1        0.040984
# 11              3.0          3.266667                1        0.040984
# 12              3.0          3.133333                1        0.025641
# 13              2.0          3.066667                1        0.025641
# 14              2.0          3.066667                1        0.025641
# 15              2.0          2.466667                1        0.024590
# 16              2.0          3.000000                1        0.032787
# 17              2.0          3.000000                1        0.033333
# 18              1.0          1.733333                1        0.024590
# 19              1.0          1.533333                1        0.024590
# 20              1.0          1.533333                1        0.024590
# 21              1.0          1.000000                1        0.008547
# 22              1.0          1.000000                1        0.008547
# 23              1.0          1.000000                1        0.008547
# 24              1.0          0.933333                0        0.008547
# 25              1.0          1.133333                0        0.016667
# 26              1.0          2.000000                0        0.020000
# 27              1.0          2.000000                0        0.020000
# 28              0.0          0.533333                0        0.013333
#
#     uniq_ratio_med  uniq_ratio_mean  uniq_ratio_min  null_ratio_max  \
# 0         0.540323         0.495453        0.241379        0.000000
# 1         0.206349         0.187282        0.029101        0.016393
# 2         0.166667         0.143457        0.026455        0.464623
# 3         0.156667         0.133773        0.013228        0.020000
# 4         0.147541         0.126275        0.013228        0.000000
# 5         0.147541         0.126052        0.013228        0.000000
# 6         0.057377         0.051080        0.005291        0.858491
# 7         0.031746         0.023793        0.005291        0.000000
# 8         0.017094         0.017690        0.002646        0.000000
# 9         0.017094         0.017690        0.002646        0.000000
# 10        0.016949         0.017825        0.005291        0.000000
# 11        0.016949         0.017690        0.005291        0.000000
# 12        0.020000         0.018373        0.002646        0.915094
# 13        0.016129         0.015545        0.002646        0.000000
# 14        0.016129         0.015545        0.002646        0.000000
# 15        0.016129         0.014127        0.002646        0.000000
# 16        0.016667         0.015883        0.004717        0.000000
# 17        0.016807         0.016332        0.004717        0.000000
# 18        0.008197         0.009016        0.002646        0.000000
# 19        0.008130         0.008523        0.002646        0.000000
# 20        0.008130         0.008523        0.002646        0.000000
# 21        0.008065         0.006336        0.002028        0.000000
# 22        0.008065         0.006336        0.002028        0.000000
# 23        0.008065         0.006336        0.002028        0.000000
# 24        0.007937         0.005771        0.000000        1.000000
# 25        0.008065         0.006991        0.000000        1.000000
# 26        0.008130         0.009074        0.000000        1.000000
# 27        0.008130         0.009074        0.000000        1.000000
# 28        0.000000         0.002722        0.000000        1.000000
#
#     null_ratio_med  null_ratio_mean  null_ratio_min
# 0         0.000000         0.000000        0.000000
# 1         0.000000         0.001945        0.000000
# 2         0.180328         0.186251        0.014199
# 3         0.000000         0.004131        0.000000
# 4         0.000000         0.000000        0.000000
# 5         0.000000         0.000000        0.000000
# 6         0.081967         0.160295        0.005291
# 7         0.000000         0.000000        0.000000
# 8         0.000000         0.000000        0.000000
# 9         0.000000         0.000000        0.000000
# 10        0.000000         0.000000        0.000000
# 11        0.000000         0.000000        0.000000
# 12        0.344262         0.317388        0.010582
# 13        0.000000         0.000000        0.000000
# 14        0.000000         0.000000        0.000000
# 15        0.000000         0.000000        0.000000
# 16        0.000000         0.000000        0.000000
# 17        0.000000         0.000000        0.000000
# 18        0.000000         0.000000        0.000000
# 19        0.000000         0.000000        0.000000
# 20        0.000000         0.000000        0.000000
# 21        0.000000         0.000000        0.000000
# 22        0.000000         0.000000        0.000000
# 23        0.000000         0.000000        0.000000
# 24        0.106557         0.276286        0.000000
# 25        0.106557         0.276286        0.000000
# 26        0.969231         0.860172        0.056795
# 27        0.969231         0.860172        0.056795
# 28        1.000000         0.858156        0.016129

# %% [markdown]
# We can see that some features look less promising at the per-entity level. The same set of criteria can be reused here to evaluate whether a feature should be included as a candidate or not:
# - High cardinality (each row has a unique value, i.e. high uniqueness)
# - Low cardinality (all rows share 1 or 2 constant values)
# - High null ratio

# %% [markdown]
# #### 5.3.1 Good feature candidates<a class="anchor" id="1.6.4.1"></a>
# The thresholds used here are just for demonstration. They can be tuned to suit your data and your requirements better.

# %%
per_entity_stats.columns = per_entity_stats.columns.map(lambda col: f'per_ent_{col}' if col != 'field' else 'field')
feature_stats = feature_candidates.merge(per_entity_stats, on='field')  # merge overall and per-entity stats

# %%
feature_stats
# Out:
#                                            field     type  cardinality  \
# 0        properties.processingTimeInMilliseconds    int64          307
# 1                               properties.appId      str           78
# 2                      properties.appDisplayName      str           77
# 3                                callerIpAddress      str           42
# 4                           properties.ipAddress      str           42
# 5   properties.location.geoCoordinates.longitude  float64           41
# 6    properties.location.geoCoordinates.latitude  float64           40
# 7               properties.deviceDetail.deviceId      str           36
# 8                       properties.location.city      str           34
# 9              properties.autonomousSystemNumber    int64           27
# 10                                      identity      str           20
# 11                    properties.userDisplayName      str           20
# 12                             properties.userId      str           20
# 13                                    resultType      str           16
# 14                   properties.status.errorCode    int64           16
# 15                     properties.location.state      str           16
# 16                                      location      str           11
# 17           properties.location.countryOrRegion      str           11
# 18       properties.deviceDetail.operatingSystem      str            7
# 19                         properties.resourceId      str           83
# 20                properties.resourceDisplayName      str           87
# 21         properties.resourceServicePrincipalId      str           60
# 22               properties.deviceDetail.browser      str           41
# 23                          properties.userAgent      str           22
# 24           properties.deviceDetail.displayName      str           19
# 25             properties.deviceDetail.trustType      str            4
# 26                             resultDescription      str           13
# 27               properties.status.failureReason      str           13
# 28           properties.status.additionalDetails    float            5
#
#     uniq_ratio  null_ratio                                           example1  \
# 0     0.094782      0.0000                                                164
# 1     0.024082      0.0000               9a7e67c7-6f05-42a3-b226-97c7ec3e9696
# 2     0.023773      0.0000                          Adobe Identity Management
# 3     0.012967      0.0000                                       44.22.19.201
# 4     0.012967      0.0000                                       44.22.19.201
# 5     0.012658      0.0000                                        -109.530885
# 6     0.012349      0.0000                                          25.443725
# 7     0.011115      0.0000               0927e60c-8dfa-4ecf-be85-ad63bccf40a1
# 8     0.010497      0.0000                                        Littlemouth
# 9     0.008336      0.0000                                             230297
# 10    0.006175      0.0000                                       Thomas Price
# 11    0.006175      0.0000                                       Thomas Price
# 12    0.006175      0.0000               32109ee2-ee4f-4d11-9c38-2556aec0f2b5
# 13    0.004940      0.0000                                              50158
# 14    0.004940      0.0000                                              50158
# 15    0.004940      0.0000                                      Alexanderfurt
# 16    0.003396      0.0000                                                 XN
# 17    0.003396      0.0000                                                 XN
# 18    0.002161      0.0000                                         Windows 10
# 19    0.025625      0.0022               30663ca7-f8a9-43ab-8ca1-7906bdbc1485
# 20    0.026860      0.0043                  Adobe Identity Management Service
# 21    0.018524      0.1849               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 22    0.012658      0.1911                                     Edge 118.12158
# 23    0.006792      0.3359  Mozilla/5.0 (X11; Linux i686) AppleWebKit/535....
# 24    0.005866      0.3381                                     THOMASPRICE-LT
# 25    0.001235      0.3381                             Hybrid Azure AD joined
# 26    0.004014      0.7891     External security challenge was not satisfied.
# 27    0.004014      0.7891     External security challenge was not satisfied.
# 28    0.001544      0.8713    MFA requirement satisfied by claim in the token
#
#                                              example2  \
# 0                                                 100
# 1                e47a1d38-5f61-45cd-b1b9-bc92f525c598
# 2                                             Altoura
# 3                                      99.116.100.205
# 4                                      99.116.100.205
# 5                                          -17.674718
# 6                                          -38.854047
# 7
# 8                                         Carrollstad
# 9                                              214655
# 10                                         Aaron Cole
# 11                                         Aaron Cole
# 12               5d557969-1645-4ba4-be83-b6fd943659f7
# 13                                                  0
# 14                                                  0
# 15                                         Norrisbury
# 16                                                 XD
# 17                                                 XD
# 18                                            Windows
# 19               f0630e90-b752-4960-bfb9-a0794fc34930
# 20                                     Altoura Online
# 21               1f37c851-4be4-455b-928a-fbde7845a68a
# 22                                     Edge 105.19198
# 23  Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit...
# 24                                   KRISTENHOWELL-LT
# 25                                    Azure AD joined
# 26                                              Other
# 27                                              Other
# 28                           MFA required in Azure AD
#
#                                              example3  \
# 0                                                  91
# 1                9c5b7fe3-0ad2-4ea6-94e5-9e0001f367e3
# 2                                      Articulate 360
# 3                                      86.154.193.190
# 4                                      86.154.193.190
# 5                                          131.871582
# 6                                            3.551896
# 7                6ea76864-5f18-47dd-adb9-2b1dfcbfc425
# 8                                     Port Denisetown
# 9                                              256668
# 10                                     Kristen Howell
# 11                                     Kristen Howell
# 12               20e1e3f9-665f-45bd-9984-5e74b526d3b5
# 13                                             700084
# 14                                             700084
# 15                                           Smithton
# 16                                                 XR
# 17                                                 XR
# 18                                          Windows10
# 19               5e244d4f-26b9-4ef2-a497-f0c533628ee1
# 20                              Articulate 360 Online
# 21               36673087-318c-4304-8804-602d45a6f290
# 22                                      Edge 40.11325
# 23  Mozilla/5.0 (X11; Linux i686) AppleWebKit/533....
# 24                                    JOSEPHTAYLOR-LT
# 25                                Azure AD registered
# 26  Fresh auth token is needed. Have the user re-s...
# 27  Fresh auth token is needed. Have the user re-s...
# 28                          MFA completed in Azure AD
#
#     per_ent_cardinality_max  per_ent_cardinality_med  \
# 0                       144                     72.0
# 1                        44                     19.0
# 2                        43                     19.0
# 3                        11                      3.0
# 4                        11                      3.0
# 5                        11                      3.0
# 6                        10                      3.0
# 7                        13                      2.0
# 8                        10                      2.0
# 9                         7                      2.0
# 10                        1                      1.0
# 11                        1                      1.0
# 12                        1                      1.0
# 13                        8                      2.0
# 14                        8                      2.0
# 15                        5                      1.0
# 16                        4                      1.0
# 17                        4                      1.0
# 18                        5                      4.0
# 19                       51                     30.0
# 20                       47                     20.0
# 21                       39                     23.0
# 22                       18                      7.0
# 23                        6                      3.0
# 24                        1                      1.0
# 25                        2                      1.0
# 26                        7                      1.0
# 27                        7                      1.0
# 28                        4                      0.0
#
#     per_ent_cardinality_mean  per_ent_cardinality_min  per_ent_uniq_ratio_max  \
# 0                  90.000000                       61                0.631148
# 1                  19.666667                        5                0.196721
# 2                  19.600000                        5                0.196721
# 3                   3.266667                        1                0.032787
# 4                   3.266667                        1                0.032787
# 5                   3.333333                        1                0.040984
# 6                   3.266667                        1                0.040984
# 7                   3.000000                        1                0.033333
# 8                   3.000000                        1                0.032787
# 9                   2.466667                        1                0.024590
# 10                  1.000000                        1                0.008547
# 11                  1.000000                        1                0.008547
# 12                  1.000000                        1                0.008547
# 13                  3.066667                        1                0.025641
# 14                  3.066667                        1                0.025641
# 15                  1.733333                        1                0.024590
# 16                  1.533333                        1                0.024590
# 17                  1.533333                        1                0.024590
# 18                  3.666667                        2                0.038462
# 19                 29.266667                       11                0.285714
# 20                 21.066667                        5                0.205128
# 21                 22.333333                       10                0.230769
# 22                  8.200000                        2                0.093220
# 23                  3.133333                        1                0.025641
# 24                  0.933333                        0                0.008547
# 25                  1.133333                        0                0.016667
# 26                  2.000000                        0                0.020000
# 27                  2.000000                        0                0.020000
# 28                  0.533333                        0                0.013333
#
#     per_ent_uniq_ratio_med  per_ent_uniq_ratio_mean  per_ent_uniq_ratio_min  \
# 0                 0.540323                 0.495453                0.241379
# 1                 0.147541                 0.126275                0.013228
# 2                 0.147541                 0.126052                0.013228
# 3                 0.017094                 0.017690                0.002646
# 4                 0.017094                 0.017690                0.002646
# 5                 0.016949                 0.017825                0.005291
# 6                 0.016949                 0.017690                0.005291
# 7                 0.016807                 0.016332                0.004717
# 8                 0.016667                 0.015883                0.004717
# 9                 0.016129                 0.014127                0.002646
# 10                0.008065                 0.006336                0.002028
# 11                0.008065                 0.006336                0.002028
# 12                0.008065                 0.006336                0.002028
# 13                0.016129                 0.015545                0.002646
# 14                0.016129                 0.015545                0.002646
# 15                0.008197                 0.009016                0.002646
# 16                0.008130                 0.008523                0.002646
# 17                0.008130                 0.008523                0.002646
# 18                0.031746                 0.023793                0.005291
# 19                0.206349                 0.187282                0.029101
# 20                0.156667                 0.133773                0.013228
# 21                0.166667                 0.143457                0.026455
# 22                0.057377                 0.051080                0.005291
# 23                0.020000                 0.018373                0.002646
# 24                0.007937                 0.005771                0.000000
# 25                0.008065                 0.006991                0.000000
# 26                0.008130                 0.009074                0.000000
# 27                0.008130                 0.009074                0.000000
# 28                0.000000                 0.002722                0.000000
#
#     per_ent_null_ratio_max  per_ent_null_ratio_med  per_ent_null_ratio_mean  \
# 0                 0.000000                0.000000                 0.000000
# 1                 0.000000                0.000000                 0.000000
# 2                 0.000000                0.000000                 0.000000
# 3                 0.000000                0.000000                 0.000000
# 4                 0.000000                0.000000                 0.000000
# 5                 0.000000                0.000000                 0.000000
# 6                 0.000000                0.000000                 0.000000
# 7                 0.000000                0.000000                 0.000000
# 8                 0.000000                0.000000                 0.000000
# 9                 0.000000                0.000000                 0.000000
# 10                0.000000                0.000000                 0.000000
# 11                0.000000                0.000000                 0.000000
# 12                0.000000                0.000000                 0.000000
# 13                0.000000                0.000000                 0.000000
# 14                0.000000                0.000000                 0.000000
# 15                0.000000                0.000000                 0.000000
# 16                0.000000                0.000000                 0.000000
# 17                0.000000                0.000000                 0.000000
# 18                0.000000                0.000000                 0.000000
# 19                0.016393                0.000000                 0.001945
# 20                0.020000                0.000000                 0.004131
# 21                0.464623                0.180328                 0.186251
# 22                0.858491                0.081967                 0.160295
# 23                0.915094                0.344262                 0.317388
# 24                1.000000                0.106557                 0.276286
# 25                1.000000                0.106557                 0.276286
# 26                1.000000                0.969231                 0.860172
# 27                1.000000                0.969231                 0.860172
# 28                1.000000                1.000000                 0.858156
#
#     per_ent_null_ratio_min
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# 5                 0.000000
# 6                 0.000000
# 7                 0.000000
# 8                 0.000000
# 9                 0.000000
# 10                0.000000
# 11                0.000000
# 12                0.000000
# 13                0.000000
# 14                0.000000
# 15                0.000000
# 16                0.000000
# 17                0.000000
# 18                0.000000
# 19                0.000000
# 20                0.000000
# 21                0.014199
# 22                0.005291
# 23                0.010582
# 24                0.000000
# 25                0.000000
# 26                0.056795
# 27                0.056795
# 28                0.016129

# %%
good_feat_candidate_criteria = (
    # median is a more objective measurement but we can also use mean if we want to take into account everything including the outliers
    (feature_stats.per_ent_uniq_ratio_med < 0.95)
    & ~((feature_stats.per_ent_cardinality_med < 2) & (feature_stats.type != 'bool'))
    & (feature_stats.per_ent_null_ratio_med < 0.9)
)
final_feature_candidates = feature_stats.loc[good_feat_candidate_criteria]

# %%
final_feature_candidates
# Out:
#                                            field     type  cardinality  \
# 0        properties.processingTimeInMilliseconds    int64          307
# 1                               properties.appId      str           78
# 2                      properties.appDisplayName      str           77
# 3                                callerIpAddress      str           42
# 4                           properties.ipAddress      str           42
# 5   properties.location.geoCoordinates.longitude  float64           41
# 6    properties.location.geoCoordinates.latitude  float64           40
# 7               properties.deviceDetail.deviceId      str           36
# 8                       properties.location.city      str           34
# 9              properties.autonomousSystemNumber    int64           27
# 13                                    resultType      str           16
# 14                   properties.status.errorCode    int64           16
# 18       properties.deviceDetail.operatingSystem      str            7
# 19                         properties.resourceId      str           83
# 20                properties.resourceDisplayName      str           87
# 21         properties.resourceServicePrincipalId      str           60
# 22               properties.deviceDetail.browser      str           41
# 23                          properties.userAgent      str           22
#
#     uniq_ratio  null_ratio                                           example1  \
# 0     0.094782      0.0000                                                164
# 1     0.024082      0.0000               9a7e67c7-6f05-42a3-b226-97c7ec3e9696
# 2     0.023773      0.0000                          Adobe Identity Management
# 3     0.012967      0.0000                                       44.22.19.201
# 4     0.012967      0.0000                                       44.22.19.201
# 5     0.012658      0.0000                                        -109.530885
# 6     0.012349      0.0000                                          25.443725
# 7     0.011115      0.0000               0927e60c-8dfa-4ecf-be85-ad63bccf40a1
# 8     0.010497      0.0000                                        Littlemouth
# 9     0.008336      0.0000                                             230297
# 13    0.004940      0.0000                                              50158
# 14    0.004940      0.0000                                              50158
# 18    0.002161      0.0000                                         Windows 10
# 19    0.025625      0.0022               30663ca7-f8a9-43ab-8ca1-7906bdbc1485
# 20    0.026860      0.0043                  Adobe Identity Management Service
# 21    0.018524      0.1849               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 22    0.012658      0.1911                                     Edge 118.12158
# 23    0.006792      0.3359  Mozilla/5.0 (X11; Linux i686) AppleWebKit/535....
#
#                                              example2  \
# 0                                                 100
# 1                e47a1d38-5f61-45cd-b1b9-bc92f525c598
# 2                                             Altoura
# 3                                      99.116.100.205
# 4                                      99.116.100.205
# 5                                          -17.674718
# 6                                          -38.854047
# 7
# 8                                         Carrollstad
# 9                                              214655
# 13                                                  0
# 14                                                  0
# 18                                            Windows
# 19               f0630e90-b752-4960-bfb9-a0794fc34930
# 20                                     Altoura Online
# 21               1f37c851-4be4-455b-928a-fbde7845a68a
# 22                                     Edge 105.19198
# 23  Mozilla/5.0 (Linux; Android 2.3.5) AppleWebKit...
#
#                                              example3  \
# 0                                                  91
# 1                9c5b7fe3-0ad2-4ea6-94e5-9e0001f367e3
# 2                                      Articulate 360
# 3                                      86.154.193.190
# 4                                      86.154.193.190
# 5                                          131.871582
# 6                                            3.551896
# 7                6ea76864-5f18-47dd-adb9-2b1dfcbfc425
# 8                                     Port Denisetown
# 9                                              256668
# 13                                             700084
# 14                                             700084
# 18                                          Windows10
# 19               5e244d4f-26b9-4ef2-a497-f0c533628ee1
# 20                              Articulate 360 Online
# 21               36673087-318c-4304-8804-602d45a6f290
# 22                                      Edge 40.11325
# 23  Mozilla/5.0 (X11; Linux i686) AppleWebKit/533....
#
#     per_ent_cardinality_max  per_ent_cardinality_med  \
# 0                       144                     72.0
# 1                        44                     19.0
# 2                        43                     19.0
# 3                        11                      3.0
# 4                        11                      3.0
# 5                        11                      3.0
# 6                        10                      3.0
# 7                        13                      2.0
# 8                        10                      2.0
# 9                         7                      2.0
# 13                        8                      2.0
# 14                        8                      2.0
# 18                        5                      4.0
# 19                       51                     30.0
# 20                       47                     20.0
# 21                       39                     23.0
# 22                       18                      7.0
# 23                        6                      3.0
#
#     per_ent_cardinality_mean  per_ent_cardinality_min  per_ent_uniq_ratio_max  \
# 0                  90.000000                       61                0.631148
# 1                  19.666667                        5                0.196721
# 2                  19.600000                        5                0.196721
# 3                   3.266667                        1                0.032787
# 4                   3.266667                        1                0.032787
# 5                   3.333333                        1                0.040984
# 6                   3.266667                        1                0.040984
# 7                   3.000000                        1                0.033333
# 8                   3.000000                        1                0.032787
# 9                   2.466667                        1                0.024590
# 13                  3.066667                        1                0.025641
# 14                  3.066667                        1                0.025641
# 18                  3.666667                        2                0.038462
# 19                 29.266667                       11                0.285714
# 20                 21.066667                        5                0.205128
# 21                 22.333333                       10                0.230769
# 22                  8.200000                        2                0.093220
# 23                  3.133333                        1                0.025641
#
#     per_ent_uniq_ratio_med  per_ent_uniq_ratio_mean  per_ent_uniq_ratio_min  \
# 0                 0.540323                 0.495453                0.241379
# 1                 0.147541                 0.126275                0.013228
# 2                 0.147541                 0.126052                0.013228
# 3                 0.017094                 0.017690                0.002646
# 4                 0.017094                 0.017690                0.002646
# 5                 0.016949                 0.017825                0.005291
# 6                 0.016949                 0.017690                0.005291
# 7                 0.016807                 0.016332                0.004717
# 8                 0.016667                 0.015883                0.004717
# 9                 0.016129                 0.014127                0.002646
# 13                0.016129                 0.015545                0.002646
# 14                0.016129                 0.015545                0.002646
# 18                0.031746                 0.023793                0.005291
# 19                0.206349                 0.187282                0.029101
# 20                0.156667                 0.133773                0.013228
# 21                0.166667                 0.143457                0.026455
# 22                0.057377                 0.051080                0.005291
# 23                0.020000                 0.018373                0.002646
#
#     per_ent_null_ratio_max  per_ent_null_ratio_med  per_ent_null_ratio_mean  \
# 0                 0.000000                0.000000                 0.000000
# 1                 0.000000                0.000000                 0.000000
# 2                 0.000000                0.000000                 0.000000
# 3                 0.000000                0.000000                 0.000000
# 4                 0.000000                0.000000                 0.000000
# 5                 0.000000                0.000000                 0.000000
# 6                 0.000000                0.000000                 0.000000
# 7                 0.000000                0.000000                 0.000000
# 8                 0.000000                0.000000                 0.000000
# 9                 0.000000                0.000000                 0.000000
# 13                0.000000                0.000000                 0.000000
# 14                0.000000                0.000000                 0.000000
# 18                0.000000                0.000000                 0.000000
# 19                0.016393                0.000000                 0.001945
# 20                0.020000                0.000000                 0.004131
# 21                0.464623                0.180328                 0.186251
# 22                0.858491                0.081967                 0.160295
# 23                0.915094                0.344262                 0.317388
#
#     per_ent_null_ratio_min
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# 5                 0.000000
# 6                 0.000000
# 7                 0.000000
# 8                 0.000000
# 9                 0.000000
# 13                0.000000
# 14                0.000000
# 18                0.000000
# 19                0.000000
# 20                0.000000
# 21                0.014199
# 22                0.005291
# 23                0.010582

# %%
len(final_feature_candidates)
# Out:
# 18

# %% [markdown]
# Note that `properties.processingTimeInMilliseconds` doesn't seem to be carrying interesting security meaning even if it looks good from the data science perspectives.<br>
# Reviewing with domain expert can help filter out the deceivingly promising features!

# %% [markdown]
# ### 5.4. Feature Correlation<a class="anchor" id="1.6.5"></a>
# Evaluate the correlation between feature candidates to remove redundancy.
# - A data source can have multiple fields representing similar information
#     - E.g., `callerIpAddress` and `properties.ipAddress` are two separate but highly correlated fields in Azure AD logs.<br>
#       They both represent the IP address of the actor in the log event and will always share the same value.
# - <font color='#76B900'>Minimizing redundancy</font> in the feature space boosts the DFP pipeline’s <font color='#76B900'>efficacy</font> and <font color='#76B900'>efficiency</font>
#     - Including fields with overlapping information can distract the model and lead to extra computational cost
# - Measuring the <font color='#76B900'>correlation</font> between each pair of features helps identify and remove redundancy
#     - Make note of the highly correlated features discuss with security experts to rule out redundant information

# %%
# get a dataframe that only includes the final candidate columns
final_candidate_data = data_candidate_cols[final_feature_candidates.field].copy()

# %% [markdown]
# #### 5.4.1 Pearson Correlation Coefficients - Numerical Feature Correlation<a class="anchor" id="1.6.5.1"></a>
# Measure the correlation between numerical features (value range: [-1, 1])
# - Value near ± 1 indicates strong correlation while value near 0 shows no correlation
# - \> 0.5 (or < -0.5) is considered correlation strong enough to be aware of<br>
#
# Analyze the numerical columns:

# %%
final_candidate_data.corr(method='pearson')
# Out:
#                                               properties.processingTimeInMilliseconds  \
# properties.processingTimeInMilliseconds                                      1.000000
# properties.location.geoCoordinates.longitude                                 0.008551
# properties.location.geoCoordinates.latitude                                  0.015966
# properties.autonomousSystemNumber                                           -0.112487
# properties.status.errorCode                                                 -0.038145
#
#                                               properties.location.geoCoordinates.longitude  \
# properties.processingTimeInMilliseconds                                           0.008551
# properties.location.geoCoordinates.longitude                                      1.000000
# properties.location.geoCoordinates.latitude                                      -0.164056
# properties.autonomousSystemNumber                                                 0.011657
# properties.status.errorCode                                                       0.035172
#
#                                               properties.location.geoCoordinates.latitude  \
# properties.processingTimeInMilliseconds                                          0.015966
# properties.location.geoCoordinates.longitude                                    -0.164056
# properties.location.geoCoordinates.latitude                                      1.000000
# properties.autonomousSystemNumber                                                0.204570
# properties.status.errorCode                                                      0.062535
#
#                                               properties.autonomousSystemNumber  \
# properties.processingTimeInMilliseconds                               -0.112487
# properties.location.geoCoordinates.longitude                           0.011657
# properties.location.geoCoordinates.latitude                            0.204570
# properties.autonomousSystemNumber                                      1.000000
# properties.status.errorCode                                            0.126132
#
#                                               properties.status.errorCode
# properties.processingTimeInMilliseconds                         -0.038145
# properties.location.geoCoordinates.longitude                     0.035172
# properties.location.geoCoordinates.latitude                      0.062535
# properties.autonomousSystemNumber                                0.126132
# properties.status.errorCode                                      1.000000

# %% [markdown]
# We can see that there is very little correlation between the numerical columns.

# %% [markdown]
# #### 5.4.2 Cramer's V - Categorical Feature Correlation<a class="anchor" id="1.6.5.2"></a>
# - Value near 1 indicates strong correlation while value near 0 shows no correlation
# - \> 0.5 is considered correlation strong enough to be aware of

# %% [markdown]
# ##### Preporcessing the dataframe
# To measure the correlation between a numerical and a categorical feature, we can bin the numerical feature values into buckets and treat as categorical.

# %%
# Drop properties.processingTimeInMilliseconds as there is no security relevancy
final_candidate_data = final_candidate_data.drop(columns=['properties.processingTimeInMilliseconds'])

# latitude and longitude (numerical, float between -180 to 180) can be binned into size 5 buckets so we have 72 categories instead of infinite possible values
# Note that we use a bin size of 5 here for demonstration, but it can be any value you see fit for your use case.
round_to_closest_5 = lambda x: x//5 * 5
final_candidate_data['latitude_binned'] = final_candidate_data['properties.location.geoCoordinates.latitude'].apply(round_to_closest_5)
final_candidate_data['longitude_binned'] = final_candidate_data['properties.location.geoCoordinates.longitude'].apply(round_to_closest_5)
final_candidate_data = final_candidate_data.drop(columns=['properties.location.geoCoordinates.latitude', 'properties.location.geoCoordinates.longitude'])

# %%
def cramers_v(confusion_matrix):
    """ Takes a confusion matrix of two features and return the Cramer's V correlation coefficient.
    Note that Cramér's V tends to overestimate the strength of association hence this funciton is integrating the suggested correction terms.
    
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r, k = confusion_matrix.shape
    phi2_corrected = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    r_corrected = r - ((r-1)**2)/(n-1)
    k_corrected = k - ((k-1)**2)/(n-1)
    v_corrected = np.sqrt(phi2_corrected / min( (k_corrected-1), (r_corrected-1)))
    return v_corrected

def measure_correlation(data):
    """ Go through all possible pairs of features, evaluate the Cramer's correlation value, and return the result in a dataframe."""
    correlation_results = []
    for i, col_i in enumerate(data.columns):
        for j, col_j in enumerate(data.columns):
            if i >= j:
                # no need to repeat for the same pairs
                continue

            conf_matrix = pd.crosstab(data[col_i], data[col_j])
            v = cramers_v(conf_matrix)
            correlation_results.append([col_i, col_j, v])
    return pd.DataFrame(correlation_results, columns=['column1', 'column2', 'cramers_v'])

# %% [markdown]
# ##### Loop through all pairs of features and evaluate their correlation

# %%
correlations = measure_correlation(final_candidate_data).sort_values('cramers_v', ascending=False)

# %% [markdown]
# ##### Strongly correlated features

# %%
correlations.loc[correlations.cramers_v > 0.5]
# Out:
#                                      column1  \
# 31                           callerIpAddress
# 91                                resultType
# 130          properties.deviceDetail.browser
# 0                           properties.appId
# 116                    properties.resourceId
# 25                 properties.appDisplayName
# 47                      properties.ipAddress
# 34                           callerIpAddress
# 112  properties.deviceDetail.operatingSystem
# 10                          properties.appId
# 56                      properties.ipAddress
# 43                           callerIpAddress
# 46                      properties.ipAddress
# 33                           callerIpAddress
# 44                           callerIpAddress
# 57                      properties.ipAddress
# 80                  properties.location.city
# 79                  properties.location.city
# 70                  properties.location.city
# 135                          latitude_binned
# 111  properties.deviceDetail.operatingSystem
# 90         properties.autonomousSystemNumber
# 89         properties.autonomousSystemNumber
# 122           properties.resourceDisplayName
# 27                 properties.appDisplayName
# 12                          properties.appId
# 32                           callerIpAddress
# 45                      properties.ipAddress
# 59          properties.deviceDetail.deviceId
# 109  properties.deviceDetail.operatingSystem
# 23                 properties.appDisplayName
# 8                           properties.appId
# 69          properties.deviceDetail.deviceId
# 58          properties.deviceDetail.deviceId
# 37                           callerIpAddress
# 50                      properties.ipAddress
# 121           properties.resourceDisplayName
# 68          properties.deviceDetail.deviceId
# 115                    properties.resourceId
# 67          properties.deviceDetail.deviceId
# 24                 properties.appDisplayName
# 28                 properties.appDisplayName
# 13                          properties.appId
# 123           properties.resourceDisplayName
# 9                           properties.appId
# 26                 properties.appDisplayName
# 11                          properties.appId
# 73                  properties.location.city
# 42                           callerIpAddress
# 55                      properties.ipAddress
# 83         properties.autonomousSystemNumber
# 114  properties.deviceDetail.operatingSystem
#
#                                      column2  cramers_v
# 31                      properties.ipAddress   1.000000
# 91               properties.status.errorCode   1.000000
# 130                     properties.userAgent   1.000000
# 0                  properties.appDisplayName   0.999842
# 116    properties.resourceServicePrincipalId   0.999806
# 25            properties.resourceDisplayName   0.998252
# 47         properties.autonomousSystemNumber   0.997662
# 34         properties.autonomousSystemNumber   0.997662
# 112                     properties.userAgent   0.995570
# 10            properties.resourceDisplayName   0.991551
# 56                           latitude_binned   0.960616
# 43                           latitude_binned   0.960616
# 46                  properties.location.city   0.960510
# 33                  properties.location.city   0.960510
# 44                          longitude_binned   0.954442
# 57                          longitude_binned   0.954442
# 80                          longitude_binned   0.917581
# 79                           latitude_binned   0.910711
# 70         properties.autonomousSystemNumber   0.908828
# 135                         longitude_binned   0.908051
# 111          properties.deviceDetail.browser   0.870180
# 90                          longitude_binned   0.844064
# 89                           latitude_binned   0.778096
# 122          properties.deviceDetail.browser   0.717357
# 27           properties.deviceDetail.browser   0.713049
# 12           properties.deviceDetail.browser   0.712817
# 32          properties.deviceDetail.deviceId   0.668674
# 45          properties.deviceDetail.deviceId   0.668674
# 59         properties.autonomousSystemNumber   0.655320
# 109           properties.resourceDisplayName   0.649057
# 23   properties.deviceDetail.operatingSystem   0.647994
# 8    properties.deviceDetail.operatingSystem   0.647755
# 69                          longitude_binned   0.622947
# 58                  properties.location.city   0.596754
# 37   properties.deviceDetail.operatingSystem   0.593905
# 50   properties.deviceDetail.operatingSystem   0.593905
# 121    properties.resourceServicePrincipalId   0.582470
# 68                           latitude_binned   0.574902
# 115           properties.resourceDisplayName   0.572902
# 67                      properties.userAgent   0.554112
# 24                     properties.resourceId   0.550114
# 28                      properties.userAgent   0.550109
# 13                      properties.userAgent   0.549785
# 123                     properties.userAgent   0.549677
# 9                      properties.resourceId   0.546308
# 26     properties.resourceServicePrincipalId   0.545608
# 11     properties.resourceServicePrincipalId   0.545339
# 73   properties.deviceDetail.operatingSystem   0.520000
# 42                      properties.userAgent   0.519910
# 55                      properties.userAgent   0.519910
# 83   properties.deviceDetail.operatingSystem   0.510906
# 114                         longitude_binned   0.505864

# %% [markdown]
# Each pair of features in the above table correlates strong enough to be aware of. <br>
# - E.g., `properties.appId` and `properties.appDisplayName` both provide information on which app was accessed in an event, one being the ID string while the other being the human-readable name. <br>
#   The two fields share a **~1.0** Cramer’s correlation score because there is a one-to-one mapping between them.<br>
#   We should choose one from the two to avoid adding redundancy in the feature space.
# - E.g. `properties.location.city` and `properties.deviceDetail.operatingSystem` has a correlation of **0.52**, which is not insignificant.<br>
#   However, the two variables are independent from the security perspective. We would want to keep both of them as potential feature candidates.<br>
#
# The correlation analysis helps us quickly identify the possible redundancy in the feature space, but **<font color='#76B900'>a strong correlation doesn't indicate dependency</font>**.<br>
# It is important to understand the security context and the dependency of features before ruling out any features. (Two features can show a strong correlation in a sampled dataset by coincidence!)

# %% [markdown]
# ### 5.5. Review with Security Experts<a class="anchor" id="1.6.6"></a>
# Validate the feature candidates with security experts.
# - A “good feature” identified by data science methods can be irrelevant to the problem being solved
#     - E.g., `processingTimeInMilliseconds` is a feature in Azure AD logs which has a proper cardinality and is never null.<br>
#       However, it represents the milliseconds taken to process the log, which helps monitor the health of the pipeline but carries very little security context about the event.
# - An identified “bad feature” can carry important security context and just needs some extra feature engineering to be useful
#     - E.g., `timestamp` of every log is unique. Hence as a feature, timestamp will have a super high cardinality.<br>
#       However, the time an event happened can contribute largely to the “anomalousness” of a behavior.<br>
#       As a workaround, we can capture the time information by parsing “hour of day” or “day of week” and use them as derived features.
# - Reviewing feature candidates with security experts helps keep our model <font color='#76B900'>relevant</font> and <font color='#76B900'>effective</font>
#     - A deeper understanding of the data and the target domain is always beneficial for all ML applications

# %% [markdown]
# ## 6. Ideas on Derived Features<a class="anchor" id="1.7"></a>
# The previous sections demonstrate a way to select from the raw features. However, raw values do not always capture the information that is helpful for modeling.
# - Derived features enlighten the model on <font color='#76B900'>key</font> information that is <font color='#76B900'>hidden</font> in plain sight
# - Examples of useful insights to feed into the model:
#     - **Strong relation between fields**<br>
#     E.g.: City, state, and country fields together provide information on location.<br>
#     Concatenating them into a single <font color='#76B900'>location</font> feature can inform the model about it and avoid collisions between multiple cities with the same names.
#     - **Semantics behind the plain value of a field**<br>
#     E.g.: App name are strings hence are treated as categorical features by the model. However, `Microsoft Teams` and `Microsoft Teams Services` might be semantically closer compared to `Office 365 Exchange Online`.<br>
#     Adding an <font color='#76B900'>app category</font> feature (e.g., `MS Teams`/`Exchange`) can help capture the meaning of the field better.
#     - **Anomalous pattern to target**<br>
#     Depending on the use case, there may be specific patterns we wish to highlight for the model.<br>
#     E.g.: Being compromised, a user account may be used to access a high number of resources in the environment.<br>
#     In this case, <font color='#76B900'>incremental app count</font> for the day would be a good feature to being attention to targeted red flags.

# %% [markdown]
# ## 7. Conclusion<a class="anchor" id="1.8"></a>
# - Feature selection and feature engineering are fundamental to all machine learning applications
# - A good feature set should cover the key information about an event (actor, time, location, resource accessed, ... etc.) without redundancy
# - Any information that is considered useful for a human analyst during threat investigation should be considered to be included in the DFP feature set<br>
#
# With a good set of raw and derived features, DFP can be a powerful tool that helps monitor the activities in the network and detect anomalies at scale.
