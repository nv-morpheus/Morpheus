# %% [markdown]
# # Digital Fingerprinting (DFP) — Feature Selection

# %% [markdown]
# This notebook includes an introduction to DFP, the suggested steps for DFP feature selection, and the code segments demonstrating how each step can be done in practice.<br>
# <font color='gray'>Note. This notebook uses Azure AD logs as an example but the same process can be applied to any data sources.</font>

# %% [markdown]
# ## Table of Contents
# 1. [The Application of DFP](#1.2)
# 2. [DFP Features In Use - Azure AD Logs](#1.3)
# 3. [DFP Features In Use - DUO Authentication Logs](#1.4)
# 4. [Feature Engineering and Feature Types](#1.5)
# 5. [Steps for Selecting Raw Features](#1.6)<br>
#     - 5.0. [Load Data](#1.6.1)<br>
#     - 5.1. [Data Overview](#1.6.2)<br>
#     - 5.2. [Overall Statistics](#1.6.3)<br>
#         - 5.2.1 [Signs of a bad feature](#1.6.3.1)<br>
# 		- 5.2.2 [Good feature candidates](#1.6.3.5)<br>
# 	- 5.3. [Per-entity Statistics](#1.6.4)<br>
# 		- 5.3.1 [Good feature candidates](#1.6.4.1) <br>
# 	- 5.4. [Feature Correlation](#1.6.5)<br>
# 		- 5.4.1 [Pearson Correlation Coefficients - Numerical Feature Correlation](#1.6.5.1)<br>
# 		- 5.4.2 [Cramer's V - Categorical Feature Correlation](#1.6.5.2)<br>
# 	- 5.5. [Review with Security Experts](1.6.6)<br>
# 6. [Ideas on Derived Features](#1.7)
# 7. [Conclusion](#1.8)

# %% [markdown]
# ## 1. The Application of DFP <a class="anchor" id="1.2"></a>
# - DFP is a general pipeline that can ingest various data sources to do behavioral anomaly detection
# - POC was done on <font color='#76B900'>Azure AD logs</font> and <font color='#76B900'>DUO authentication logs</font>, but the application of DFP can easily be expanded to other data sources
# - The key to applying DFP to a new data source is through the process of <font color='#76B900'>feature selection</font>
#     - DFP supports all types of features (numerical/categorical/binary)
#     - Any data source can be fed into DFP after some preprocessing to get a feature vector per log/data point
# - Note that DFP builds targeted model for each entity (user/service/machine… etc.), so it would work best if the chosen data source has a field that uniquely identify the entity we’re trying to model

# %% [markdown]
# ## 2. DFP Features In Use - Azure AD Logs <a class="anchor" id="1.3"></a>
# **<font color='#76B900'>1. </font>appDisplayName**: e.g., Windows sign in, MS Teams, Office 365<br>
# **<font color='#76B900'>2. </font>clientAppUsed**: e.g., IMAP4, Browser<br>
# **<font color='#76B900'>3. </font>deviceDetail.displayName**: e.g., username-LT<br>
# **<font color='#76B900'>4. </font>deviceDetail.browser**: e.g., EDGE 98.0.xyz, Chrome 98.0.xyz<br>
# **<font color='#76B900'>5. </font>deviceDetail.operatingSystem**: e.g., Linux, IOS 15, Windows 10<br>
# **<font color='#76B900'>6. </font>statusfailureReason**: e.g., external security challenge not satisfied, error validating credentials<br>
# **<font color='#76B900'>7. </font>riskEventTypesv2**: AzureADThreatIntel, unfamiliarFeatures<br>
# **<font color='#76B900'>8. </font>location.countryOrRegion**: country or region name<br>
# **<font color='#76B900'>9. </font>location.city**: city name<br>
#
# <ins>Derived features</ins>:<br>
# **<font color='#76B900'>10. </font>Log count**: tracks the number of logs generated by a user within that day (increments with every log)<br>
# **<font color='#76B900'>11. </font>Location increment**: increments every time we observe a new city (location.city) in a user’s logs within that day<br>
# **<font color='#76B900'>12. </font>App increment**: increments every time we observe a new app (appDisplayName) in a user’s logs within that day<br>

# %% [markdown]
# ## 3. DFP Features In Use - DUO Authentication Logs <a class="anchor" id="1.4"></a>
# **<font color='#76B900'>1. </font>auth_device.name**: phone number<br>
# **<font color='#76B900'>2. </font>access_device.browser**: e.g., Edge, Chrome, Chrome Mobile<br>
# **<font color='#76B900'>3. </font>access_device.os**: e.g., Android, Windows<br>
# **<font color='#76B900'>4. </font>result**: SUCCESS or FAILURE <br>
# **<font color='#76B900'>5. </font>reason**: reason for the results, e.g., User Cancelled, User Approved, User Mistake, No Response<br>
# **<font color='#76B900'>6. </font>access_device.location.city**: city name<br>
#
# <ins>Derived features</ins>:<br>
# **<font color='#76B900'>7. </font>Log count**: tracks the number of logs generated by a user within that day (increments with every log)<br>
# **<font color='#76B900'>8. </font>Location increment**: increments every time we observe a new city (location.city) in a user’s logs within that day<br>

# %% [markdown]
# ## 4. Feature Engineering and Feature Types <a class="anchor" id="1.5"></a>
# - Feature engineering is key to every successful machine learning application
#     - The more <font color='#76B900'>relevant</font> the features are to the problem being solved the better
#     - <font color='#76B900'>Excluding redundant fields</font> in the raw data helps the model concentrate on key information
# - The different feature types:<br>
#     **<font color='#76B900'>1. </font>Raw feature**: raw value from a data field (e.g., operation name)<br>
#     **<font color='#76B900'>2. </font>Derived feature**: processed value from one or more data fields and/or data records<br>
#     - **Single-record extracted feature**: value computed from one or more fields of a single data record<br>
#         E.g.: parse from IPv4 address the /16 CIDR block to get a “subnet” feature<br>
#         E.g.: concatenate first and last name fields into a “name” feature<br>
#     - **Aggregated feature**: value computed across multiple data records over time<br>
#         E.g.: a “log count” feature that counts the number of logs generated by a user within a given day<br>
#         (this is <font color='#76B900'>time-dependent</font> as the count increments with each log throughout the day)<br>
#         <font color='#C00000'>Note. Aggregated features can require significant resource to compute. Use with caution to avoid unnecessary performance penalties.</font>

# %% [markdown]
# ## 5. Steps for Selecting Raw Features <a class="anchor" id="1.6"></a>
# - Each data source provides a unique set of information about cyber activities
#     - There can be a high number of fields while many of them are <font color='#76B900'>unpopulated</font> or <font color='#76B900'>irrelevant</font> to our problem
#     - Data analysis can help us quickly identify good and bad candidates for raw features
# - The following steps are a general guideline on feature selection for custom DFP applications:<br>
#     **<font color='#76B900'>1. </font>Date overview**: scan through all the features to understand what are available<br>
#     **<font color='#76B900'>2. </font>Overall statistics**: collect global statistics for each feature to rule out bad fits<br>
#     **<font color='#76B900'>3. </font>Per-entity statistics**: collect entity-level statistics for each feature to further evaluate their “usefulness”<br>
#     **<font color='#76B900'>4. </font>Feature correlation**: evaluate the correlation between feature candidates to remove redundancy<br>
#     **<font color='#76B900'>5. </font>Review with security experts**: run the feature candidates by security experts to make sure they are meaningful and relevant to the problem being solved<br>

# %% [markdown]
# <img src="steps.png" width="1000"/>

# %%
import json
import pandas as pd
import numpy as np
import scipy.stats as ss

# %% [markdown]
# ### 5.0 Load Data <a class="anchor" id="1.6.1"></a>
# The following steps show how to load a __nested json__ file and flatten it into a pandas dataframe.<br>
# If your data doesn't have nested fields or is in other formats, you can load it by `pd.read_json` or other `pd.read_*` methods.<br>
#
# __Note.__ Make sure you're loading the __entire__ dataset OR a sample as representative as it can be of the entire dataset.<br>
# This is to avoid underestimating the cardinality of each feature by using a small, non-representative sample of the entire dataset.

# %%
json_obj = json.load(open('azure_ad_logs_sample_with_anomaly.json', 'r'))

# %%
print(f'# rows: {len(json_obj)}\nExample:\n{json.dumps(json_obj[0], indent=2, sort_keys=True)}')
# Out:
# # rows: 3567
# Example:
# {
#   "Level": 4,
#   "callerIpAddress": "68.28.66.83",
#   "category": "NonInteractiveUserSignInLogs",
#   "correlationId": "00cb0df9-b21d-4544-b859-f78ae9e9048b",
#   "durationMs": 0,
#   "identity": "Russell Watson",
#   "location": "XX",
#   "operationName": "Sign-in activity",
#   "operationVersion": "1.0",
#   "properties": {
#     "appDisplayName": "Adobe Identity Management",
#     "appId": "9da0a1ff-e8cf-4513-8520-bf84f723f1ae",
#     "appServicePrincipalId": null,
#     "appliedConditionalAccessPolicies": [],
#     "authenticationContextClassReferences": [],
#     "authenticationDetails": [],
#     "authenticationProcessingDetails": [],
#     "authenticationProtocol": "none",
#     "authenticationRequirement": "singleFactorAuthentication",
#     "authenticationRequirementPolicies": [],
#     "autonomousSystemNumber": 38834,
#     "clientAppUsed": "Mobile Apps and Desktop clients",
#     "clientCredentialType": "none",
#     "conditionalAccessStatus": "failure",
#     "correlationId": "00cb0df9-b21d-4544-b859-f78ae9e9048b",
#     "createdDateTime": "2022-08-01T00:06:10.138613Z",
#     "crossTenantAccessType": "none",
#     "deviceDetail": {
#       "browser": "Edge 18.17763",
#       "deviceId": "72c565a0-f587-4d5e-9fa9-82cab482ddf0",
#       "displayName": "RUSSELLWATSON-LT",
#       "operatingSystem": "Windows 10",
#       "trustType": "Hybrid Azure AD joined"
#     },
#     "flaggedForReview": false,
#     "homeTenantId": "7eea32ba-5081-491b-be43-2b067cb95201",
#     "id": "ffcaca16-51c9-4067-8710-403cefa97200",
#     "incomingTokenType": "primaryRefreshToken",
#     "ipAddress": "68.28.66.83",
#     "isInteractive": false,
#     "isTenantRestricted": false,
#     "location": {
#       "city": "Dawnshire",
#       "countryOrRegion": "XX",
#       "geoCoordinates": {
#         "latitude": -49.889482,
#         "longitude": 170.600705
#       },
#       "state": "Sanchezton"
#     },
#     "networkLocationDetails": [],
#     "originalRequestId": "ffcaca16-51c9-4067-8710-403cefa97200",
#     "privateLinkDetails": {},
#     "processingTimeInMilliseconds": 120,
#     "resourceDisplayName": "Adobe Identity Management Service",
#     "resourceId": "abd030d9-bce0-4089-9303-9d46fb13ee16",
#     "resourceServicePrincipalId": "a6c259e5-7f16-48b2-a9f3-75becd6daa9b",
#     "resourceTenantId": "7eea32ba-5081-491b-be43-2b067cb95201",
#     "riskDetail": "none",
#     "riskEventTypes": [],
#     "riskEventTypes_v2": [],
#     "riskLevelAggregated": "none",
#     "riskLevelDuringSignIn": "none",
#     "riskState": "none",
#     "rngcStatus": 0,
#     "servicePrincipalId": "",
#     "ssoExtensionVersion": "",
#     "status": {
#       "errorCode": 50158,
#       "failureReason": "External security challenge was not satisfied."
#     },
#     "tokenIssuerName": "",
#     "tokenIssuerType": "AzureAD",
#     "uniqueTokenIdentifier": "ZmZjYWNhMTYtNTFjOS00MDY3LTg3MTAtNDAzY2VmYTk3MjAw",
#     "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36 Edge/18.17763",
#     "userDisplayName": "Russell Watson",
#     "userId": "8621535c-c57e-4001-966e-a09ee53372ab",
#     "userPrincipalName": "rwatson@domain.com",
#     "userType": "Member"
#   },
#   "resourceId": "/tenants/7eea32ba-5081-491b-be43-2b067cb95201/providers/Microsoft.aadiam",
#   "resultDescription": "External security challenge was not satisfied.",
#   "resultSignature": "None",
#   "resultType": "50158",
#   "tenantId": "7eea32ba-5081-491b-be43-2b067cb95201",
#   "time": "2022-08-01T00:06:10.018613Z"
# }

# %%
data = pd.json_normalize(json_obj)

# %% [markdown]
# ### 5.1. Data Overview <a class="anchor" id="1.6.2"></a>
# Scan through the columns and understand what are available.<br>
# - A quick glance over the data helps us identify whether the data source is a good fit for DFP and what options we have on potential features
# - In the POC, DFP works well with the following set of information:
#     - **<span style='background:#76B900;color:white'>WHO</span>** Unique identifier of the entity: e.g., user ID, email address, machine name
#     - **<span style='background:#76B900;color:white'>WHAT</span>** Device involved: e.g., device ID, browser, OS version
#     - **<span style='background:#76B900;color:white'>WHERE</span>** Location of the event: e.g., country, state, city, latitude, longitude
#     - **<span style='background:#76B900;color:white'>WHY</span>** Application used: e.g., app name, resource ID, service principal name
#     - **<span style='background:#76B900;color:white'>WHEN</span>** Time stamp: for temporal analysis
#     - Any features that can provide the above information are good candidates to consider!

# %%
pd.set_option('display.max_columns', None)  # ask pandas to show all the columns

# %%
data
# Out:
#                              time  \
# 0     2022-08-01T00:06:10.018613Z
# 1     2022-08-01T00:12:41.855581Z
# 2     2022-08-01T00:29:13.018517Z
# 3     2022-08-01T00:31:39.804189Z
# 4     2022-08-01T00:41:49.420942Z
# ...                           ...
# 3562  2022-08-31T23:38:00.610805Z
# 3563  2022-08-31T23:44:52.230053Z
# 3564  2022-08-31T23:46:51.306855Z
# 3565  2022-08-31T23:51:38.278516Z
# 3566  2022-08-31T23:58:40.334832Z
#
#                                              resourceId     operationName  \
# 0     /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 1     /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 2     /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 3     /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 4     /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# ...                                                 ...               ...
# 3562  /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 3563  /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 3564  /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 3565  /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
# 3566  /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...  Sign-in activity
#
#      operationVersion                      category  \
# 0                 1.0  NonInteractiveUserSignInLogs
# 1                 1.0  NonInteractiveUserSignInLogs
# 2                 1.0  NonInteractiveUserSignInLogs
# 3                 1.0  NonInteractiveUserSignInLogs
# 4                 1.0  NonInteractiveUserSignInLogs
# ...               ...                           ...
# 3562              1.0  NonInteractiveUserSignInLogs
# 3563              1.0  NonInteractiveUserSignInLogs
# 3564              1.0  NonInteractiveUserSignInLogs
# 3565              1.0  NonInteractiveUserSignInLogs
# 3566              1.0  NonInteractiveUserSignInLogs
#
#                                   tenantId resultType resultSignature  \
# 0     7eea32ba-5081-491b-be43-2b067cb95201      50158            None
# 1     7eea32ba-5081-491b-be43-2b067cb95201          0            None
# 2     7eea32ba-5081-491b-be43-2b067cb95201          0            None
# 3     7eea32ba-5081-491b-be43-2b067cb95201          0            None
# 4     7eea32ba-5081-491b-be43-2b067cb95201          0            None
# ...                                    ...        ...             ...
# 3562  7eea32ba-5081-491b-be43-2b067cb95201          0            None
# 3563  7eea32ba-5081-491b-be43-2b067cb95201          0            None
# 3564  7eea32ba-5081-491b-be43-2b067cb95201          0            None
# 3565  7eea32ba-5081-491b-be43-2b067cb95201          0            None
# 3566  7eea32ba-5081-491b-be43-2b067cb95201          0            None
#
#                                    resultDescription  durationMs  \
# 0     External security challenge was not satisfied.           0
# 1                                                NaN           0
# 2                                                NaN           0
# 3                                                NaN           0
# 4                                                NaN           0
# ...                                              ...         ...
# 3562                                             NaN           0
# 3563                                             NaN           0
# 3564                                             NaN           0
# 3565                                             NaN           0
# 3566                                             NaN           0
#
#       callerIpAddress                         correlationId        identity  \
# 0         68.28.66.83  00cb0df9-b21d-4544-b859-f78ae9e9048b  Russell Watson
# 1      38.185.182.132  044e431d-93e2-415d-9fb5-2936a1a7ec3c   Stephen White
# 2       185.25.177.84  778307c7-9801-4873-bb5e-a8adba9f8bb2   Amber Estrada
# 3         34.87.0.182  4c4dedb1-62f2-4fba-9bd3-ab1ef86aa211   Daniel Barber
# 4     103.174.219.227  6bccda12-dea6-41d9-bfdc-d3b21178fd69   Attack Target
# ...               ...                                   ...             ...
# 3562   65.209.146.180  30b064e2-c6e3-42bb-a837-f7b0998aa7a3   Attack Target
# 3563   65.209.146.180  e85e2f87-47c4-43fc-8fca-bbfed43b2c6d   Attack Target
# 3564   65.209.146.180  99b0cdd3-a457-4930-9192-163237ed1677   Attack Target
# 3565   65.209.146.180  48f0634f-c13a-491b-99e9-9ff127cc5f12   Attack Target
# 3566   65.209.146.180  9bf1e5bc-3cd6-4b8c-abd9-53dbff3ab51d   Attack Target
#
#       Level location                         properties.id  \
# 0         4       XX  ffcaca16-51c9-4067-8710-403cefa97200
# 1         4       XK  717ef043-4342-4bef-be3f-b1a2379d6600
# 2         4       XS  17558929-4181-40d4-9645-7d2933c57400
# 3         4       XS  cb1cdc58-3d1a-4d1a-ab9f-1d7756291800
# 4         4       XK  381dc42c-1581-42c2-8b81-ee5d74406b00
# ...     ...      ...                                   ...
# 3562      4       ZZ  94c99ee9-21d2-4aba-9fc3-5d1f98c85000
# 3563      4       ZZ  94c99ee9-21d2-4aba-9fc3-5d1f98c85000
# 3564      4       ZZ  94c99ee9-21d2-4aba-9fc3-5d1f98c85000
# 3565      4       ZZ  94c99ee9-21d2-4aba-9fc3-5d1f98c85000
# 3566      4       ZZ  94c99ee9-21d2-4aba-9fc3-5d1f98c85000
#
#        properties.createdDateTime properties.userDisplayName  \
# 0     2022-08-01T00:06:10.138613Z             Russell Watson
# 1     2022-08-01T00:12:42.005581Z              Stephen White
# 2     2022-08-01T00:29:13.114517Z              Amber Estrada
# 3     2022-08-01T00:31:39.908189Z              Daniel Barber
# 4     2022-08-01T00:41:49.573942Z              Attack Target
# ...                           ...                        ...
# 3562  2022-08-31T23:38:00.740805Z              Attack Target
# 3563  2022-08-31T23:44:52.360053Z              Attack Target
# 3564  2022-08-31T23:46:51.436855Z              Attack Target
# 3565  2022-08-31T23:51:38.408516Z              Attack Target
# 3566  2022-08-31T23:58:40.464832Z              Attack Target
#
#      properties.userPrincipalName                     properties.userId  \
# 0              rwatson@domain.com  8621535c-c57e-4001-966e-a09ee53372ab
# 1               swhite@domain.com  e79f7294-f107-4e74-95d5-53a6521bc624
# 2             aestrada@domain.com  c0c2d7f1-4a8a-4a76-b687-ba2d2001a545
# 3              dbarber@domain.com  4c3246f6-a8c2-4142-bf9f-1e130ae95070
# 4         attacktarget@domain.com  6269aa4a-69bb-47c4-a217-31eeefc13e24
# ...                           ...                                   ...
# 3562      attacktarget@domain.com  6269aa4a-69bb-47c4-a217-31eeefc13e24
# 3563      attacktarget@domain.com  6269aa4a-69bb-47c4-a217-31eeefc13e24
# 3564      attacktarget@domain.com  6269aa4a-69bb-47c4-a217-31eeefc13e24
# 3565      attacktarget@domain.com  6269aa4a-69bb-47c4-a217-31eeefc13e24
# 3566      attacktarget@domain.com  6269aa4a-69bb-47c4-a217-31eeefc13e24
#
#                           properties.appId  \
# 0     9da0a1ff-e8cf-4513-8520-bf84f723f1ae
# 1     890fda57-180f-472a-8838-ad79f06ad863
# 2     9da0a1ff-e8cf-4513-8520-bf84f723f1ae
# 3     0f834804-f0dc-4fef-b3f5-be308ac60f9f
# 4     9da0a1ff-e8cf-4513-8520-bf84f723f1ae
# ...                                    ...
# 3562  0cb4050a-1e8f-4f5d-ba48-265281954a3c
# 3563  1fdfd6f1-6a86-4df8-9fc9-7266b579eef6
# 3564  4e8e03c9-9347-42d5-9352-c0e515dfcb61
# 3565  d87545d3-088a-43c5-a606-7a314b08e67e
# 3566  b8c105ea-3566-47e9-9de9-538f4d13e696
#
#                  properties.appDisplayName properties.ipAddress  \
# 0                Adobe Identity Management          68.28.66.83
# 1                                    Alaya       38.185.182.132
# 2                Adobe Identity Management        185.25.177.84
# 3                                      Air          34.87.0.182
# 4                Adobe Identity Management      103.174.219.227
# ...                                    ...                  ...
# 3562                            Help Scout       65.209.146.180
# 3563                               Altoura       65.209.146.180
# 3564  Qlik Sense Enterprise Client-Managed       65.209.146.180
# 3565                    SAP SuccessFactors       65.209.146.180
# 3566                             InStation       65.209.146.180
#
#       properties.status.errorCode  \
# 0                           50158
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 3562                            0
# 3563                            0
# 3564                            0
# 3565                            0
# 3566                            0
#
#                      properties.status.failureReason  \
# 0     External security challenge was not satisfied.
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 3562                                             NaN
# 3563                                             NaN
# 3564                                             NaN
# 3565                                             NaN
# 3566                                             NaN
#
#              properties.clientAppUsed  \
# 0     Mobile Apps and Desktop clients
# 1     Mobile Apps and Desktop clients
# 2     Mobile Apps and Desktop clients
# 3     Mobile Apps and Desktop clients
# 4     Mobile Apps and Desktop clients
# ...                               ...
# 3562  Mobile Apps and Desktop clients
# 3563  Mobile Apps and Desktop clients
# 3564  Mobile Apps and Desktop clients
# 3565  Mobile Apps and Desktop clients
# 3566  Mobile Apps and Desktop clients
#
#                                    properties.userAgent  \
# 0     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 4     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# ...                                                 ...
# 3562  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3563  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3564  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3565  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3566  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#           properties.deviceDetail.deviceId  \
# 0     72c565a0-f587-4d5e-9fa9-82cab482ddf0
# 1     15135d1f-cb47-4bd8-b76d-90a9171c09bd
# 2     639815fd-5018-4e38-9d81-67538b2ce460
# 3     e395a3f4-8f2d-4170-804f-d3e13ce3151b
# 4     a44625dc-6f81-449a-9799-8005f7209b42
# ...                                    ...
# 3562  a44625dc-6f81-449a-9799-8005f7209b42
# 3563  a44625dc-6f81-449a-9799-8005f7209b42
# 3564  a44625dc-6f81-449a-9799-8005f7209b42
# 3565  a44625dc-6f81-449a-9799-8005f7209b42
# 3566  a44625dc-6f81-449a-9799-8005f7209b42
#
#      properties.deviceDetail.displayName  \
# 0                       RUSSELLWATSON-LT
# 1                        STEPHENWHITE-LT
# 2                        AMBERESTRADA-LT
# 3                        DANIELBARBER-LT
# 4                        ATTACKTARGET-LT
# ...                                  ...
# 3562                     ATTACKTARGET-LT
# 3563                     ATTACKTARGET-LT
# 3564                     ATTACKTARGET-LT
# 3565                     ATTACKTARGET-LT
# 3566                     ATTACKTARGET-LT
#
#      properties.deviceDetail.operatingSystem properties.deviceDetail.browser  \
# 0                                 Windows 10                   Edge 18.17763
# 1                                 Windows 10                   Edge 18.19043
# 2                                 Windows 10                   Edge 18.18363
# 3                                 Windows 10                   Edge 18.19041
# 4                                 Windows 10                   Edge 18.19042
# ...                                      ...                             ...
# 3562                              Windows 10               Chrome 100.0.4896
# 3563                              Windows 10               Chrome 100.0.4896
# 3564                              Windows 10               Chrome 100.0.4896
# 3565                              Windows 10               Chrome 100.0.4896
# 3566                              Windows 10               Chrome 100.0.4896
#
#      properties.deviceDetail.trustType properties.location.city  \
# 0               Hybrid Azure AD joined                Dawnshire
# 1                  Azure AD registered                East Kara
# 2                  Azure AD registered              Port Robert
# 3                  Azure AD registered           Port Mikemouth
# 4                  Azure AD registered            Cummingsville
# ...                                ...                      ...
# 3562               Azure AD registered           Anomalous City
# 3563               Azure AD registered           Anomalous City
# 3564               Azure AD registered           Anomalous City
# 3565               Azure AD registered           Anomalous City
# 3566               Azure AD registered           Anomalous City
#
#      properties.location.state properties.location.countryOrRegion  \
# 0                   Sanchezton                                  XX
# 1                    Amberland                                  XK
# 2                    Jesusland                                  XS
# 3                    Jesusland                                  XS
# 4                    Anneville                                  XK
# ...                        ...                                 ...
# 3562             Anomaloustate                                  ZZ
# 3563             Anomaloustate                                  ZZ
# 3564             Anomaloustate                                  ZZ
# 3565             Anomaloustate                                  ZZ
# 3566             Anomaloustate                                  ZZ
#
#       properties.location.geoCoordinates.latitude  \
# 0                                      -49.889482
# 1                                        6.915915
# 2                                      -38.158813
# 3                                      -87.816018
# 4                                       44.309193
# ...                                           ...
# 3562                                   -49.629359
# 3563                                   -49.629359
# 3564                                   -49.629359
# 3565                                   -49.629359
# 3566                                   -49.629359
#
#       properties.location.geoCoordinates.longitude  \
# 0                                       170.600705
# 1                                         5.176877
# 2                                      -178.150039
# 3                                       145.033056
# 4                                        20.003646
# ...                                            ...
# 3562                                    -19.914365
# 3563                                    -19.914365
# 3564                                    -19.914365
# 3565                                    -19.914365
# 3566                                    -19.914365
#
#                   properties.correlationId properties.conditionalAccessStatus  \
# 0     00cb0df9-b21d-4544-b859-f78ae9e9048b                            failure
# 1     044e431d-93e2-415d-9fb5-2936a1a7ec3c                            success
# 2     778307c7-9801-4873-bb5e-a8adba9f8bb2                            success
# 3     4c4dedb1-62f2-4fba-9bd3-ab1ef86aa211                            success
# 4     6bccda12-dea6-41d9-bfdc-d3b21178fd69                            success
# ...                                    ...                                ...
# 3562  1511bc50-e1c8-4ea8-abe7-f221fe62fd04                            success
# 3563  1511bc50-e1c8-4ea8-abe7-f221fe62fd04                            success
# 3564  1511bc50-e1c8-4ea8-abe7-f221fe62fd04                            success
# 3565  1511bc50-e1c8-4ea8-abe7-f221fe62fd04                            success
# 3566  1511bc50-e1c8-4ea8-abe7-f221fe62fd04                            success
#
#      properties.appliedConditionalAccessPolicies  \
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4                                             []
# ...                                          ...
# 3562                                          []
# 3563                                          []
# 3564                                          []
# 3565                                          []
# 3566                                          []
#
#      properties.authenticationContextClassReferences  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# ...                                              ...
# 3562                                              []
# 3563                                              []
# 3564                                              []
# 3565                                              []
# 3566                                              []
#
#               properties.originalRequestId  properties.isInteractive  \
# 0     ffcaca16-51c9-4067-8710-403cefa97200                     False
# 1     717ef043-4342-4bef-be3f-b1a2379d6600                     False
# 2     17558929-4181-40d4-9645-7d2933c57400                     False
# 3     cb1cdc58-3d1a-4d1a-ab9f-1d7756291800                     False
# 4     381dc42c-1581-42c2-8b81-ee5d74406b00                     False
# ...                                    ...                       ...
# 3562  94c99ee9-21d2-4aba-9fc3-5d1f98c85000                     False
# 3563  94c99ee9-21d2-4aba-9fc3-5d1f98c85000                     False
# 3564  94c99ee9-21d2-4aba-9fc3-5d1f98c85000                     False
# 3565  94c99ee9-21d2-4aba-9fc3-5d1f98c85000                     False
# 3566  94c99ee9-21d2-4aba-9fc3-5d1f98c85000                     False
#
#      properties.tokenIssuerName properties.tokenIssuerType  \
# 0                                                  AzureAD
# 1                                                  AzureAD
# 2                                                  AzureAD
# 3                                                  AzureAD
# 4                                                  AzureAD
# ...                         ...                        ...
# 3562                                               AzureAD
# 3563                                               AzureAD
# 3564                                               AzureAD
# 3565                                               AzureAD
# 3566                                               AzureAD
#
#      properties.authenticationProcessingDetails  \
# 0                                            []
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
# ...                                         ...
# 3562                                         []
# 3563                                         []
# 3564                                         []
# 3565                                         []
# 3566                                         []
#
#      properties.networkLocationDetails properties.clientCredentialType  \
# 0                                   []                            none
# 1                                   []                            none
# 2                                   []                            none
# 3                                   []                            none
# 4                                   []                            none
# ...                                ...                             ...
# 3562                                []                             NaN
# 3563                                []                             NaN
# 3564                                []                             NaN
# 3565                                []                             NaN
# 3566                                []                             NaN
#
#       properties.processingTimeInMilliseconds properties.riskDetail  \
# 0                                         120                  none
# 1                                         150                  none
# 2                                          96                  none
# 3                                         104                  none
# 4                                         153                  none
# ...                                       ...                   ...
# 3562                                      130                  none
# 3563                                      130                  none
# 3564                                      130                  none
# 3565                                      130                  none
# 3566                                      130                  none
#
#      properties.riskLevelAggregated properties.riskLevelDuringSignIn  \
# 0                              none                             none
# 1                              none                             none
# 2                              none                             none
# 3                              none                             none
# 4                              none                             none
# ...                             ...                              ...
# 3562                           none                             none
# 3563                           none                             none
# 3564                           none                             none
# 3565                           none                             none
# 3566                           none                             none
#
#      properties.riskState properties.riskEventTypes  \
# 0                    none                        []
# 1                    none                        []
# 2                    none                        []
# 3                    none                        []
# 4                    none                        []
# ...                   ...                       ...
# 3562                 none                        []
# 3563                 none                        []
# 3564                 none                        []
# 3565                 none                        []
# 3566                 none                        []
#
#      properties.riskEventTypes_v2     properties.resourceDisplayName  \
# 0                              []  Adobe Identity Management Service
# 1                              []                       Alaya Online
# 2                              []  Adobe Identity Management Service
# 3                              []                         Air Online
# 4                              []  Adobe Identity Management Service
# ...                           ...                                ...
# 3562                           []                  Help Scout Online
# 3563                           []                    Altoura Service
# 3564                           []                                NaN
# 3565                           []          SAP SuccessFactors Online
# 3566                           []                  InStation Service
#
#                      properties.resourceId  \
# 0     abd030d9-bce0-4089-9303-9d46fb13ee16
# 1     2e24cac4-a41a-4c56-ae71-19908dd3372d
# 2     2e24cac4-a41a-4c56-ae71-19908dd3372d
# 3     1f5ea909-535d-450c-a608-299eeff503fb
# 4     5da4c0e4-d642-41ee-b94c-8df5c3178b40
# ...                                    ...
# 3562  7183be3b-1c59-49d7-8a8e-f52bbf852267
# 3563  c5bdd6c7-4dd2-4fd4-8e11-8784d71032b2
# 3564                                   NaN
# 3565  ac60dad2-2d0a-4d4a-bc6d-310224d91df3
# 3566  a3496856-82a4-40f7-a9f1-48129eb0d562
#
#                properties.resourceTenantId  \
# 0     7eea32ba-5081-491b-be43-2b067cb95201
# 1     7eea32ba-5081-491b-be43-2b067cb95201
# 2     7eea32ba-5081-491b-be43-2b067cb95201
# 3     7eea32ba-5081-491b-be43-2b067cb95201
# 4     7eea32ba-5081-491b-be43-2b067cb95201
# ...                                    ...
# 3562  7eea32ba-5081-491b-be43-2b067cb95201
# 3563  7eea32ba-5081-491b-be43-2b067cb95201
# 3564  7eea32ba-5081-491b-be43-2b067cb95201
# 3565  7eea32ba-5081-491b-be43-2b067cb95201
# 3566  7eea32ba-5081-491b-be43-2b067cb95201
#
#                    properties.homeTenantId properties.authenticationDetails  \
# 0     7eea32ba-5081-491b-be43-2b067cb95201                               []
# 1     7eea32ba-5081-491b-be43-2b067cb95201                               []
# 2     7eea32ba-5081-491b-be43-2b067cb95201                               []
# 3     7eea32ba-5081-491b-be43-2b067cb95201                               []
# 4     7eea32ba-5081-491b-be43-2b067cb95201                               []
# ...                                    ...                              ...
# 3562  7eea32ba-5081-491b-be43-2b067cb95201                               []
# 3563  7eea32ba-5081-491b-be43-2b067cb95201                               []
# 3564  7eea32ba-5081-491b-be43-2b067cb95201                               []
# 3565  7eea32ba-5081-491b-be43-2b067cb95201                               []
# 3566  7eea32ba-5081-491b-be43-2b067cb95201                               []
#
#      properties.authenticationRequirementPolicies  \
# 0                                              []
# 1                                              []
# 2                                              []
# 3                                              []
# 4                                              []
# ...                                           ...
# 3562                                           []
# 3563                                           []
# 3564                                           []
# 3565                                           []
# 3566                                           []
#
#      properties.authenticationRequirement properties.servicePrincipalId  \
# 0              singleFactorAuthentication
# 1              singleFactorAuthentication
# 2              singleFactorAuthentication
# 3              singleFactorAuthentication
# 4              singleFactorAuthentication
# ...                                   ...                           ...
# 3562           singleFactorAuthentication
# 3563           singleFactorAuthentication
# 3564           singleFactorAuthentication
# 3565           singleFactorAuthentication
# 3566           singleFactorAuthentication
#
#      properties.userType  properties.flaggedForReview  \
# 0                 Member                        False
# 1                 Member                        False
# 2                 Member                        False
# 3                 Member                        False
# 4                 Member                        False
# ...                  ...                          ...
# 3562              Member                        False
# 3563              Member                        False
# 3564              Member                        False
# 3565              Member                        False
# 3566              Member                        False
#
#       properties.isTenantRestricted  properties.autonomousSystemNumber  \
# 0                             False                              38834
# 1                             False                              11414
# 2                             False                               2510
# 3                             False                               2527
# 4                             False                               7922
# ...                             ...                                ...
# 3562                          False                               7922
# 3563                          False                               7922
# 3564                          False                               7922
# 3565                          False                               7922
# 3566                          False                               7922
#
#      properties.crossTenantAccessType properties.ssoExtensionVersion  \
# 0                                none
# 1                                none
# 2                                none
# 3                                none
# 4                                none
# ...                               ...                            ...
# 3562                             none
# 3563                             none
# 3564                             none
# 3565                             none
# 3566                             none
#
#                       properties.uniqueTokenIdentifier  \
# 0     ZmZjYWNhMTYtNTFjOS00MDY3LTg3MTAtNDAzY2VmYTk3MjAw
# 1     NzE3ZWYwNDMtNDM0Mi00YmVmLWJlM2YtYjFhMjM3OWQ2NjAw
# 2     MTc1NTg5MjktNDE4MS00MGQ0LTk2NDUtN2QyOTMzYzU3NDAw
# 3     Y2IxY2RjNTgtM2QxYS00ZDFhLWFiOWYtMWQ3NzU2MjkxODAw
# 4     MzgxZGM0MmMtMTU4MS00MmMyLThiODEtZWU1ZDc0NDA2YjAw
# ...                                                ...
# 3562  3pfU4RZozewb9cTEXqVMYQPl08gtBWrxaS2CF5NvhydDJnAk
# 3563  ewk6tK3folUpZrNdnaqmWGAT19JYbXIcBF8zHiOQhsLDyRug
# 3564  gB8HVsGqJL6lXr2PWw7xKTdhCcRSkb1UmtFDIpinvjZ5ozaA
# 3565  rub5UvfptLXyHslzj7VJ4WRGaEwBc8Nx2Q9miCFMD1SPg0Ze
# 3566  4Z6mLOyUEhBz2dS0Vp8tugR3CjQ7xiofDwTPa9FbAXclMsIW
#
#      properties.incomingTokenType properties.authenticationProtocol  \
# 0             primaryRefreshToken                              none
# 1             primaryRefreshToken                              none
# 2             primaryRefreshToken                              none
# 3             primaryRefreshToken                              none
# 4             primaryRefreshToken                              none
# ...                           ...                               ...
# 3562          primaryRefreshToken                              none
# 3563          primaryRefreshToken                              none
# 3564          primaryRefreshToken                              none
# 3565          primaryRefreshToken                              none
# 3566          primaryRefreshToken                              none
#
#      properties.appServicePrincipalId properties.resourceServicePrincipalId  \
# 0                                None  a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 1                                None  1f37c851-4be4-455b-928a-fbde7845a68a
# 2                                None  1f37c851-4be4-455b-928a-fbde7845a68a
# 3                                None                                  None
# 4                                None  537d9419-7e2b-4778-9102-62256bcfcf45
# ...                               ...                                   ...
# 3562                             None                                  None
# 3563                             None                                  None
# 3564                             None                                  None
# 3565                             None                                  None
# 3566                             None                                  None
#
#       properties.rngcStatus properties.deviceDetail.isCompliant  \
# 0                       0.0                                 NaN
# 1                       0.0                                 NaN
# 2                       0.0                                 NaN
# 3                       0.0                                 NaN
# 4                       0.0                                 NaN
# ...                     ...                                 ...
# 3562                    NaN                                 NaN
# 3563                    NaN                                 NaN
# 3564                    NaN                                 NaN
# 3565                    NaN                                 NaN
# 3566                    NaN                                 NaN
#
#      properties.deviceDetail.isManaged properties.status.additionalDetails  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# ...                                ...                                 ...
# 3562                               NaN                                 NaN
# 3563                               NaN                                 NaN
# 3564                               NaN                                 NaN
# 3565                               NaN                                 NaN
# 3566                               NaN                                 NaN
#
#      properties.ipAddressFromResourceProvider properties.alternateSignInName  \
# 0                                         NaN                            NaN
# 1                                         NaN                            NaN
# 2                                         NaN                            NaN
# 3                                         NaN                            NaN
# 4                                         NaN                            NaN
# ...                                       ...                            ...
# 3562                           65.209.146.180                            NaN
# 3563                           65.209.146.180                            NaN
# 3564                           65.209.146.180                            NaN
# 3565                           65.209.146.180                            NaN
# 3566                           65.209.146.180                            NaN
#
#      properties.signInIdentifier
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3562                         NaN
# 3563                         NaN
# 3564                         NaN
# 3565                         NaN
# 3566                         NaN
#
# [3567 rows x 81 columns]

# %% [markdown]
# Note that it's important to make sure there is a field that **uniquely identifies** each entity you wish to monitor with DFP.<br>
# E.g. `properties.userPrincipalName` for Azure AD.

# %% [markdown]
# ### 5.2. Overall Statistics <a class="anchor" id="1.6.3"></a>
# Collect global statistics for each feature to rule out bad fits.
#
# - Interesting stats to collect over the entire dataset for each feature:
#     - Unique value count (cardinality)
#     - Percentage of missing values or “null”
#     - Distribution of the unique values

# %%
def json_dumps_keep_null(obj):
    """A wrapper around jsonn.dumps to keep `null` from converted to a string `'null'`."""
    if type(obj) != list and pd.isnull(obj):
        return obj
    return json.dumps(obj)

def collect_overall_stats(data, n_example=3):
    """Take the data and return a dataframe that summarizes the data into stats and example values for each column."""
    overall_stats = []
    total_row_count = len(data)
    for col in data.columns:
        try:
            uniq_values = data[col].unique()
        except:
            # unique() will throw an error if the values in the column are not hashable
            # dump into strings if so
            uniq_values = data[col].apply(json_dumps_keep_null).unique()

        null_ratio = round(data[col].isnull().sum() / total_row_count, 4) # round the numbers to be more readable
        
        # Collect `n_example` examples for each column to include in the result dataframe (non-null values only)
        examples = []
        for val in uniq_values:
            if pd.isnull(val):
                continue
                
            examples.append(val)
            
            if len(examples) >= n_example:
                break
                
        # Pad sentinel values for columns with less than `n_example` unique values
        while len(examples) < n_example:
            examples.append('(empty)')

        overall_stats.append(
            [col, type(data[col][0]).__name__, len(uniq_values), len(uniq_values)/total_row_count, null_ratio, *examples]
        )
        
    result = pd.DataFrame(
        overall_stats, 
        columns=[
            'field', 
            'type', 
            'cardinality', 
            'uniq_ratio', 
            'null_ratio', 
            *[f'example{i+1}' for i in range(n_example)],
        ]
    )
    return result

# %%
pd.set_option('display.max_rows', 200) # ask pandas to display more rows

# %%
overall_stats = collect_overall_stats(data).sort_values(['null_ratio', 'cardinality'], ascending=[True, False]).reset_index(drop=True)

# %%
overall_stats
# Out:
#                                               field      type  cardinality  \
# 0                                              time       str         3567
# 1                        properties.createdDateTime       str         3567
# 2                  properties.uniqueTokenIdentifier       str         3560
# 3                                     correlationId       str         3464
# 4                                     properties.id       str         3460
# 5                      properties.originalRequestId       str         3460
# 6                          properties.correlationId       str         3364
# 7           properties.processingTimeInMilliseconds     int64          310
# 8                                  properties.appId       str           86
# 9                         properties.appDisplayName       str           85
# 10                                  callerIpAddress       str           43
# 11                             properties.ipAddress       str           43
# 12     properties.location.geoCoordinates.longitude   float64           42
# 13      properties.location.geoCoordinates.latitude   float64           41
# 14                 properties.deviceDetail.deviceId       str           37
# 15                         properties.location.city       str           35
# 16                properties.autonomousSystemNumber     int64           27
# 17                                         identity       str           20
# 18                       properties.userDisplayName       str           20
# 19                     properties.userPrincipalName       str           20
# 20                                properties.userId       str           20
# 21                        properties.location.state       str           17
# 22                                       resultType       str           16
# 23                      properties.status.errorCode     int64           16
# 24                                         location       str           12
# 25              properties.location.countryOrRegion       str           12
# 26          properties.deviceDetail.operatingSystem       str            7
# 27               properties.conditionalAccessStatus       str            3
# 28                                         category       str            2
# 29                         properties.isInteractive     bool_            2
# 30     properties.authenticationRequirementPolicies      list            2
# 31             properties.authenticationRequirement       str            2
# 32                     properties.incomingTokenType       str            2
# 33                                       resourceId       str            1
# 34                                    operationName       str            1
# 35                                 operationVersion       str            1
# 36                                         tenantId       str            1
# 37                                  resultSignature       str            1
# 38                                       durationMs     int64            1
# 39                                            Level     int64            1
# 40      properties.appliedConditionalAccessPolicies      list            1
# 41  properties.authenticationContextClassReferences      list            1
# 42                       properties.tokenIssuerName       str            1
# 43                       properties.tokenIssuerType       str            1
# 44       properties.authenticationProcessingDetails      list            1
# 45                properties.networkLocationDetails      list            1
# 46                            properties.riskDetail       str            1
# 47                   properties.riskLevelAggregated       str            1
# 48                 properties.riskLevelDuringSignIn       str            1
# 49                             properties.riskState       str            1
# 50                        properties.riskEventTypes      list            1
# 51                     properties.riskEventTypes_v2      list            1
# 52                      properties.resourceTenantId       str            1
# 53                          properties.homeTenantId       str            1
# 54                 properties.authenticationDetails      list            1
# 55                    properties.servicePrincipalId       str            1
# 56                      properties.flaggedForReview     bool_            1
# 57                    properties.isTenantRestricted     bool_            1
# 58                 properties.crossTenantAccessType       str            1
# 59                   properties.ssoExtensionVersion       str            1
# 60                properties.authenticationProtocol       str            1
# 61                            properties.resourceId       str           89
# 62                         properties.clientAppUsed       str            3
# 63                              properties.userType       str            2
# 64                   properties.resourceDisplayName       str           95
# 65                  properties.deviceDetail.browser       str           36
# 66            properties.resourceServicePrincipalId       str           60
# 67                  properties.clientCredentialType       str            2
# 68                            properties.rngcStatus   float64            2
# 69                             properties.userAgent       str           47
# 70              properties.deviceDetail.displayName       str           19
# 71                properties.deviceDetail.trustType       str            4
# 72                                resultDescription       str           13
# 73                  properties.status.failureReason       str           13
# 74                properties.deviceDetail.isManaged     float            2
# 75              properties.deviceDetail.isCompliant     float            2
# 76              properties.status.additionalDetails     float            5
# 77         properties.ipAddressFromResourceProvider     float           16
# 78                   properties.alternateSignInName     float            5
# 79                      properties.signInIdentifier     float            5
# 80                 properties.appServicePrincipalId  NoneType            1
#
#     uniq_ratio  null_ratio                                           example1  \
# 0     1.000000      0.0000                        2022-08-01T00:06:10.018613Z
# 1     1.000000      0.0000                        2022-08-01T00:06:10.138613Z
# 2     0.998038      0.0000   ZmZjYWNhMTYtNTFjOS00MDY3LTg3MTAtNDAzY2VmYTk3MjAw
# 3     0.971124      0.0000               00cb0df9-b21d-4544-b859-f78ae9e9048b
# 4     0.970003      0.0000               ffcaca16-51c9-4067-8710-403cefa97200
# 5     0.970003      0.0000               ffcaca16-51c9-4067-8710-403cefa97200
# 6     0.943089      0.0000               00cb0df9-b21d-4544-b859-f78ae9e9048b
# 7     0.086908      0.0000                                                120
# 8     0.024110      0.0000               9da0a1ff-e8cf-4513-8520-bf84f723f1ae
# 9     0.023830      0.0000                          Adobe Identity Management
# 10    0.012055      0.0000                                        68.28.66.83
# 11    0.012055      0.0000                                        68.28.66.83
# 12    0.011775      0.0000                                         170.600705
# 13    0.011494      0.0000                                         -49.889482
# 14    0.010373      0.0000               72c565a0-f587-4d5e-9fa9-82cab482ddf0
# 15    0.009812      0.0000                                          Dawnshire
# 16    0.007569      0.0000                                              38834
# 17    0.005607      0.0000                                     Russell Watson
# 18    0.005607      0.0000                                     Russell Watson
# 19    0.005607      0.0000                                 rwatson@domain.com
# 20    0.005607      0.0000               8621535c-c57e-4001-966e-a09ee53372ab
# 21    0.004766      0.0000                                         Sanchezton
# 22    0.004486      0.0000                                              50158
# 23    0.004486      0.0000                                              50158
# 24    0.003364      0.0000                                                 XX
# 25    0.003364      0.0000                                                 XX
# 26    0.001962      0.0000                                         Windows 10
# 27    0.000841      0.0000                                            failure
# 28    0.000561      0.0000                       NonInteractiveUserSignInLogs
# 29    0.000561      0.0000                                              False
# 30    0.000561      0.0000                                                 []
# 31    0.000561      0.0000                         singleFactorAuthentication
# 32    0.000561      0.0000                                primaryRefreshToken
# 33    0.000280      0.0000  /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...
# 34    0.000280      0.0000                                   Sign-in activity
# 35    0.000280      0.0000                                                1.0
# 36    0.000280      0.0000               7eea32ba-5081-491b-be43-2b067cb95201
# 37    0.000280      0.0000                                               None
# 38    0.000280      0.0000                                                  0
# 39    0.000280      0.0000                                                  4
# 40    0.000280      0.0000                                                 []
# 41    0.000280      0.0000                                                 []
# 42    0.000280      0.0000
# 43    0.000280      0.0000                                            AzureAD
# 44    0.000280      0.0000                                                 []
# 45    0.000280      0.0000                                                 []
# 46    0.000280      0.0000                                               none
# 47    0.000280      0.0000                                               none
# 48    0.000280      0.0000                                               none
# 49    0.000280      0.0000                                               none
# 50    0.000280      0.0000                                                 []
# 51    0.000280      0.0000                                                 []
# 52    0.000280      0.0000               7eea32ba-5081-491b-be43-2b067cb95201
# 53    0.000280      0.0000               7eea32ba-5081-491b-be43-2b067cb95201
# 54    0.000280      0.0000                                                 []
# 55    0.000280      0.0000
# 56    0.000280      0.0000                                              False
# 57    0.000280      0.0000                                              False
# 58    0.000280      0.0000                                               none
# 59    0.000280      0.0000
# 60    0.000280      0.0000                                               none
# 61    0.024951      0.0028               abd030d9-bce0-4089-9303-9d46fb13ee16
# 62    0.000841      0.0028                    Mobile Apps and Desktop clients
# 63    0.000561      0.0028                                             Member
# 64    0.026633      0.0053                  Adobe Identity Management Service
# 65    0.010093      0.1847                                      Edge 18.17763
# 66    0.016821      0.2094               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 67    0.000561      0.2372                                               none
# 68    0.000561      0.2372                                                0.0
# 69    0.013176      0.2759  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 70    0.005327      0.3300                                   RUSSELLWATSON-LT
# 71    0.001121      0.3300                             Hybrid Azure AD joined
# 72    0.003645      0.7959     External security challenge was not satisfied.
# 73    0.003645      0.7959     External security challenge was not satisfied.
# 74    0.000561      0.8259                                               True
# 75    0.000561      0.8262                                               True
# 76    0.001402      0.8764    MFA requirement satisfied by claim in the token
# 77    0.004486      0.9111                                      186.223.69.56
# 78    0.001402      0.9913                                mdunlap1@domain.com
# 79    0.001402      0.9913                                mdunlap1@domain.com
# 80    0.000280      1.0000                                            (empty)
#
#                                              example2  \
# 0                         2022-08-01T00:12:41.855581Z
# 1                         2022-08-01T00:12:42.005581Z
# 2    NzE3ZWYwNDMtNDM0Mi00YmVmLWJlM2YtYjFhMjM3OWQ2NjAw
# 3                044e431d-93e2-415d-9fb5-2936a1a7ec3c
# 4                717ef043-4342-4bef-be3f-b1a2379d6600
# 5                717ef043-4342-4bef-be3f-b1a2379d6600
# 6                044e431d-93e2-415d-9fb5-2936a1a7ec3c
# 7                                                 150
# 8                890fda57-180f-472a-8838-ad79f06ad863
# 9                                               Alaya
# 10                                     38.185.182.132
# 11                                     38.185.182.132
# 12                                           5.176877
# 13                                           6.915915
# 14               15135d1f-cb47-4bd8-b76d-90a9171c09bd
# 15                                          East Kara
# 16                                              11414
# 17                                      Stephen White
# 18                                      Stephen White
# 19                                  swhite@domain.com
# 20               e79f7294-f107-4e74-95d5-53a6521bc624
# 21                                          Amberland
# 22                                                  0
# 23                                                  0
# 24                                                 XK
# 25                                                 XK
# 26                                          Windows10
# 27                                            success
# 28                                         SignInLogs
# 29                                               True
# 30  [{"requirementProvider": "request", "detail": ...
# 31                          multiFactorAuthentication
# 32                                               none
# 33                                            (empty)
# 34                                            (empty)
# 35                                            (empty)
# 36                                            (empty)
# 37                                            (empty)
# 38                                            (empty)
# 39                                            (empty)
# 40                                            (empty)
# 41                                            (empty)
# 42                                            (empty)
# 43                                            (empty)
# 44                                            (empty)
# 45                                            (empty)
# 46                                            (empty)
# 47                                            (empty)
# 48                                            (empty)
# 49                                            (empty)
# 50                                            (empty)
# 51                                            (empty)
# 52                                            (empty)
# 53                                            (empty)
# 54                                            (empty)
# 55                                            (empty)
# 56                                            (empty)
# 57                                            (empty)
# 58                                            (empty)
# 59                                            (empty)
# 60                                            (empty)
# 61               2e24cac4-a41a-4c56-ae71-19908dd3372d
# 62                                            Browser
# 63                                            (empty)
# 64                                       Alaya Online
# 65                                      Edge 18.19043
# 66               1f37c851-4be4-455b-928a-fbde7845a68a
# 67                                            (empty)
# 68                                            (empty)
# 69  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 70                                    STEPHENWHITE-LT
# 71                                Azure AD registered
# 72  User needs to enroll for second factor authent...
# 73  User needs to enroll for second factor authent...
# 74                                            (empty)
# 75                                            (empty)
# 76                           MFA required in Azure AD
# 77                                      216.72.23.109
# 78                                swilson1@domain.com
# 79                                swilson1@domain.com
# 80                                            (empty)
#
#                                              example3
# 0                         2022-08-01T00:29:13.018517Z
# 1                         2022-08-01T00:29:13.114517Z
# 2    MTc1NTg5MjktNDE4MS00MGQ0LTk2NDUtN2QyOTMzYzU3NDAw
# 3                778307c7-9801-4873-bb5e-a8adba9f8bb2
# 4                17558929-4181-40d4-9645-7d2933c57400
# 5                17558929-4181-40d4-9645-7d2933c57400
# 6                778307c7-9801-4873-bb5e-a8adba9f8bb2
# 7                                                  96
# 8                0f834804-f0dc-4fef-b3f5-be308ac60f9f
# 9                                                 Air
# 10                                      185.25.177.84
# 11                                      185.25.177.84
# 12                                        -178.150039
# 13                                         -38.158813
# 14               639815fd-5018-4e38-9d81-67538b2ce460
# 15                                        Port Robert
# 16                                               2510
# 17                                      Amber Estrada
# 18                                      Amber Estrada
# 19                                aestrada@domain.com
# 20               c0c2d7f1-4a8a-4a76-b687-ba2d2001a545
# 21                                          Jesusland
# 22                                              50079
# 23                                              50079
# 24                                                 XS
# 25                                                 XS
# 26                                            Windows
# 27                                         notApplied
# 28                                            (empty)
# 29                                            (empty)
# 30                                            (empty)
# 31                                            (empty)
# 32                                            (empty)
# 33                                            (empty)
# 34                                            (empty)
# 35                                            (empty)
# 36                                            (empty)
# 37                                            (empty)
# 38                                            (empty)
# 39                                            (empty)
# 40                                            (empty)
# 41                                            (empty)
# 42                                            (empty)
# 43                                            (empty)
# 44                                            (empty)
# 45                                            (empty)
# 46                                            (empty)
# 47                                            (empty)
# 48                                            (empty)
# 49                                            (empty)
# 50                                            (empty)
# 51                                            (empty)
# 52                                            (empty)
# 53                                            (empty)
# 54                                            (empty)
# 55                                            (empty)
# 56                                            (empty)
# 57                                            (empty)
# 58                                            (empty)
# 59                                            (empty)
# 60                                            (empty)
# 61               1f5ea909-535d-450c-a608-299eeff503fb
# 62                                            (empty)
# 63                                            (empty)
# 64                                         Air Online
# 65                                      Edge 18.18363
# 66               537d9419-7e2b-4778-9102-62256bcfcf45
# 67                                            (empty)
# 68                                            (empty)
# 69  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 70                                    AMBERESTRADA-LT
# 71                                    Azure AD joined
# 72                                              Other
# 73                                              Other
# 74                                            (empty)
# 75                                            (empty)
# 76                          MFA completed in Azure AD
# 77                                    103.174.219.227
# 78                                 tlopez1@domain.com
# 79                                 tlopez1@domain.com
# 80                                            (empty)

# %% [markdown]
# Definition of `null`: NaN in numeric arrays, None or NaN in object arrays, NaT in datetimelike<br>
# Note. Unique count includes null values

# %% [markdown]
# #### 5.2.1 Signs of a bad feature<a class="anchor" id="1.6.3.1"></a>
# #### High Cardinality
# Each row has a unique value (cardinality/(# of all data points) ≅ 1)<br>
# E.g.: Log ID (correlationId) that uniquely identifies each log entry

# %%
overall_stats.loc[overall_stats.uniq_ratio > 0.95]
# Out:
#                               field type  cardinality  uniq_ratio  null_ratio  \
# 0                              time  str         3567    1.000000         0.0
# 1        properties.createdDateTime  str         3567    1.000000         0.0
# 2  properties.uniqueTokenIdentifier  str         3560    0.998038         0.0
# 3                     correlationId  str         3464    0.971124         0.0
# 4                     properties.id  str         3460    0.970003         0.0
# 5      properties.originalRequestId  str         3460    0.970003         0.0
#
#                                            example1  \
# 0                       2022-08-01T00:06:10.018613Z
# 1                       2022-08-01T00:06:10.138613Z
# 2  ZmZjYWNhMTYtNTFjOS00MDY3LTg3MTAtNDAzY2VmYTk3MjAw
# 3              00cb0df9-b21d-4544-b859-f78ae9e9048b
# 4              ffcaca16-51c9-4067-8710-403cefa97200
# 5              ffcaca16-51c9-4067-8710-403cefa97200
#
#                                            example2  \
# 0                       2022-08-01T00:12:41.855581Z
# 1                       2022-08-01T00:12:42.005581Z
# 2  NzE3ZWYwNDMtNDM0Mi00YmVmLWJlM2YtYjFhMjM3OWQ2NjAw
# 3              044e431d-93e2-415d-9fb5-2936a1a7ec3c
# 4              717ef043-4342-4bef-be3f-b1a2379d6600
# 5              717ef043-4342-4bef-be3f-b1a2379d6600
#
#                                            example3
# 0                       2022-08-01T00:29:13.018517Z
# 1                       2022-08-01T00:29:13.114517Z
# 2  MTc1NTg5MjktNDE4MS00MGQ0LTk2NDUtN2QyOTMzYzU3NDAw
# 3              778307c7-9801-4873-bb5e-a8adba9f8bb2
# 4              17558929-4181-40d4-9645-7d2933c57400
# 5              17558929-4181-40d4-9645-7d2933c57400

# %% [markdown]
# Fields with constantly changing values are not good candidates as a feature as there isn't much predictability.

# %% [markdown]
# #### Low Cardinality
# All rows share the same value ( cardinality ≅ 1 )<br>
# E.g.: tenantId if all logs are coming from the same tenant<br>

# %%
# excluding bool columns, as they'll by default have a low cardinality. Their usefulness needs to be determined by the security context they carry.
overall_stats.loc[(overall_stats.cardinality <= 3) & (overall_stats.type != 'bool')]
# Out:
#                                               field      type  cardinality  \
# 27               properties.conditionalAccessStatus       str            3
# 28                                         category       str            2
# 29                         properties.isInteractive     bool_            2
# 30     properties.authenticationRequirementPolicies      list            2
# 31             properties.authenticationRequirement       str            2
# 32                     properties.incomingTokenType       str            2
# 33                                       resourceId       str            1
# 34                                    operationName       str            1
# 35                                 operationVersion       str            1
# 36                                         tenantId       str            1
# 37                                  resultSignature       str            1
# 38                                       durationMs     int64            1
# 39                                            Level     int64            1
# 40      properties.appliedConditionalAccessPolicies      list            1
# 41  properties.authenticationContextClassReferences      list            1
# 42                       properties.tokenIssuerName       str            1
# 43                       properties.tokenIssuerType       str            1
# 44       properties.authenticationProcessingDetails      list            1
# 45                properties.networkLocationDetails      list            1
# 46                            properties.riskDetail       str            1
# 47                   properties.riskLevelAggregated       str            1
# 48                 properties.riskLevelDuringSignIn       str            1
# 49                             properties.riskState       str            1
# 50                        properties.riskEventTypes      list            1
# 51                     properties.riskEventTypes_v2      list            1
# 52                      properties.resourceTenantId       str            1
# 53                          properties.homeTenantId       str            1
# 54                 properties.authenticationDetails      list            1
# 55                    properties.servicePrincipalId       str            1
# 56                      properties.flaggedForReview     bool_            1
# 57                    properties.isTenantRestricted     bool_            1
# 58                 properties.crossTenantAccessType       str            1
# 59                   properties.ssoExtensionVersion       str            1
# 60                properties.authenticationProtocol       str            1
# 62                         properties.clientAppUsed       str            3
# 63                              properties.userType       str            2
# 67                  properties.clientCredentialType       str            2
# 68                            properties.rngcStatus   float64            2
# 74                properties.deviceDetail.isManaged     float            2
# 75              properties.deviceDetail.isCompliant     float            2
# 80                 properties.appServicePrincipalId  NoneType            1
#
#     uniq_ratio  null_ratio                                           example1  \
# 27    0.000841      0.0000                                            failure
# 28    0.000561      0.0000                       NonInteractiveUserSignInLogs
# 29    0.000561      0.0000                                              False
# 30    0.000561      0.0000                                                 []
# 31    0.000561      0.0000                         singleFactorAuthentication
# 32    0.000561      0.0000                                primaryRefreshToken
# 33    0.000280      0.0000  /tenants/7eea32ba-5081-491b-be43-2b067cb95201/...
# 34    0.000280      0.0000                                   Sign-in activity
# 35    0.000280      0.0000                                                1.0
# 36    0.000280      0.0000               7eea32ba-5081-491b-be43-2b067cb95201
# 37    0.000280      0.0000                                               None
# 38    0.000280      0.0000                                                  0
# 39    0.000280      0.0000                                                  4
# 40    0.000280      0.0000                                                 []
# 41    0.000280      0.0000                                                 []
# 42    0.000280      0.0000
# 43    0.000280      0.0000                                            AzureAD
# 44    0.000280      0.0000                                                 []
# 45    0.000280      0.0000                                                 []
# 46    0.000280      0.0000                                               none
# 47    0.000280      0.0000                                               none
# 48    0.000280      0.0000                                               none
# 49    0.000280      0.0000                                               none
# 50    0.000280      0.0000                                                 []
# 51    0.000280      0.0000                                                 []
# 52    0.000280      0.0000               7eea32ba-5081-491b-be43-2b067cb95201
# 53    0.000280      0.0000               7eea32ba-5081-491b-be43-2b067cb95201
# 54    0.000280      0.0000                                                 []
# 55    0.000280      0.0000
# 56    0.000280      0.0000                                              False
# 57    0.000280      0.0000                                              False
# 58    0.000280      0.0000                                               none
# 59    0.000280      0.0000
# 60    0.000280      0.0000                                               none
# 62    0.000841      0.0028                    Mobile Apps and Desktop clients
# 63    0.000561      0.0028                                             Member
# 67    0.000561      0.2372                                               none
# 68    0.000561      0.2372                                                0.0
# 74    0.000561      0.8259                                               True
# 75    0.000561      0.8262                                               True
# 80    0.000280      1.0000                                            (empty)
#
#                                              example2    example3
# 27                                            success  notApplied
# 28                                         SignInLogs     (empty)
# 29                                               True     (empty)
# 30  [{"requirementProvider": "request", "detail": ...     (empty)
# 31                          multiFactorAuthentication     (empty)
# 32                                               none     (empty)
# 33                                            (empty)     (empty)
# 34                                            (empty)     (empty)
# 35                                            (empty)     (empty)
# 36                                            (empty)     (empty)
# 37                                            (empty)     (empty)
# 38                                            (empty)     (empty)
# 39                                            (empty)     (empty)
# 40                                            (empty)     (empty)
# 41                                            (empty)     (empty)
# 42                                            (empty)     (empty)
# 43                                            (empty)     (empty)
# 44                                            (empty)     (empty)
# 45                                            (empty)     (empty)
# 46                                            (empty)     (empty)
# 47                                            (empty)     (empty)
# 48                                            (empty)     (empty)
# 49                                            (empty)     (empty)
# 50                                            (empty)     (empty)
# 51                                            (empty)     (empty)
# 52                                            (empty)     (empty)
# 53                                            (empty)     (empty)
# 54                                            (empty)     (empty)
# 55                                            (empty)     (empty)
# 56                                            (empty)     (empty)
# 57                                            (empty)     (empty)
# 58                                            (empty)     (empty)
# 59                                            (empty)     (empty)
# 60                                            (empty)     (empty)
# 62                                            Browser     (empty)
# 63                                            (empty)     (empty)
# 67                                            (empty)     (empty)
# 68                                            (empty)     (empty)
# 74                                            (empty)     (empty)
# 75                                            (empty)     (empty)
# 80                                            (empty)     (empty)

# %% [markdown]
# Note that `cardinality` here includes `null` values too, so fields with one possible value + `null` will have 2 as the cardinality.

# %% [markdown]
# #### Mostly Null
# Most values are Null ( (# of  null values)/(# of all data points) ≅ 1)<br>
# Might be a redundant/non-populated field that does not provide much information<br>
# ! Beware that sometimes "None" can be in the string format and bypass the `pd.isnull` check

# %%
overall_stats.loc[overall_stats.null_ratio > 0.9]
# Out:
#                                        field      type  cardinality  \
# 77  properties.ipAddressFromResourceProvider     float           16
# 78            properties.alternateSignInName     float            5
# 79               properties.signInIdentifier     float            5
# 80          properties.appServicePrincipalId  NoneType            1
#
#     uniq_ratio  null_ratio             example1             example2  \
# 77    0.004486      0.9111        186.223.69.56        216.72.23.109
# 78    0.001402      0.9913  mdunlap1@domain.com  swilson1@domain.com
# 79    0.001402      0.9913  mdunlap1@domain.com  swilson1@domain.com
# 80    0.000280      1.0000              (empty)              (empty)
#
#               example3
# 77     103.174.219.227
# 78  tlopez1@domain.com
# 79  tlopez1@domain.com
# 80             (empty)

# %% [markdown]
# #### 5.2.2 Good feature candidates<a class="anchor" id="1.6.3.5"></a>
# The thresholds used here are just for demonstration. They can be tuned to suit your data and your requirements better.

# %%
good_feat_candidate_criteria = (
    (overall_stats.uniq_ratio < 0.95)
    & ~((overall_stats.cardinality <= 3) & (overall_stats.type != 'bool'))
    & (overall_stats.null_ratio < 0.9)
)
feature_candidates = overall_stats.loc[good_feat_candidate_criteria]

# %%
print(f'Number of all columns: {len(overall_stats)}\nPotential feature candidate count: {len(feature_candidates)}')
# Out:
# Number of all columns: 81
# Potential feature candidate count: 31

# %%
feature_candidates
# Out:
#                                            field     type  cardinality  \
# 6                       properties.correlationId      str         3364
# 7        properties.processingTimeInMilliseconds    int64          310
# 8                               properties.appId      str           86
# 9                      properties.appDisplayName      str           85
# 10                               callerIpAddress      str           43
# 11                          properties.ipAddress      str           43
# 12  properties.location.geoCoordinates.longitude  float64           42
# 13   properties.location.geoCoordinates.latitude  float64           41
# 14              properties.deviceDetail.deviceId      str           37
# 15                      properties.location.city      str           35
# 16             properties.autonomousSystemNumber    int64           27
# 17                                      identity      str           20
# 18                    properties.userDisplayName      str           20
# 19                  properties.userPrincipalName      str           20
# 20                             properties.userId      str           20
# 21                     properties.location.state      str           17
# 22                                    resultType      str           16
# 23                   properties.status.errorCode    int64           16
# 24                                      location      str           12
# 25           properties.location.countryOrRegion      str           12
# 26       properties.deviceDetail.operatingSystem      str            7
# 61                         properties.resourceId      str           89
# 64                properties.resourceDisplayName      str           95
# 65               properties.deviceDetail.browser      str           36
# 66         properties.resourceServicePrincipalId      str           60
# 69                          properties.userAgent      str           47
# 70           properties.deviceDetail.displayName      str           19
# 71             properties.deviceDetail.trustType      str            4
# 72                             resultDescription      str           13
# 73               properties.status.failureReason      str           13
# 76           properties.status.additionalDetails    float            5
#
#     uniq_ratio  null_ratio                                           example1  \
# 6     0.943089      0.0000               00cb0df9-b21d-4544-b859-f78ae9e9048b
# 7     0.086908      0.0000                                                120
# 8     0.024110      0.0000               9da0a1ff-e8cf-4513-8520-bf84f723f1ae
# 9     0.023830      0.0000                          Adobe Identity Management
# 10    0.012055      0.0000                                        68.28.66.83
# 11    0.012055      0.0000                                        68.28.66.83
# 12    0.011775      0.0000                                         170.600705
# 13    0.011494      0.0000                                         -49.889482
# 14    0.010373      0.0000               72c565a0-f587-4d5e-9fa9-82cab482ddf0
# 15    0.009812      0.0000                                          Dawnshire
# 16    0.007569      0.0000                                              38834
# 17    0.005607      0.0000                                     Russell Watson
# 18    0.005607      0.0000                                     Russell Watson
# 19    0.005607      0.0000                                 rwatson@domain.com
# 20    0.005607      0.0000               8621535c-c57e-4001-966e-a09ee53372ab
# 21    0.004766      0.0000                                         Sanchezton
# 22    0.004486      0.0000                                              50158
# 23    0.004486      0.0000                                              50158
# 24    0.003364      0.0000                                                 XX
# 25    0.003364      0.0000                                                 XX
# 26    0.001962      0.0000                                         Windows 10
# 61    0.024951      0.0028               abd030d9-bce0-4089-9303-9d46fb13ee16
# 64    0.026633      0.0053                  Adobe Identity Management Service
# 65    0.010093      0.1847                                      Edge 18.17763
# 66    0.016821      0.2094               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 69    0.013176      0.2759  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 70    0.005327      0.3300                                   RUSSELLWATSON-LT
# 71    0.001121      0.3300                             Hybrid Azure AD joined
# 72    0.003645      0.7959     External security challenge was not satisfied.
# 73    0.003645      0.7959     External security challenge was not satisfied.
# 76    0.001402      0.8764    MFA requirement satisfied by claim in the token
#
#                                              example2  \
# 6                044e431d-93e2-415d-9fb5-2936a1a7ec3c
# 7                                                 150
# 8                890fda57-180f-472a-8838-ad79f06ad863
# 9                                               Alaya
# 10                                     38.185.182.132
# 11                                     38.185.182.132
# 12                                           5.176877
# 13                                           6.915915
# 14               15135d1f-cb47-4bd8-b76d-90a9171c09bd
# 15                                          East Kara
# 16                                              11414
# 17                                      Stephen White
# 18                                      Stephen White
# 19                                  swhite@domain.com
# 20               e79f7294-f107-4e74-95d5-53a6521bc624
# 21                                          Amberland
# 22                                                  0
# 23                                                  0
# 24                                                 XK
# 25                                                 XK
# 26                                          Windows10
# 61               2e24cac4-a41a-4c56-ae71-19908dd3372d
# 64                                       Alaya Online
# 65                                      Edge 18.19043
# 66               1f37c851-4be4-455b-928a-fbde7845a68a
# 69  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 70                                    STEPHENWHITE-LT
# 71                                Azure AD registered
# 72  User needs to enroll for second factor authent...
# 73  User needs to enroll for second factor authent...
# 76                           MFA required in Azure AD
#
#                                              example3
# 6                778307c7-9801-4873-bb5e-a8adba9f8bb2
# 7                                                  96
# 8                0f834804-f0dc-4fef-b3f5-be308ac60f9f
# 9                                                 Air
# 10                                      185.25.177.84
# 11                                      185.25.177.84
# 12                                        -178.150039
# 13                                         -38.158813
# 14               639815fd-5018-4e38-9d81-67538b2ce460
# 15                                        Port Robert
# 16                                               2510
# 17                                      Amber Estrada
# 18                                      Amber Estrada
# 19                                aestrada@domain.com
# 20               c0c2d7f1-4a8a-4a76-b687-ba2d2001a545
# 21                                          Jesusland
# 22                                              50079
# 23                                              50079
# 24                                                 XS
# 25                                                 XS
# 26                                            Windows
# 61               1f5ea909-535d-450c-a608-299eeff503fb
# 64                                         Air Online
# 65                                      Edge 18.18363
# 66               537d9419-7e2b-4778-9102-62256bcfcf45
# 69  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 70                                    AMBERESTRADA-LT
# 71                                    Azure AD joined
# 72                                              Other
# 73                                              Other
# 76                          MFA completed in Azure AD

# %% [markdown]
# Now we can double-check if these are good candidates under the per-entity scope.

# %% [markdown]
# ### 5.3. Per-entity Statistics<a class="anchor" id="1.6.4"></a>
# Collect entity-level statistics for each feature to further evaluate their “usefulness”.

# %%
def get_data_with_selected_features(data, features):
    """Return a new dataframe with only the selected features and json dumps the unhashable fields for `nunique` to work."""
    data_candidate_cols = pd.DataFrame()
    for col in features:
        # json dumps the array fields
        try:
            data[col].nunique()
            data_candidate_cols[col] = data[col]
        except:
            data_candidate_cols[col] = data[col].apply(json_dumps_keep_null)
    return data_candidate_cols

def get_entity_feature_cardinality(data, entity_id_field, trainable_user_activity_limit=100):
    """Return a dataframe of the per-entity cardinality (unique count) of each feature, including only the entities with enough activity to be "trainable" by DFP. 
    (DFP doesn't train a model for entities with little activity. Instead, it uses a shared model for the light-traffic entities.)
    """
    kwargs = {col: (col, 'nunique') for col in data.columns if col != entity_id_field}
    kwargs['count'] = (data.columns[0], 'count')
    per_entity_nunique_all = data.groupby(entity_id_field).agg(**kwargs).reset_index()
    
    per_entity_nunique = per_entity_nunique_all.loc[per_entity_nunique_all['count'] > trainable_user_activity_limit]
    return per_entity_nunique

def get_entity_feature_null_ratio(data, entity_id_field, trainable_user_activity_limit=100):
    """Return a dataframe of the per-entity null ratio of each feature, including only the entities with enough activity to be "trainable" by DFP. 
    (DFP doesn't train a model for entities with little activity. Instead, it uses a shared model for the light-traffic entities.)
    """
    data_with_null_eval = data.join(data.isnull(), rsuffix='_isnull')
    kwargs = {f'{col}': (f'{col}_isnull', 'sum') for col in data.columns if col != entity_id_field}
    kwargs['count'] = (data.columns[0], 'count')
    per_entity_null_count_all = data_with_null_eval.groupby(entity_id_field).agg(**kwargs).reset_index()
    per_entity_null_count = per_entity_null_count_all.loc[per_entity_null_count_all['count'] > trainable_user_activity_limit]
    
    # calculate null ratio
    per_entity_null_ratio = pd.DataFrame()
    per_entity_null_ratio[entity_id_field] = per_entity_null_count[entity_id_field]
    for col in per_entity_null_count.columns:
        if col == entity_id_field or col == 'count':
            continue
        per_entity_null_ratio[col] = per_entity_null_count[col] / per_entity_null_count['count']
    
    return per_entity_null_ratio

def get_feature_per_entity_stats(entity_feature_cardinality, entity_feature_null_ratio, entity_id_field):
    """ Given the cardinality and the null ratio of each feature, return a summary dataframe of the per-entity stats for each feature.
    """
    stat_types = ['max', 'med', 'mean', 'min']
    stat_funcs = [max, np.median, np.mean, min]
    
    per_user_feature_dist = []
    for col in entity_feature_cardinality.columns:
        if col == entity_id_field or col == 'count':
            continue

        vals = entity_feature_cardinality[col]
        uniq_ratios = vals / entity_feature_cardinality['count']
        null_ratios = entity_feature_null_ratio[col]
        
        
        per_user_feature_dist.append([
            col,
            # cardinality
            *[func(vals) for func in stat_funcs],
            # unique ratio
            *[func(uniq_ratios) for func in stat_funcs],
            # null ratio
            *[func(null_ratios) for func in stat_funcs],
        ])

    return pd.DataFrame(
        data=per_user_feature_dist, 
        columns=[
            'field', 
            *[f'cardinality_{stat}' for stat in stat_types], 
            *[f'uniq_ratio_{stat}' for stat in stat_types],
            *[f'null_ratio_{stat}' for stat in stat_types],
        ]
    ).sort_values('cardinality_med', ascending=False).reset_index(drop=True)

# %%
data_candidate_cols = get_data_with_selected_features(data, feature_candidates.field)
user_feature_cardinality = get_entity_feature_cardinality(data_candidate_cols, entity_id_field='properties.userPrincipalName')
user_feature_null_ratio = get_entity_feature_null_ratio(data_candidate_cols, entity_id_field='properties.userPrincipalName')
per_entity_stats = get_feature_per_entity_stats(user_feature_cardinality, user_feature_null_ratio, entity_id_field='properties.userPrincipalName')

# %%
per_entity_stats
# Out:
#                                            field  cardinality_max  \
# 0                       properties.correlationId              523
# 1        properties.processingTimeInMilliseconds              149
# 2                          properties.resourceId               51
# 3          properties.resourceServicePrincipalId               39
# 4                 properties.resourceDisplayName               83
# 5                               properties.appId               85
# 6                      properties.appDisplayName               85
# 7                properties.deviceDetail.browser               16
# 8                           properties.userAgent                8
# 9        properties.deviceDetail.operatingSystem                5
# 10                               callerIpAddress               11
# 11                          properties.ipAddress               11
# 12  properties.location.geoCoordinates.longitude               11
# 13   properties.location.geoCoordinates.latitude               10
# 14                   properties.status.errorCode                8
# 15                                    resultType                8
# 16             properties.autonomousSystemNumber                7
# 17                      properties.location.city               10
# 18              properties.deviceDetail.deviceId               14
# 19                     properties.location.state                5
# 20                                      location                4
# 21           properties.location.countryOrRegion                4
# 22                             properties.userId                1
# 23                    properties.userDisplayName                1
# 24                                      identity                1
# 25           properties.deviceDetail.displayName                1
# 26             properties.deviceDetail.trustType                2
# 27                             resultDescription                7
# 28               properties.status.failureReason                7
# 29           properties.status.additionalDetails                4
#
#     cardinality_med  cardinality_mean  cardinality_min  uniq_ratio_max  \
# 0             131.0        220.866667              118        1.000000
# 1              76.0         92.933333               65        0.614815
# 2              31.0         31.800000               22        0.269231
# 3              23.0         22.600000               10        0.222222
# 4              21.0         26.666667               14        0.192308
# 5              20.0         25.400000               13        0.192308
# 6              20.0         25.333333               13        0.192308
# 7               7.0          7.933333                3        0.083333
# 8               5.0          5.133333                3        0.060606
# 9               4.0          3.666667                2        0.037037
# 10              3.0          3.333333                1        0.030769
# 11              3.0          3.333333                1        0.030769
# 12              3.0          3.400000                1        0.038462
# 13              3.0          3.333333                1        0.038462
# 14              2.0          3.133333                1        0.030769
# 15              2.0          3.133333                1        0.030769
# 16              2.0          2.466667                1        0.023077
# 17              2.0          3.066667                1        0.030769
# 18              2.0          3.066667                1        0.030769
# 19              1.0          1.800000                1        0.022901
# 20              1.0          1.600000                1        0.022901
# 21              1.0          1.600000                1        0.022901
# 22              1.0          1.000000                1        0.007752
# 23              1.0          1.000000                1        0.007752
# 24              1.0          1.000000                1        0.007752
# 25              1.0          0.933333                0        0.007752
# 26              1.0          1.133333                0        0.015385
# 27              1.0          2.066667                0        0.023077
# 28              1.0          2.066667                0        0.023077
# 29              0.0          0.533333                0        0.012539
#
#     uniq_ratio_med  uniq_ratio_mean  uniq_ratio_min  null_ratio_max  \
# 0         0.977778         0.959198        0.792829        0.000000
# 1         0.521739         0.473558        0.228571        0.000000
# 2         0.195652         0.180401        0.043810        0.023077
# 3         0.159420         0.134885        0.019920        0.468889
# 4         0.146154         0.136353        0.028571        0.023077
# 5         0.141066         0.129644        0.028571        0.000000
# 6         0.137931         0.129435        0.028571        0.000000
# 7         0.050157         0.045370        0.005976        0.857778
# 8         0.030534         0.029079        0.005976        0.911111
# 9         0.028986         0.021992        0.003984        0.000000
# 10        0.015504         0.016513        0.003984        0.000000
# 11        0.015504         0.016513        0.003984        0.000000
# 12        0.015385         0.016661        0.005976        0.000000
# 13        0.015385         0.016534        0.005976        0.000000
# 14        0.015152         0.014927        0.001992        0.000000
# 15        0.015152         0.014927        0.001992        0.000000
# 16        0.015152         0.013084        0.001992        0.000000
# 17        0.015385         0.014851        0.004444        0.000000
# 18        0.015267         0.015237        0.003984        0.000000
# 19        0.007634         0.008491        0.002506        0.000000
# 20        0.007634         0.008028        0.002506        0.000000
# 21        0.007634         0.008028        0.002506        0.000000
# 22        0.007576         0.005848        0.001905        0.000000
# 23        0.007576         0.005848        0.001905        0.000000
# 24        0.007576         0.005848        0.001905        0.000000
# 25        0.007407         0.005343        0.000000        1.000000
# 26        0.007634         0.006466        0.000000        1.000000
# 27        0.007634         0.008952        0.000000        1.000000
# 28        0.007634         0.008952        0.000000        1.000000
# 29        0.000000         0.002542        0.000000        1.000000
#
#     null_ratio_med  null_ratio_mean  null_ratio_min
# 0         0.000000         0.000000        0.000000
# 1         0.000000         0.000000        0.000000
# 2         0.000000         0.002601        0.000000
# 3         0.189394         0.201239        0.013333
# 4         0.000000         0.004945        0.000000
# 5         0.000000         0.000000        0.000000
# 6         0.000000         0.000000        0.000000
# 7         0.083969         0.160483        0.003984
# 8         0.206107         0.252868        0.000000
# 9         0.000000         0.000000        0.000000
# 10        0.000000         0.000000        0.000000
# 11        0.000000         0.000000        0.000000
# 12        0.000000         0.000000        0.000000
# 13        0.000000         0.000000        0.000000
# 14        0.000000         0.000000        0.000000
# 15        0.000000         0.000000        0.000000
# 16        0.000000         0.000000        0.000000
# 17        0.000000         0.000000        0.000000
# 18        0.000000         0.000000        0.000000
# 19        0.000000         0.000000        0.000000
# 20        0.000000         0.000000        0.000000
# 21        0.000000         0.000000        0.000000
# 22        0.000000         0.000000        0.000000
# 23        0.000000         0.000000        0.000000
# 24        0.000000         0.000000        0.000000
# 25        0.107692         0.276595        0.000000
# 26        0.107692         0.276595        0.000000
# 27        0.961538         0.860190        0.057143
# 28        0.961538         0.860190        0.057143
# 29        1.000000         0.858408        0.015504

# %% [markdown]
# We can see that some features look less promising at the per-entity level. The same set of criteria can be reused here to evaluate whether a feature should be included as a candidate or not:
# - High cardinality (each row has a unique value, i.e. high uniqueness)
# - Low cardinality (all rows share 1 or 2 constant values)
# - High null ratio

# %% [markdown]
# #### 5.3.1 Good feature candidates<a class="anchor" id="1.6.4.1"></a>
# The thresholds used here are just for demonstration. They can be tuned to suit your data and your requirements better.

# %%
per_entity_stats.columns = per_entity_stats.columns.map(lambda col: f'per_ent_{col}' if col != 'field' else 'field')
feature_stats = feature_candidates.merge(per_entity_stats, on='field')  # merge overall and per-entity stats

# %%
feature_stats
# Out:
#                                            field     type  cardinality  \
# 0                       properties.correlationId      str         3364
# 1        properties.processingTimeInMilliseconds    int64          310
# 2                               properties.appId      str           86
# 3                      properties.appDisplayName      str           85
# 4                                callerIpAddress      str           43
# 5                           properties.ipAddress      str           43
# 6   properties.location.geoCoordinates.longitude  float64           42
# 7    properties.location.geoCoordinates.latitude  float64           41
# 8               properties.deviceDetail.deviceId      str           37
# 9                       properties.location.city      str           35
# 10             properties.autonomousSystemNumber    int64           27
# 11                                      identity      str           20
# 12                    properties.userDisplayName      str           20
# 13                             properties.userId      str           20
# 14                     properties.location.state      str           17
# 15                                    resultType      str           16
# 16                   properties.status.errorCode    int64           16
# 17                                      location      str           12
# 18           properties.location.countryOrRegion      str           12
# 19       properties.deviceDetail.operatingSystem      str            7
# 20                         properties.resourceId      str           89
# 21                properties.resourceDisplayName      str           95
# 22               properties.deviceDetail.browser      str           36
# 23         properties.resourceServicePrincipalId      str           60
# 24                          properties.userAgent      str           47
# 25           properties.deviceDetail.displayName      str           19
# 26             properties.deviceDetail.trustType      str            4
# 27                             resultDescription      str           13
# 28               properties.status.failureReason      str           13
# 29           properties.status.additionalDetails    float            5
#
#     uniq_ratio  null_ratio                                           example1  \
# 0     0.943089      0.0000               00cb0df9-b21d-4544-b859-f78ae9e9048b
# 1     0.086908      0.0000                                                120
# 2     0.024110      0.0000               9da0a1ff-e8cf-4513-8520-bf84f723f1ae
# 3     0.023830      0.0000                          Adobe Identity Management
# 4     0.012055      0.0000                                        68.28.66.83
# 5     0.012055      0.0000                                        68.28.66.83
# 6     0.011775      0.0000                                         170.600705
# 7     0.011494      0.0000                                         -49.889482
# 8     0.010373      0.0000               72c565a0-f587-4d5e-9fa9-82cab482ddf0
# 9     0.009812      0.0000                                          Dawnshire
# 10    0.007569      0.0000                                              38834
# 11    0.005607      0.0000                                     Russell Watson
# 12    0.005607      0.0000                                     Russell Watson
# 13    0.005607      0.0000               8621535c-c57e-4001-966e-a09ee53372ab
# 14    0.004766      0.0000                                         Sanchezton
# 15    0.004486      0.0000                                              50158
# 16    0.004486      0.0000                                              50158
# 17    0.003364      0.0000                                                 XX
# 18    0.003364      0.0000                                                 XX
# 19    0.001962      0.0000                                         Windows 10
# 20    0.024951      0.0028               abd030d9-bce0-4089-9303-9d46fb13ee16
# 21    0.026633      0.0053                  Adobe Identity Management Service
# 22    0.010093      0.1847                                      Edge 18.17763
# 23    0.016821      0.2094               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 24    0.013176      0.2759  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 25    0.005327      0.3300                                   RUSSELLWATSON-LT
# 26    0.001121      0.3300                             Hybrid Azure AD joined
# 27    0.003645      0.7959     External security challenge was not satisfied.
# 28    0.003645      0.7959     External security challenge was not satisfied.
# 29    0.001402      0.8764    MFA requirement satisfied by claim in the token
#
#                                              example2  \
# 0                044e431d-93e2-415d-9fb5-2936a1a7ec3c
# 1                                                 150
# 2                890fda57-180f-472a-8838-ad79f06ad863
# 3                                               Alaya
# 4                                      38.185.182.132
# 5                                      38.185.182.132
# 6                                            5.176877
# 7                                            6.915915
# 8                15135d1f-cb47-4bd8-b76d-90a9171c09bd
# 9                                           East Kara
# 10                                              11414
# 11                                      Stephen White
# 12                                      Stephen White
# 13               e79f7294-f107-4e74-95d5-53a6521bc624
# 14                                          Amberland
# 15                                                  0
# 16                                                  0
# 17                                                 XK
# 18                                                 XK
# 19                                          Windows10
# 20               2e24cac4-a41a-4c56-ae71-19908dd3372d
# 21                                       Alaya Online
# 22                                      Edge 18.19043
# 23               1f37c851-4be4-455b-928a-fbde7845a68a
# 24  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 25                                    STEPHENWHITE-LT
# 26                                Azure AD registered
# 27  User needs to enroll for second factor authent...
# 28  User needs to enroll for second factor authent...
# 29                           MFA required in Azure AD
#
#                                              example3  \
# 0                778307c7-9801-4873-bb5e-a8adba9f8bb2
# 1                                                  96
# 2                0f834804-f0dc-4fef-b3f5-be308ac60f9f
# 3                                                 Air
# 4                                       185.25.177.84
# 5                                       185.25.177.84
# 6                                         -178.150039
# 7                                          -38.158813
# 8                639815fd-5018-4e38-9d81-67538b2ce460
# 9                                         Port Robert
# 10                                               2510
# 11                                      Amber Estrada
# 12                                      Amber Estrada
# 13               c0c2d7f1-4a8a-4a76-b687-ba2d2001a545
# 14                                          Jesusland
# 15                                              50079
# 16                                              50079
# 17                                                 XS
# 18                                                 XS
# 19                                            Windows
# 20               1f5ea909-535d-450c-a608-299eeff503fb
# 21                                         Air Online
# 22                                      Edge 18.18363
# 23               537d9419-7e2b-4778-9102-62256bcfcf45
# 24  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 25                                    AMBERESTRADA-LT
# 26                                    Azure AD joined
# 27                                              Other
# 28                                              Other
# 29                          MFA completed in Azure AD
#
#     per_ent_cardinality_max  per_ent_cardinality_med  \
# 0                       523                    131.0
# 1                       149                     76.0
# 2                        85                     20.0
# 3                        85                     20.0
# 4                        11                      3.0
# 5                        11                      3.0
# 6                        11                      3.0
# 7                        10                      3.0
# 8                        14                      2.0
# 9                        10                      2.0
# 10                        7                      2.0
# 11                        1                      1.0
# 12                        1                      1.0
# 13                        1                      1.0
# 14                        5                      1.0
# 15                        8                      2.0
# 16                        8                      2.0
# 17                        4                      1.0
# 18                        4                      1.0
# 19                        5                      4.0
# 20                       51                     31.0
# 21                       83                     21.0
# 22                       16                      7.0
# 23                       39                     23.0
# 24                        8                      5.0
# 25                        1                      1.0
# 26                        2                      1.0
# 27                        7                      1.0
# 28                        7                      1.0
# 29                        4                      0.0
#
#     per_ent_cardinality_mean  per_ent_cardinality_min  per_ent_uniq_ratio_max  \
# 0                 220.866667                      118                1.000000
# 1                  92.933333                       65                0.614815
# 2                  25.400000                       13                0.192308
# 3                  25.333333                       13                0.192308
# 4                   3.333333                        1                0.030769
# 5                   3.333333                        1                0.030769
# 6                   3.400000                        1                0.038462
# 7                   3.333333                        1                0.038462
# 8                   3.066667                        1                0.030769
# 9                   3.066667                        1                0.030769
# 10                  2.466667                        1                0.023077
# 11                  1.000000                        1                0.007752
# 12                  1.000000                        1                0.007752
# 13                  1.000000                        1                0.007752
# 14                  1.800000                        1                0.022901
# 15                  3.133333                        1                0.030769
# 16                  3.133333                        1                0.030769
# 17                  1.600000                        1                0.022901
# 18                  1.600000                        1                0.022901
# 19                  3.666667                        2                0.037037
# 20                 31.800000                       22                0.269231
# 21                 26.666667                       14                0.192308
# 22                  7.933333                        3                0.083333
# 23                 22.600000                       10                0.222222
# 24                  5.133333                        3                0.060606
# 25                  0.933333                        0                0.007752
# 26                  1.133333                        0                0.015385
# 27                  2.066667                        0                0.023077
# 28                  2.066667                        0                0.023077
# 29                  0.533333                        0                0.012539
#
#     per_ent_uniq_ratio_med  per_ent_uniq_ratio_mean  per_ent_uniq_ratio_min  \
# 0                 0.977778                 0.959198                0.792829
# 1                 0.521739                 0.473558                0.228571
# 2                 0.141066                 0.129644                0.028571
# 3                 0.137931                 0.129435                0.028571
# 4                 0.015504                 0.016513                0.003984
# 5                 0.015504                 0.016513                0.003984
# 6                 0.015385                 0.016661                0.005976
# 7                 0.015385                 0.016534                0.005976
# 8                 0.015267                 0.015237                0.003984
# 9                 0.015385                 0.014851                0.004444
# 10                0.015152                 0.013084                0.001992
# 11                0.007576                 0.005848                0.001905
# 12                0.007576                 0.005848                0.001905
# 13                0.007576                 0.005848                0.001905
# 14                0.007634                 0.008491                0.002506
# 15                0.015152                 0.014927                0.001992
# 16                0.015152                 0.014927                0.001992
# 17                0.007634                 0.008028                0.002506
# 18                0.007634                 0.008028                0.002506
# 19                0.028986                 0.021992                0.003984
# 20                0.195652                 0.180401                0.043810
# 21                0.146154                 0.136353                0.028571
# 22                0.050157                 0.045370                0.005976
# 23                0.159420                 0.134885                0.019920
# 24                0.030534                 0.029079                0.005976
# 25                0.007407                 0.005343                0.000000
# 26                0.007634                 0.006466                0.000000
# 27                0.007634                 0.008952                0.000000
# 28                0.007634                 0.008952                0.000000
# 29                0.000000                 0.002542                0.000000
#
#     per_ent_null_ratio_max  per_ent_null_ratio_med  per_ent_null_ratio_mean  \
# 0                 0.000000                0.000000                 0.000000
# 1                 0.000000                0.000000                 0.000000
# 2                 0.000000                0.000000                 0.000000
# 3                 0.000000                0.000000                 0.000000
# 4                 0.000000                0.000000                 0.000000
# 5                 0.000000                0.000000                 0.000000
# 6                 0.000000                0.000000                 0.000000
# 7                 0.000000                0.000000                 0.000000
# 8                 0.000000                0.000000                 0.000000
# 9                 0.000000                0.000000                 0.000000
# 10                0.000000                0.000000                 0.000000
# 11                0.000000                0.000000                 0.000000
# 12                0.000000                0.000000                 0.000000
# 13                0.000000                0.000000                 0.000000
# 14                0.000000                0.000000                 0.000000
# 15                0.000000                0.000000                 0.000000
# 16                0.000000                0.000000                 0.000000
# 17                0.000000                0.000000                 0.000000
# 18                0.000000                0.000000                 0.000000
# 19                0.000000                0.000000                 0.000000
# 20                0.023077                0.000000                 0.002601
# 21                0.023077                0.000000                 0.004945
# 22                0.857778                0.083969                 0.160483
# 23                0.468889                0.189394                 0.201239
# 24                0.911111                0.206107                 0.252868
# 25                1.000000                0.107692                 0.276595
# 26                1.000000                0.107692                 0.276595
# 27                1.000000                0.961538                 0.860190
# 28                1.000000                0.961538                 0.860190
# 29                1.000000                1.000000                 0.858408
#
#     per_ent_null_ratio_min
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# 5                 0.000000
# 6                 0.000000
# 7                 0.000000
# 8                 0.000000
# 9                 0.000000
# 10                0.000000
# 11                0.000000
# 12                0.000000
# 13                0.000000
# 14                0.000000
# 15                0.000000
# 16                0.000000
# 17                0.000000
# 18                0.000000
# 19                0.000000
# 20                0.000000
# 21                0.000000
# 22                0.003984
# 23                0.013333
# 24                0.000000
# 25                0.000000
# 26                0.000000
# 27                0.057143
# 28                0.057143
# 29                0.015504

# %%
good_feat_candidate_criteria = (
    # median is a more objective measurement but we can also use mean if we want to take into account everything including the outliers
    (feature_stats.per_ent_uniq_ratio_med < 0.95)
    & ~((feature_stats.per_ent_cardinality_med < 2) & (feature_stats.type != 'bool'))
    & (feature_stats.per_ent_null_ratio_med < 0.9)
)
final_feature_candidates = feature_stats.loc[good_feat_candidate_criteria]

# %%
final_feature_candidates
# Out:
#                                            field     type  cardinality  \
# 1        properties.processingTimeInMilliseconds    int64          310
# 2                               properties.appId      str           86
# 3                      properties.appDisplayName      str           85
# 4                                callerIpAddress      str           43
# 5                           properties.ipAddress      str           43
# 6   properties.location.geoCoordinates.longitude  float64           42
# 7    properties.location.geoCoordinates.latitude  float64           41
# 8               properties.deviceDetail.deviceId      str           37
# 9                       properties.location.city      str           35
# 10             properties.autonomousSystemNumber    int64           27
# 15                                    resultType      str           16
# 16                   properties.status.errorCode    int64           16
# 19       properties.deviceDetail.operatingSystem      str            7
# 20                         properties.resourceId      str           89
# 21                properties.resourceDisplayName      str           95
# 22               properties.deviceDetail.browser      str           36
# 23         properties.resourceServicePrincipalId      str           60
# 24                          properties.userAgent      str           47
#
#     uniq_ratio  null_ratio                                           example1  \
# 1     0.086908      0.0000                                                120
# 2     0.024110      0.0000               9da0a1ff-e8cf-4513-8520-bf84f723f1ae
# 3     0.023830      0.0000                          Adobe Identity Management
# 4     0.012055      0.0000                                        68.28.66.83
# 5     0.012055      0.0000                                        68.28.66.83
# 6     0.011775      0.0000                                         170.600705
# 7     0.011494      0.0000                                         -49.889482
# 8     0.010373      0.0000               72c565a0-f587-4d5e-9fa9-82cab482ddf0
# 9     0.009812      0.0000                                          Dawnshire
# 10    0.007569      0.0000                                              38834
# 15    0.004486      0.0000                                              50158
# 16    0.004486      0.0000                                              50158
# 19    0.001962      0.0000                                         Windows 10
# 20    0.024951      0.0028               abd030d9-bce0-4089-9303-9d46fb13ee16
# 21    0.026633      0.0053                  Adobe Identity Management Service
# 22    0.010093      0.1847                                      Edge 18.17763
# 23    0.016821      0.2094               a6c259e5-7f16-48b2-a9f3-75becd6daa9b
# 24    0.013176      0.2759  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#                                              example2  \
# 1                                                 150
# 2                890fda57-180f-472a-8838-ad79f06ad863
# 3                                               Alaya
# 4                                      38.185.182.132
# 5                                      38.185.182.132
# 6                                            5.176877
# 7                                            6.915915
# 8                15135d1f-cb47-4bd8-b76d-90a9171c09bd
# 9                                           East Kara
# 10                                              11414
# 15                                                  0
# 16                                                  0
# 19                                          Windows10
# 20               2e24cac4-a41a-4c56-ae71-19908dd3372d
# 21                                       Alaya Online
# 22                                      Edge 18.19043
# 23               1f37c851-4be4-455b-928a-fbde7845a68a
# 24  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#                                              example3  \
# 1                                                  96
# 2                0f834804-f0dc-4fef-b3f5-be308ac60f9f
# 3                                                 Air
# 4                                       185.25.177.84
# 5                                       185.25.177.84
# 6                                         -178.150039
# 7                                          -38.158813
# 8                639815fd-5018-4e38-9d81-67538b2ce460
# 9                                         Port Robert
# 10                                               2510
# 15                                              50079
# 16                                              50079
# 19                                            Windows
# 20               1f5ea909-535d-450c-a608-299eeff503fb
# 21                                         Air Online
# 22                                      Edge 18.18363
# 23               537d9419-7e2b-4778-9102-62256bcfcf45
# 24  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#     per_ent_cardinality_max  per_ent_cardinality_med  \
# 1                       149                     76.0
# 2                        85                     20.0
# 3                        85                     20.0
# 4                        11                      3.0
# 5                        11                      3.0
# 6                        11                      3.0
# 7                        10                      3.0
# 8                        14                      2.0
# 9                        10                      2.0
# 10                        7                      2.0
# 15                        8                      2.0
# 16                        8                      2.0
# 19                        5                      4.0
# 20                       51                     31.0
# 21                       83                     21.0
# 22                       16                      7.0
# 23                       39                     23.0
# 24                        8                      5.0
#
#     per_ent_cardinality_mean  per_ent_cardinality_min  per_ent_uniq_ratio_max  \
# 1                  92.933333                       65                0.614815
# 2                  25.400000                       13                0.192308
# 3                  25.333333                       13                0.192308
# 4                   3.333333                        1                0.030769
# 5                   3.333333                        1                0.030769
# 6                   3.400000                        1                0.038462
# 7                   3.333333                        1                0.038462
# 8                   3.066667                        1                0.030769
# 9                   3.066667                        1                0.030769
# 10                  2.466667                        1                0.023077
# 15                  3.133333                        1                0.030769
# 16                  3.133333                        1                0.030769
# 19                  3.666667                        2                0.037037
# 20                 31.800000                       22                0.269231
# 21                 26.666667                       14                0.192308
# 22                  7.933333                        3                0.083333
# 23                 22.600000                       10                0.222222
# 24                  5.133333                        3                0.060606
#
#     per_ent_uniq_ratio_med  per_ent_uniq_ratio_mean  per_ent_uniq_ratio_min  \
# 1                 0.521739                 0.473558                0.228571
# 2                 0.141066                 0.129644                0.028571
# 3                 0.137931                 0.129435                0.028571
# 4                 0.015504                 0.016513                0.003984
# 5                 0.015504                 0.016513                0.003984
# 6                 0.015385                 0.016661                0.005976
# 7                 0.015385                 0.016534                0.005976
# 8                 0.015267                 0.015237                0.003984
# 9                 0.015385                 0.014851                0.004444
# 10                0.015152                 0.013084                0.001992
# 15                0.015152                 0.014927                0.001992
# 16                0.015152                 0.014927                0.001992
# 19                0.028986                 0.021992                0.003984
# 20                0.195652                 0.180401                0.043810
# 21                0.146154                 0.136353                0.028571
# 22                0.050157                 0.045370                0.005976
# 23                0.159420                 0.134885                0.019920
# 24                0.030534                 0.029079                0.005976
#
#     per_ent_null_ratio_max  per_ent_null_ratio_med  per_ent_null_ratio_mean  \
# 1                 0.000000                0.000000                 0.000000
# 2                 0.000000                0.000000                 0.000000
# 3                 0.000000                0.000000                 0.000000
# 4                 0.000000                0.000000                 0.000000
# 5                 0.000000                0.000000                 0.000000
# 6                 0.000000                0.000000                 0.000000
# 7                 0.000000                0.000000                 0.000000
# 8                 0.000000                0.000000                 0.000000
# 9                 0.000000                0.000000                 0.000000
# 10                0.000000                0.000000                 0.000000
# 15                0.000000                0.000000                 0.000000
# 16                0.000000                0.000000                 0.000000
# 19                0.000000                0.000000                 0.000000
# 20                0.023077                0.000000                 0.002601
# 21                0.023077                0.000000                 0.004945
# 22                0.857778                0.083969                 0.160483
# 23                0.468889                0.189394                 0.201239
# 24                0.911111                0.206107                 0.252868
#
#     per_ent_null_ratio_min
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# 5                 0.000000
# 6                 0.000000
# 7                 0.000000
# 8                 0.000000
# 9                 0.000000
# 10                0.000000
# 15                0.000000
# 16                0.000000
# 19                0.000000
# 20                0.000000
# 21                0.000000
# 22                0.003984
# 23                0.013333
# 24                0.000000

# %%
len(final_feature_candidates)
# Out:
# 18

# %% [markdown]
# Note that `properties.processingTimeInMilliseconds` doesn't seem to be carrying interesting security meaning even if it looks good from the data science perspectives.<br>
# Reviewing with domain expert can help filter out the deceivingly promising features!

# %% [markdown]
# ### 5.4. Feature Correlation<a class="anchor" id="1.6.5"></a>
# Evaluate the correlation between feature candidates to remove redundancy.
# - A data source can have multiple fields representing similar information
#     - E.g., `callerIpAddress` and `properties.ipAddress` are two separate but highly correlated fields in Azure AD logs.<br>
#       They both represent the IP address of the actor in the log event and will always share the same value.
# - <font color='#76B900'>Minimizing redundancy</font> in the feature space boosts the DFP pipeline’s <font color='#76B900'>efficacy</font> and <font color='#76B900'>efficiency</font>
#     - Including fields with overlapping information can distract the model and lead to extra computational cost
# - Measuring the <font color='#76B900'>correlation</font> between each pair of features helps identify and remove redundancy
#     - Make note of the highly correlated features discuss with security experts to rule out redundant information

# %%
# get a dataframe that only includes the final candidate columns
final_candidate_data = data_candidate_cols[final_feature_candidates.field].copy()

# %% [markdown]
# #### 5.4.1 Pearson Correlation Coefficients - Numerical Feature Correlation<a class="anchor" id="1.6.5.1"></a>
# Measure the correlation between numerical features (value range: [-1, 1])
# - Value near ± 1 indicates strong correlation while value near 0 shows no correlation
# - \> 0.5 (or < -0.5) is considered correlation strong enough to be aware of<br>
#
# Analyze the numerical columns:

# %%
final_candidate_data.corr(method='pearson')
# Out:
#                                               properties.processingTimeInMilliseconds  \
# properties.processingTimeInMilliseconds                                      1.000000
# properties.location.geoCoordinates.longitude                                 0.065748
# properties.location.geoCoordinates.latitude                                  0.116035
# properties.autonomousSystemNumber                                            0.018635
# properties.status.errorCode                                                 -0.035325
#
#                                               properties.location.geoCoordinates.longitude  \
# properties.processingTimeInMilliseconds                                           0.065748
# properties.location.geoCoordinates.longitude                                      1.000000
# properties.location.geoCoordinates.latitude                                      -0.124969
# properties.autonomousSystemNumber                                                -0.336707
# properties.status.errorCode                                                      -0.118040
#
#                                               properties.location.geoCoordinates.latitude  \
# properties.processingTimeInMilliseconds                                          0.116035
# properties.location.geoCoordinates.longitude                                    -0.124969
# properties.location.geoCoordinates.latitude                                      1.000000
# properties.autonomousSystemNumber                                                0.184355
# properties.status.errorCode                                                      0.151495
#
#                                               properties.autonomousSystemNumber  \
# properties.processingTimeInMilliseconds                                0.018635
# properties.location.geoCoordinates.longitude                          -0.336707
# properties.location.geoCoordinates.latitude                            0.184355
# properties.autonomousSystemNumber                                      1.000000
# properties.status.errorCode                                            0.188610
#
#                                               properties.status.errorCode
# properties.processingTimeInMilliseconds                         -0.035325
# properties.location.geoCoordinates.longitude                    -0.118040
# properties.location.geoCoordinates.latitude                      0.151495
# properties.autonomousSystemNumber                                0.188610
# properties.status.errorCode                                      1.000000

# %% [markdown]
# We can see that there is very little correlation between the numerical columns.

# %% [markdown]
# #### 5.4.2 Cramer's V - Categorical Feature Correlation<a class="anchor" id="1.6.5.2"></a>
# - Value near 1 indicates strong correlation while value near 0 shows no correlation
# - \> 0.5 is considered correlation strong enough to be aware of

# %% [markdown]
# ##### Preporcessing the dataframe
# To measure the correlation between a numerical and a categorical feature, we can bin the numerical feature values into buckets and treat as categorical.

# %%
# Drop properties.processingTimeInMilliseconds as there is no security relevancy
final_candidate_data = final_candidate_data.drop(columns=['properties.processingTimeInMilliseconds'])

# latitude and longitude (numerical, float between -180 to 180) can be binned into size 5 buckets so we have 72 categories instead of infinite possible values
# Note that we use a bin size of 5 here for demonstration, but it can be any value you see fit for your use case.
round_to_closest_5 = lambda x: x//5 * 5
final_candidate_data['latitude_binned'] = final_candidate_data['properties.location.geoCoordinates.latitude'].apply(round_to_closest_5)
final_candidate_data['longitude_binned'] = final_candidate_data['properties.location.geoCoordinates.longitude'].apply(round_to_closest_5)
final_candidate_data = final_candidate_data.drop(columns=['properties.location.geoCoordinates.latitude', 'properties.location.geoCoordinates.longitude'])

# %%
def cramers_v(confusion_matrix):
    """ Takes a confusion matrix of two features and return the Cramer's V correlation coefficient.
    Note that Cramér's V tends to overestimate the strength of association hence this funciton is integrating the suggested correction terms.
    
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r, k = confusion_matrix.shape
    phi2_corrected = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    r_corrected = r - ((r-1)**2)/(n-1)
    k_corrected = k - ((k-1)**2)/(n-1)
    v_corrected = np.sqrt(phi2_corrected / min( (k_corrected-1), (r_corrected-1)))
    return v_corrected

def measure_correlation(data):
    """ Go through all possible pairs of features, evaluate the Cramer's correlation value, and return the result in a dataframe."""
    correlation_results = []
    for i, col_i in enumerate(data.columns):
        for j, col_j in enumerate(data.columns):
            if i >= j:
                # no need to repeat for the same pairs
                continue

            conf_matrix = pd.crosstab(data[col_i], data[col_j])
            v = cramers_v(conf_matrix)
            correlation_results.append([col_i, col_j, v])
    return pd.DataFrame(correlation_results, columns=['column1', 'column2', 'cramers_v'])

# %% [markdown]
# ##### Loop through all pairs of features and evaluate their correlation

# %%
correlations = measure_correlation(final_candidate_data).sort_values('cramers_v', ascending=False)

# %% [markdown]
# ##### Strongly correlated features

# %%
correlations.loc[correlations.cramers_v > 0.5]
# Out:
#                                      column1  \
# 31                           callerIpAddress
# 91                                resultType
# 0                           properties.appId
# 117                    properties.resourceId
# 25                 properties.appDisplayName
# 47                      properties.ipAddress
# 34                           callerIpAddress
# 10                          properties.appId
# 112  properties.deviceDetail.operatingSystem
# 127          properties.deviceDetail.browser
# 43                           callerIpAddress
# 56                      properties.ipAddress
# 46                      properties.ipAddress
# 33                           callerIpAddress
# 57                      properties.ipAddress
# 44                           callerIpAddress
# 79                  properties.location.city
# 135                          latitude_binned
# 70                  properties.location.city
# 80                  properties.location.city
# 90         properties.autonomousSystemNumber
# 110  properties.deviceDetail.operatingSystem
# 89         properties.autonomousSystemNumber
# 121           properties.resourceDisplayName
# 45                      properties.ipAddress
# 32                           callerIpAddress
# 59          properties.deviceDetail.deviceId
# 26                 properties.appDisplayName
# 11                          properties.appId
# 109  properties.deviceDetail.operatingSystem
# 23                 properties.appDisplayName
# 8                           properties.appId
# 115                    properties.resourceId
# 50                      properties.ipAddress
# 37                           callerIpAddress
# 24                 properties.appDisplayName
# 9                           properties.appId
# 58          properties.deviceDetail.deviceId
# 122           properties.resourceDisplayName
# 68          properties.deviceDetail.deviceId
# 88         properties.autonomousSystemNumber
# 42                           callerIpAddress
# 55                      properties.ipAddress
# 27                 properties.appDisplayName
# 12                          properties.appId
# 133                     properties.userAgent
# 69          properties.deviceDetail.deviceId
# 73                  properties.location.city
# 83         properties.autonomousSystemNumber
# 78                  properties.location.city
# 114  properties.deviceDetail.operatingSystem
# 67          properties.deviceDetail.deviceId
#
#                                      column2  cramers_v
# 31                      properties.ipAddress   1.000000
# 91               properties.status.errorCode   1.000000
# 0                  properties.appDisplayName   0.999856
# 117    properties.resourceServicePrincipalId   0.999819
# 25            properties.resourceDisplayName   0.998411
# 47         properties.autonomousSystemNumber   0.997738
# 34         properties.autonomousSystemNumber   0.997738
# 10            properties.resourceDisplayName   0.992359
# 112                     properties.userAgent   0.992016
# 127                     properties.userAgent   0.974065
# 43                           latitude_binned   0.968697
# 56                           latitude_binned   0.968697
# 46                  properties.location.city   0.961731
# 33                  properties.location.city   0.961731
# 57                          longitude_binned   0.960619
# 44                          longitude_binned   0.960619
# 79                           latitude_binned   0.941599
# 135                         longitude_binned   0.929327
# 70         properties.autonomousSystemNumber   0.908852
# 80                          longitude_binned   0.908687
# 90                          longitude_binned   0.864018
# 110          properties.deviceDetail.browser   0.826355
# 89                           latitude_binned   0.758978
# 121          properties.deviceDetail.browser   0.658822
# 45          properties.deviceDetail.deviceId   0.658617
# 32          properties.deviceDetail.deviceId   0.658617
# 59         properties.autonomousSystemNumber   0.655199
# 26           properties.deviceDetail.browser   0.653840
# 11           properties.deviceDetail.browser   0.653614
# 109           properties.resourceDisplayName   0.627832
# 23   properties.deviceDetail.operatingSystem   0.627355
# 8    properties.deviceDetail.operatingSystem   0.627131
# 115           properties.resourceDisplayName   0.615085
# 50   properties.deviceDetail.operatingSystem   0.601365
# 37   properties.deviceDetail.operatingSystem   0.601365
# 24                     properties.resourceId   0.591824
# 9                      properties.resourceId   0.588151
# 58                  properties.location.city   0.584373
# 122    properties.resourceServicePrincipalId   0.583246
# 68                           latitude_binned   0.567768
# 88                      properties.userAgent   0.565467
# 42                      properties.userAgent   0.552729
# 55                      properties.userAgent   0.552729
# 27     properties.resourceServicePrincipalId   0.547362
# 12     properties.resourceServicePrincipalId   0.547104
# 133                          latitude_binned   0.543726
# 69                          longitude_binned   0.537211
# 73   properties.deviceDetail.operatingSystem   0.528056
# 83   properties.deviceDetail.operatingSystem   0.518374
# 78                      properties.userAgent   0.508430
# 114                         longitude_binned   0.503408
# 67                      properties.userAgent   0.501172

# %% [markdown]
# Each pair of features in the above table correlates strong enough to be aware of. <br>
# - E.g., `resourceId` and `resourceDisplayName` in Azure AD logs both provide information on which resource was accessed in an event, one being the ID string while the other being the human-readable name. <br>
#   The two fields share a **~1.0** Cramer’s correlation score because there is a one-to-one mapping between them.<br>
#   We should choose one from the two to avoid adding redundancy in the feature space.
# - E.g. `properties.location.city` and `properties.userAgent` has a correlation of **0.51**, which is not insignificant.<br>
#   However, the two variables are independent from the security perspective. We would want to keep both of them as potential feature candidates.<br>
#
# The correlation analysis helps us quickly identify the possible redundancy in the feature space, but <font color='#76B900'>a strong correlation doesn't indicate dependency.</font><br>
# It is important to understand the security context and the dependency of features before ruling out any features. (Two features can show a strong correlation in a sampled dataset by coincidence!)

# %% [markdown]
# ### 5.5. Review with Security Experts<a class="anchor" id="1.6.6"></a>
# Validate the feature candidates with security experts.
# - A “good feature” identified by data science methods can be irrelevant to the problem being solved
#     - E.g., `processingTimeInMilliseconds` is a feature in Azure AD logs which has a proper cardinality and is never null.<br>
#       However, it represents the milliseconds taken to process the log, which helps monitor the health of the pipeline but carries very little security context about the event.
# - An identified “bad feature” can carry important security context and just needs some extra feature engineering to be useful
#     - E.g., `timestamp` of every log is unique. Hence as a feature, timestamp will have a super high cardinality.<br>
#       However, the time an event happened can contribute largely to the “anomalousness” of a behavior.<br>
#       As a workaround, we can capture the time information by parsing “hour of day” or “day of week” and use them as derived features.
# - Reviewing feature candidates with security experts helps keep our model <font color='#76B900'>relevant</font> and <font color='#76B900'>effective</font>
#     - A deeper understanding of the data and the target domain is always beneficial for all ML applications

# %% [markdown]
# ## 6. Ideas on Derived Features<a class="anchor" id="1.7"></a>
# The previous sections demonstrate a way to select from the raw features. However, raw values do not always capture the information that is helpful for modeling.
# - Derived features enlighten the model on <font color='#76B900'>key</font> information that is <font color='#76B900'>hidden</font> in plain sight
# - Examples of useful insights to feed into the model:
#     - **Strong relation between fields**<br>
#     E.g.: City, state, and country fields together provide information on location.<br>
#     Concatenating them into a single <font color='#76B900'>location</font> feature can inform the model about it and avoid collisions between multiple cities with the same names.
#     - **Semantics behind the plain value of a field**<br>
#     E.g.: App name are strings hence are treated as categorical features by the model. However, `Microsoft Teams` and `Microsoft Teams Services` might be semantically closer compared to `Office 365 Exchange Online`.<br>
#     Adding an <font color='#76B900'>app category</font> feature (e.g., `MS Teams`/`Exchange`) can help capture the meaning of the field better.
#     - **Anomalous pattern to target**<br>
#     Depending on the use case, there may be specific patterns we wish to highlight for the model.<br>
#     E.g.: Being compromised, a user account may be used to access a high number of resources in the environment.<br>
#     In this case, <font color='#76B900'>incremental app count</font> for the day would be a good feature to being attention to targeted red flags.

# %% [markdown]
# ## 7. Conclusion<a class="anchor" id="1.8"></a>
# - Feature selection and feature engineering are fundamental to all machine learning applications
# - A good feature set should cover the key information about an event (actor, time, location, resource accessed, ... etc.) without redundancy
# - Any information that is considered useful for a human analyst during threat investigation should be considered to be included in the DFP feature set<br>
#
# With a good set of raw and derived features, DFP can be a powerful tool that helps monitor the activities in the network and detect anomalies at scale.
